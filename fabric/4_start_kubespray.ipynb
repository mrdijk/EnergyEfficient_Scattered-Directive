# %%
import datetime
import json
import asyncio

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()

fablib.show_config();
# Out:
# <style type="text/css">
# #T_62e57 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_62e57 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_62e57 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_62e57_row0_col0, #T_62e57_row0_col1, #T_62e57_row1_col0, #T_62e57_row1_col1, #T_62e57_row2_col0, #T_62e57_row2_col1, #T_62e57_row3_col0, #T_62e57_row3_col1, #T_62e57_row4_col0, #T_62e57_row4_col1, #T_62e57_row5_col0, #T_62e57_row5_col1, #T_62e57_row6_col0, #T_62e57_row6_col1, #T_62e57_row7_col0, #T_62e57_row7_col1, #T_62e57_row8_col0, #T_62e57_row8_col1, #T_62e57_row9_col0, #T_62e57_row9_col1, #T_62e57_row10_col0, #T_62e57_row10_col1, #T_62e57_row11_col0, #T_62e57_row11_col1, #T_62e57_row12_col0, #T_62e57_row12_col1, #T_62e57_row13_col0, #T_62e57_row13_col1, #T_62e57_row14_col0, #T_62e57_row14_col1, #T_62e57_row15_col0, #T_62e57_row15_col1, #T_62e57_row16_col0, #T_62e57_row16_col1, #T_62e57_row17_col0, #T_62e57_row17_col1, #T_62e57_row18_col0, #T_62e57_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_62e57">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_62e57_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_62e57_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_62e57_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_62e57_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_62e57_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_62e57_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_62e57_row5_col1" class="data row5 col1" >49f65ad7-d8a2-4ab9-8ca0-ba777a2e0ea2</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_62e57_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_62e57_row7_col1" class="data row7 col1" >jakejongejans_0000313927</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_62e57_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_62e57_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_62e57_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_62e57_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_62e57_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_62e57_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_62e57_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_62e57_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row16_col0" class="data row16 col0" >Version</td>
#       <td id="T_62e57_row16_col1" class="data row16 col1" >1.8.0</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row17_col0" class="data row17 col0" >Data directory</td>
#       <td id="T_62e57_row17_col1" class="data row17 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_62e57_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_62e57_row18_col1" class="data row18 col1" >DYNAMOS project</td>
#     </tr>
#   </tbody>
# </table>

# %%
slice = fablib.get_slice(name="DYNAMOS-on-FABRIC");
nodes = slice.get_nodes();

# %%
nodes[0].upload_file(local_file_path="node_scripts/start_kubespray.sh", remote_file_path="start.sh");
nodes[0].execute(f"chmod +x start.sh && ./start.sh");
# Out:
# Using /home/ubuntu/kubespray/ansible.cfg as config file
#
# PLAY [Check Ansible version] ***************************************************
# Saturday 19 April 2025  19:22:29 +0000 (0:00:00.014)       0:00:00.014 ********
#  [WARNING]: While constructing a mapping from
# /home/ubuntu/kubespray/roles/bootstrap-os/tasks/main.yml, line 29, column 7,
# found a duplicate dict key (paths). Using last defined value only.
# [WARNING]: Skipping callback plugin 'ara_default', unable to load
#
# TASK [Check 2.16.4 <= Ansible version < 2.17.0] ********************************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 19 April 2025  19:22:29 +0000 (0:00:00.025)       0:00:00.040 ********
#
# TASK [Check that python netaddr is installed] **********************************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 19 April 2025  19:22:29 +0000 (0:00:00.051)       0:00:00.091 ********
#
# TASK [Check that jinja is not too old (install via pip)] ***********************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
#
# PLAY [Define groups for legacy less structured inventories] ********************
# Saturday 19 April 2025  19:22:29 +0000 (0:00:00.056)       0:00:00.148 ********
#
# TASK [Match needed groups by their old names or definition] ********************
# changed: [dynamos] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [dynamos] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
#  [WARNING]: Could not match supplied host pattern, ignoring: bastion
#   [WARNING]: Could not match supplied host pattern, ignoring: calico_rr
#  changed: [worker-1] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-1] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-2] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-2] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-3] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-3] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [control] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [control] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
#
# PLAY [Install bastion ssh config] **********************************************
# skipping: no hosts matched
#
# PLAY [Bootstrap hosts for Ansible] *********************************************
# Saturday 19 April 2025  19:22:29 +0000 (0:00:00.153)       0:00:00.301 ********
#  [WARNING]: raw module does not support the environment keyword
#
# TASK [bootstrap-os : Fetch /etc/os-release] ************************************
# ok: [worker-1] => {"changed": false, "rc": 0, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [control] => {"changed": false, "rc": 0, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [dynamos] => {"changed": false, "rc": 0, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-2] => {"changed": false, "rc": 0, "stderr": "Shared connection to 10.137.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.137.8.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-3] => {"changed": false, "rc": 0, "stderr": "Shared connection to 10.146.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.146.8.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# Saturday 19 April 2025  19:22:30 +0000 (0:00:00.791)       0:00:01.093 ********
# Saturday 19 April 2025  19:22:30 +0000 (0:00:00.131)       0:00:01.224 ********
#
# TASK [bootstrap-os : Include tasks] ********************************************
# included: /home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml for dynamos, worker-1, worker-2, worker-3, control => (item=/home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml)
# Saturday 19 April 2025  19:22:31 +0000 (0:00:00.217)       0:00:01.442 ********
#
# TASK [bootstrap-os : Check if bootstrap is needed] *****************************
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [control] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.137.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.137.8.2 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.146.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.146.8.2 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# Saturday 19 April 2025  19:22:31 +0000 (0:00:00.788)       0:00:02.230 ********
#
# TASK [bootstrap-os : Check http::proxy in apt configuration files] *************
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [control] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.137.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.137.8.2 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.146.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.146.8.2 closed."], "stdout": "", "stdout_lines": []}
# Saturday 19 April 2025  19:22:32 +0000 (0:00:00.794)       0:00:03.025 ********
# Saturday 19 April 2025  19:22:32 +0000 (0:00:00.071)       0:00:03.096 ********
#
# TASK [bootstrap-os : Check https::proxy in apt configuration files] ************
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [control] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "\r
# ", "stdout_lines": [""]}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.137.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.137.8.2 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.146.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.146.8.2 closed."], "stdout": "", "stdout_lines": []}
# Saturday 19 April 2025  19:22:33 +0000 (0:00:00.846)       0:00:03.943 ********
# Saturday 19 April 2025  19:22:33 +0000 (0:00:00.073)       0:00:04.016 ********
# Saturday 19 April 2025  19:22:33 +0000 (0:00:00.067)       0:00:04.083 ********
# Saturday 19 April 2025  19:22:33 +0000 (0:00:00.118)       0:00:04.202 ********
#
# TASK [bootstrap-os : Ensure iproute2 is installed] *****************************
# ok: [dynamos] => {"cache_update_time": 1745090337, "cache_updated": false, "changed": false}
# ok: [control] => {"cache_update_time": 1745090336, "cache_updated": false, "changed": false}
# ok: [worker-1] => {"cache_update_time": 1745090336, "cache_updated": false, "changed": false}
# ok: [worker-2] => {"cache_update_time": 1745090337, "cache_updated": false, "changed": false}
# ok: [worker-3] => {"cache_update_time": 1745090338, "cache_updated": false, "changed": false}
# Saturday 19 April 2025  19:22:40 +0000 (0:00:06.745)       0:00:10.947 ********
# Saturday 19 April 2025  19:22:40 +0000 (0:00:00.066)       0:00:11.014 ********
# Saturday 19 April 2025  19:22:40 +0000 (0:00:00.066)       0:00:11.081 ********
#
# TASK [bootstrap-os : Create remote_tmp for it is used by another module] *******
# ok: [dynamos] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-1] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [control] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-2] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-3] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# Saturday 19 April 2025  19:22:46 +0000 (0:00:05.774)       0:00:16.855 ********
#
# TASK [bootstrap-os : Gather facts] *********************************************
# ok: [control]
# ok: [dynamos]
# ok: [worker-1]
# ok: [worker-2]
# ok: [worker-3]
# Saturday 19 April 2025  19:22:53 +0000 (0:00:06.510)       0:00:23.365 ********
#
# TASK [bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora)] ***
# ok: [control] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "control", "ansible_hostname": "control", "ansible_nodename": "control"}, "changed": false, "name": "control"}
# ok: [worker-1] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "worker-1", "ansible_hostname": "worker-1", "ansible_nodename": "worker-1"}, "changed": false, "name": "worker-1"}
# ok: [dynamos] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "dynamos", "ansible_hostname": "dynamos", "ansible_nodename": "dynamos"}, "changed": false, "name": "dynamos"}
# ok: [worker-2] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "worker-2", "ansible_hostname": "worker-2", "ansible_nodename": "worker-2"}, "changed": false, "name": "worker-2"}
# ok: [worker-3] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "worker-3", "ansible_hostname": "worker-3", "ansible_nodename": "worker-3"}, "changed": false, "name": "worker-3"}
# Saturday 19 April 2025  19:23:00 +0000 (0:00:07.262)       0:00:30.628 ********
# Saturday 19 April 2025  19:23:00 +0000 (0:00:00.090)       0:00:30.719 ********
#
# TASK [bootstrap-os : Ensure bash_completion.d folder exists] *******************
# ok: [dynamos] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-1] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [control] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-2] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-3] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# Saturday 19 April 2025  19:23:06 +0000 (0:00:06.068)       0:00:36.787 ********
# Saturday 19 April 2025  19:23:06 +0000 (0:00:00.073)       0:00:36.860 ********
#
# TASK [kubespray-defaults : Set fallback_ip] ************************************
# ok: [dynamos] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-1] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-2] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-3] => {"ansible_facts": {"fallback_ip": "10.20.5.75"}, "changed": false}
# ok: [control] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# Saturday 19 April 2025  19:23:06 +0000 (0:00:00.170)       0:00:37.031 ********
# Saturday 19 April 2025  19:23:06 +0000 (0:00:00.024)       0:00:37.056 ********
# Saturday 19 April 2025  19:23:06 +0000 (0:00:00.072)       0:00:37.128 ********
#
# PLAY [Gather facts] ************************************************************
# Saturday 19 April 2025  19:23:06 +0000 (0:00:00.106)       0:00:37.235 ********
#
# TASK [Gather minimal facts] ****************************************************
# ok: [dynamos]
# ok: [worker-1]
# ok: [control]
# ok: [worker-3]
# ok: [worker-2]
# Saturday 19 April 2025  19:23:09 +0000 (0:00:02.179)       0:00:39.414 ********
#
# TASK [Gather necessary facts (network)] ****************************************
# ok: [dynamos]
# ok: [worker-1]
# ok: [control]
# ok: [worker-3]
# ok: [worker-2]
# Saturday 19 April 2025  19:23:11 +0000 (0:00:02.142)       0:00:41.557 ********
#
# TASK [Gather necessary facts (hardware)] ***************************************
# ok: [dynamos]
# ok: [worker-1]
# ok: [control]
# ok: [worker-3]
# ok: [worker-2]
#
# PLAY [Prepare for etcd install] ************************************************
# Saturday 19 April 2025  19:23:13 +0000 (0:00:02.423)       0:00:43.981 ********
# Saturday 19 April 2025  19:23:13 +0000 (0:00:00.074)       0:00:44.055 ********
# Saturday 19 April 2025  19:23:13 +0000 (0:00:00.074)       0:00:44.130 ********
# Saturday 19 April 2025  19:23:13 +0000 (0:00:00.023)       0:00:44.154 ********
# Saturday 19 April 2025  19:23:13 +0000 (0:00:00.121)       0:00:44.275 ********
# Saturday 19 April 2025  19:23:14 +0000 (0:00:00.111)       0:00:44.386 ********
#
# TASK [adduser : User | Create User Group] **************************************
# ok: [control] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [worker-1] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [dynamos] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [worker-2] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [worker-3] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# Saturday 19 April 2025  19:23:15 +0000 (0:00:01.471)       0:00:45.858 ********
#
# TASK [adduser : User | Create User] ********************************************
# ok: [dynamos] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# ok: [worker-1] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# ok: [control] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# ok: [worker-2] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# ok: [worker-3] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# Saturday 19 April 2025  19:23:16 +0000 (0:00:01.335)       0:00:47.193 ********
#
# TASK [kubernetes/preinstall : Check if /etc/fstab exists] **********************
# ok: [worker-1] => {"changed": false, "stat": {"atime": 1745090296.5272298, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [dynamos] => {"changed": false, "stat": {"atime": 1745090296.5243857, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [control] => {"changed": false, "stat": {"atime": 1745090296.5258722, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [worker-2] => {"changed": false, "stat": {"atime": 1745090296.8854687, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [worker-3] => {"changed": false, "stat": {"atime": 1745090297.1289103, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# Saturday 19 April 2025  19:23:18 +0000 (0:00:01.256)       0:00:48.450 ********
#
# TASK [kubernetes/preinstall : Remove swapfile from /etc/fstab] *****************
# ok: [dynamos] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [control] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [worker-1] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [dynamos] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [control] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [worker-1] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [worker-2] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [worker-3] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [worker-2] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [worker-3] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# Saturday 19 April 2025  19:23:20 +0000 (0:00:02.293)       0:00:50.744 ********
#
# TASK [kubernetes/preinstall : Mask swap.target (persist swapoff)] **************
# ok: [worker-1] => {"changed": false, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Fri 2025-04-18 13:40:29 UTC", "ActiveEnterTimestampMonotonic": "3733264", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-18 13:40:29 UTC", "AssertTimestampMonotonic": "3733262", "Before": "sysinit.target run-user-1000.mount", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "no", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-18 13:40:29 UTC", "ConditionTimestampMonotonic": "3733261", "DefaultDependencies": "yes", "Description": "swap.target", "FailureAction": "none", "FragmentPath": "/etc/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Fri 2025-04-18 13:40:29 UTC", "InactiveExitTimestampMonotonic": "3733264", "InvocationID": "c67c068eb2f341dfad1cef360a2af58f", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadError": "org.freedesktop.systemd1.UnitMasked \"Unit swap.target is masked.\"", "LoadState": "masked", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Fri 2025-04-18 13:40:29 UTC", "StateChangeTimestampMonotonic": "3733264", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "masked", "WantedBy": "sysinit.target"}}
# ok: [control] => {"changed": false, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Fri 2025-04-18 13:40:34 UTC", "ActiveEnterTimestampMonotonic": "4451133", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-18 13:40:34 UTC", "AssertTimestampMonotonic": "4451131", "Before": "run-user-1000.mount sysinit.target", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "no", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-18 13:40:34 UTC", "ConditionTimestampMonotonic": "4451130", "DefaultDependencies": "yes", "Description": "swap.target", "FailureAction": "none", "FragmentPath": "/etc/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Fri 2025-04-18 13:40:34 UTC", "InactiveExitTimestampMonotonic": "4451133", "InvocationID": "fe9b43dc97bf4949ba6c3e5ec421713d", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadError": "org.freedesktop.systemd1.UnitMasked \"Unit swap.target is masked.\"", "LoadState": "masked", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Fri 2025-04-18 13:40:34 UTC", "StateChangeTimestampMonotonic": "4451133", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "masked", "WantedBy": "sysinit.target"}}
# ok: [dynamos] => {"changed": false, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Fri 2025-04-18 13:40:32 UTC", "ActiveEnterTimestampMonotonic": "4304016", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-18 13:40:32 UTC", "AssertTimestampMonotonic": "4304014", "Before": "sysinit.target run-user-1000.mount", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "no", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-18 13:40:32 UTC", "ConditionTimestampMonotonic": "4304013", "DefaultDependencies": "yes", "Description": "swap.target", "FailureAction": "none", "FragmentPath": "/etc/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Fri 2025-04-18 13:40:32 UTC", "InactiveExitTimestampMonotonic": "4304016", "InvocationID": "291d2e2c100041b5935eac37f035d2bb", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadError": "org.freedesktop.systemd1.UnitMasked \"Unit swap.target is masked.\"", "LoadState": "masked", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Fri 2025-04-18 13:40:32 UTC", "StateChangeTimestampMonotonic": "4304016", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "masked", "WantedBy": "sysinit.target"}}
# ok: [worker-3] => {"changed": false, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Fri 2025-04-18 13:41:58 UTC", "ActiveEnterTimestampMonotonic": "3563508", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-18 13:41:58 UTC", "AssertTimestampMonotonic": "3563506", "Before": "run-user-1000.mount sysinit.target", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "no", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-18 13:41:58 UTC", "ConditionTimestampMonotonic": "3563505", "DefaultDependencies": "yes", "Description": "swap.target", "FailureAction": "none", "FragmentPath": "/etc/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Fri 2025-04-18 13:41:58 UTC", "InactiveExitTimestampMonotonic": "3563508", "InvocationID": "b0186ab7f36b48828c5f9abb99e9759f", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadError": "org.freedesktop.systemd1.UnitMasked \"Unit swap.target is masked.\"", "LoadState": "masked", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Fri 2025-04-18 13:41:58 UTC", "StateChangeTimestampMonotonic": "3563508", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "masked", "WantedBy": "sysinit.target"}}
# ok: [worker-2] => {"changed": false, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Fri 2025-04-18 13:40:27 UTC", "ActiveEnterTimestampMonotonic": "4215930", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-18 13:40:27 UTC", "AssertTimestampMonotonic": "4215928", "Before": "sysinit.target run-user-1000.mount", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "no", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-18 13:40:27 UTC", "ConditionTimestampMonotonic": "4215927", "DefaultDependencies": "yes", "Description": "swap.target", "FailureAction": "none", "FragmentPath": "/etc/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Fri 2025-04-18 13:40:27 UTC", "InactiveExitTimestampMonotonic": "4215930", "InvocationID": "d34c1e014d154dbe92639f13ed1c6ddc", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadError": "org.freedesktop.systemd1.UnitMasked \"Unit swap.target is masked.\"", "LoadState": "masked", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Fri 2025-04-18 13:40:27 UTC", "StateChangeTimestampMonotonic": "4215930", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "masked", "WantedBy": "sysinit.target"}}
# Saturday 19 April 2025  19:23:21 +0000 (0:00:01.493)       0:00:52.237 ********
#
# TASK [kubernetes/preinstall : Disable swap] ************************************
# changed: [worker-1] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.003192", "end": "2025-04-19 19:23:22.289106", "msg": "", "rc": 0, "start": "2025-04-19 19:23:22.285914", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [control] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.003045", "end": "2025-04-19 19:23:22.290841", "msg": "", "rc": 0, "start": "2025-04-19 19:23:22.287796", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [dynamos] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.003662", "end": "2025-04-19 19:23:22.290093", "msg": "", "rc": 0, "start": "2025-04-19 19:23:22.286431", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [worker-2] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.003129", "end": "2025-04-19 19:23:22.965152", "msg": "", "rc": 0, "start": "2025-04-19 19:23:22.962023", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [worker-3] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.003996", "end": "2025-04-19 19:23:22.965558", "msg": "", "rc": 0, "start": "2025-04-19 19:23:22.961562", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# Saturday 19 April 2025  19:23:23 +0000 (0:00:01.213)       0:00:53.450 ********
# Saturday 19 April 2025  19:23:23 +0000 (0:00:00.068)       0:00:53.519 ********
#
# TASK [kubernetes/preinstall : Check resolvconf] ********************************
# ok: [dynamos] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002617", "end": "2025-04-19 19:23:23.458194", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-19 19:23:23.455577", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [worker-1] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002788", "end": "2025-04-19 19:23:23.481887", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-19 19:23:23.479099", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [control] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002502", "end": "2025-04-19 19:23:23.586796", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-19 19:23:23.584294", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [worker-2] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002576", "end": "2025-04-19 19:23:24.241193", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-19 19:23:24.238617", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [worker-3] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002532", "end": "2025-04-19 19:23:24.252423", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-19 19:23:24.249891", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# Saturday 19 April 2025  19:23:24 +0000 (0:00:01.215)       0:00:54.735 ********
#
# TASK [kubernetes/preinstall : Check existence of /etc/resolvconf/resolv.conf.d] ***
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [control] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# Saturday 19 April 2025  19:23:25 +0000 (0:00:01.155)       0:00:55.890 ********
#
# TASK [kubernetes/preinstall : Check status of /etc/resolv.conf] ****************
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "stat": {"atime": 1745069938.2388005, "block_size": 4096, "blocks": 0, "ctime": 1733820118.302475, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 1371, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": true, "isreg": false, "issock": false, "isuid": false, "lnk_source": "/run/systemd/resolve/stub-resolv.conf", "lnk_target": "../run/systemd/resolve/stub-resolv.conf", "mode": "0777", "mtime": 1733819929.0216625, "nlink": 1, "path": "/etc/resolv.conf", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 39, "uid": 0, "wgrp": true, "woth": true, "writeable": true, "wusr": true, "xgrp": true, "xoth": true, "xusr": true}}
# ...
# changed: [control] => {"changed": true, "name": "systemd-resolved", "state": "started", "status": {"ActiveEnterTimestamp": "Sat 2025-04-19 19:24:34 UTC", "ActiveEnterTimestampMonotonic": "107044232411", "ActiveExitTimestamp": "Sat 2025-04-19 19:24:34 UTC", "ActiveExitTimestampMonotonic": "107044161337", "ActiveState": "active", "After": "systemd-sysctl.service -.mount systemd-sysusers.service tmp.mount systemd-tmpfiles-setup.service systemd-journald.socket system.slice \"run-credentials-systemd\\\\x2dresolved.service.mount\"", "AllowIsolate": "no", "AmbientCapabilities": "cap_setpcap cap_net_bind_service cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Sat 2025-04-19 19:24:34 UTC", "AssertTimestampMonotonic": "107044169693", "Before": "sysinit.target nss-lookup.target network.target initrd-switch-root.target shutdown.target", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BusName": "org.freedesktop.resolve1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "123259000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_setpcap cap_net_bind_service cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Sat 2025-04-19 19:24:34 UTC", "ConditionTimestampMonotonic": "107044169691", "ConfigurationDirectoryMode": "0755", "Conflicts": "initrd-switch-root.target shutdown.target", "ControlGroup": "/system.slice/systemd-resolved.service", "ControlGroupId": "32315", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Name Resolution", "DeviceAllow": "char-rtc r", "DevicePolicy": "closed", "Documentation": "\"man:systemd-resolved.service(8)\" \"man:org.freedesktop.resolve1(5)\" https://www.freedesktop.org/wiki/Software/systemd/writing-network-configuration-managers https://www.freedesktop.org/wiki/Software/systemd/writing-resolver-clients", "DynamicUser": "no", "EffectiveCPUs": "0-1", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "872760", "ExecMainStartTimestamp": "Sat 2025-04-19 19:24:34 UTC", "ExecMainStartTimestampMonotonic": "107044175090", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "0", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-resolved.service", "FreezerState": "running", "GID": "991", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgressPackets": "[no data]", "IPIngressBytes": "[no data]", "IPIngressPackets": "[no data]", "Id": "systemd-resolved.service", "IgnoreOnIsolate": ...
# changed: [worker-2] => {"changed": true, "name": "systemd-resolved", "state": "started", "status": {"ActiveEnterTimestamp": "Sat 2025-04-19 19:24:35 UTC", "ActiveEnterTimestampMonotonic": "107050773757", "ActiveExitTimestamp": "Sat 2025-04-19 19:24:35 UTC", "ActiveExitTimestampMonotonic": "107050704650", "ActiveState": "active", "After": "-.mount tmp.mount systemd-sysctl.service system.slice systemd-journald.socket \"run-credentials-systemd\\\\x2dresolved.service.mount\" systemd-tmpfiles-setup.service systemd-sysusers.service", "AllowIsolate": "no", "AmbientCapabilities": "cap_setpcap cap_net_bind_service cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Sat 2025-04-19 19:24:35 UTC", "AssertTimestampMonotonic": "107050714216", "Before": "sysinit.target shutdown.target initrd-switch-root.target network.target nss-lookup.target", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BusName": "org.freedesktop.resolve1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "143860000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_setpcap cap_net_bind_service cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Sat 2025-04-19 19:24:35 UTC", "ConditionTimestampMonotonic": "107050714214", "ConfigurationDirectoryMode": "0755", "Conflicts": "shutdown.target initrd-switch-root.target", "ControlGroup": "/system.slice/systemd-resolved.service", "ControlGroupId": "56574", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Name Resolution", "DeviceAllow": "char-rtc r", "DevicePolicy": "closed", "Documentation": "\"man:systemd-resolved.service(8)\" \"man:org.freedesktop.resolve1(5)\" https://www.freedesktop.org/wiki/Software/systemd/writing-network-configuration-managers https://www.freedesktop.org/wiki/Software/systemd/writing-resolver-clients", "DynamicUser": "no", "EffectiveCPUs": "0-3", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "455526", "ExecMainStartTimestamp": "Sat 2025-04-19 19:24:35 UTC", "ExecMainStartTimestampMonotonic": "107050723135", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "0", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-resolved.service", "FreezerState": "running", "GID": "991", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgressPackets": "[no data]", "IPIngressBytes": "[no data]", "IPIngressPackets": "[no data]", "Id": "systemd-resolved.service", "IgnoreOnIsolate" ...
# changed: [worker-3] => {"changed": true, "name": "systemd-resolved", "state": "started", "status": {"ActiveEnterTimestamp": "Sat 2025-04-19 19:24:35 UTC", "ActiveEnterTimestampMonotonic": "106959449062", "ActiveExitTimestamp": "Sat 2025-04-19 19:24:35 UTC", "ActiveExitTimestampMonotonic": "106959371991", "ActiveState": "active", "After": "systemd-journald.socket tmp.mount systemd-tmpfiles-setup.service \"run-credentials-systemd\\\\x2dresolved.service.mount\" system.slice systemd-sysctl.service -.mount systemd-sysusers.service", "AllowIsolate": "no", "AmbientCapabilities": "cap_setpcap cap_net_bind_service cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Sat 2025-04-19 19:24:35 UTC", "AssertTimestampMonotonic": "106959386791", "Before": "network.target nss-lookup.target initrd-switch-root.target shutdown.target sysinit.target", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BusName": "org.freedesktop.resolve1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "132089000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_setpcap cap_net_bind_service cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Sat 2025-04-19 19:24:35 UTC", "ConditionTimestampMonotonic": "106959386790", "ConfigurationDirectoryMode": "0755", "Conflicts": "shutdown.target initrd-switch-root.target", "ControlGroup": "/system.slice/systemd-resolved.service", "ControlGroupId": "30535", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Name Resolution", "DeviceAllow": "char-rtc r", "DevicePolicy": "closed", "Documentation": "\"man:systemd-resolved.service(8)\" \"man:org.freedesktop.resolve1(5)\" https://www.freedesktop.org/wiki/Software/systemd/writing-network-configuration-managers https://www.freedesktop.org/wiki/Software/systemd/writing-resolver-clients", "DynamicUser": "no", "EffectiveCPUs": "0-7", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "858912", "ExecMainStartTimestamp": "Sat 2025-04-19 19:24:35 UTC", "ExecMainStartTimestampMonotonic": "106959397061", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "0", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-resolved.service", "FreezerState": "running", "GID": "991", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgressPackets": "[no data]", "IPIngressBytes": "[no data]", "IPIngressPackets": "[no data]", "Id": "systemd-resolved.service", "IgnoreOnIsolate" ...
# Saturday 19 April 2025  19:35:55 +0000 (0:00:01.755)       0:13:25.355 ********
# Saturday 19 April 2025  19:35:55 +0000 (0:00:00.090)       0:13:25.445 ********
#
# PLAY RECAP *********************************************************************
# control                    : ok=558  changed=94   unreachable=0    failed=0    skipped=940  rescued=0    ignored=3
# dynamos                    : ok=467  changed=66   unreachable=0    failed=0    skipped=699  rescued=0    ignored=1
# worker-1                   : ok=443  changed=62   unreachable=0    failed=0    skipped=634  rescued=0    ignored=1
# worker-2                   : ok=443  changed=62   unreachable=0    failed=0    skipped=634  rescued=0    ignored=1
# worker-3                   : ok=443  changed=62   unreachable=0    failed=0    skipped=634  rescued=0    ignored=1
#
# Saturday 19 April 2025  19:35:55 +0000 (0:00:00.119)       0:13:25.565 ********
# ===============================================================================
# download : Download_container | Download image if required ------------- 32.39s
# download : Download_container | Download image if required ------------- 28.89s
# kubernetes/kubeadm : Join to cluster if needed ------------------------- 13.42s
# container-engine/crictl : Extract_file | Unpacking archive -------------- 8.94s
# container-engine/nerdctl : Extract_file | Unpacking archive ------------- 8.80s
# container-engine/containerd : Download_file | Download item ------------- 8.49s
# container-engine/runc : Download_file | Download item ------------------- 8.39s
# container-engine/crictl : Download_file | Download item ----------------- 8.35s
# etcd : Restart etcd ----------------------------------------------------- 8.35s
# container-engine/nerdctl : Download_file | Download item ---------------- 8.35s
# container-engine/containerd : Containerd | Unpack containerd archive ---- 7.70s
# bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora) --- 7.26s
# kubernetes/kubeadm : Create kubeadm client config ----------------------- 7.09s
# kubernetes/preinstall : Write Kubespray DNS settings to systemd-resolved --- 6.95s
# bootstrap-os : Ensure iproute2 is installed ----------------------------- 6.75s
# kubernetes/control-plane : Kubeadm | Initialize first control plane node --- 6.68s
# kubernetes/node : Write kubelet systemd init file ----------------------- 6.61s
# kubernetes/preinstall : Write Kubespray DNS settings to systemd-resolved --- 6.57s
# container-engine/nerdctl : Nerdctl | Install nerdctl configuration ------ 6.57s
# kubernetes/preinstall : Ensure kubelet expected parameters are set ------ 6.56s

# %%
nodes[0].upload_file(local_file_path="node_scripts/reset_kubespray.sh", remote_file_path="reset.sh");
nodes[0].execute(f"chmod +x reset.sh && ./reset.sh");
# Out:
# Using /home/ubuntu/kubespray/ansible.cfg as config file
#
# PLAY [Check Ansible version] ***************************************************
# Saturday 19 April 2025  19:17:17 +0000 (0:00:00.020)       0:00:00.020 ********
#  [WARNING]: While constructing a mapping from
# /home/ubuntu/kubespray/roles/bootstrap-os/tasks/main.yml, line 29, column 7,
# found a duplicate dict key (paths). Using last defined value only.
# [WARNING]: Skipping callback plugin 'ara_default', unable to load
#
# TASK [Check 2.16.4 <= Ansible version < 2.17.0] ********************************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 19 April 2025  19:17:17 +0000 (0:00:00.018)       0:00:00.039 ********
#
# TASK [Check that python netaddr is installed] **********************************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 19 April 2025  19:17:17 +0000 (0:00:00.069)       0:00:00.108 ********
#
# TASK [Check that jinja is not too old (install via pip)] ***********************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
#
# PLAY [Define groups for legacy less structured inventories] ********************
# Saturday 19 April 2025  19:17:17 +0000 (0:00:00.015)       0:00:00.124 ********
#  [WARNING]: Could not match supplied host pattern, ignoring: bastion
#   [WARNING]: Could not match supplied host pattern, ignoring: calico_rr
#
# TASK [Match needed groups by their old names or definition] ********************
# changed: [dynamos] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [dynamos] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-2] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-2] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-1] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-1] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-3] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-3] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [control] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [control] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
#
# PLAY [Install bastion ssh config] **********************************************
# skipping: no hosts matched
#
# PLAY [Bootstrap hosts for Ansible] *********************************************
# Saturday 19 April 2025  19:17:17 +0000 (0:00:00.127)       0:00:00.252 ********
#  [WARNING]: raw module does not support the environment keyword
#
# TASK [bootstrap-os : Fetch /etc/os-release] ************************************
# ok: [control] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.2' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.2' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-1] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.4' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.4' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.4 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [dynamos] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.3' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.3' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.3 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-2] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.137.8.2' (ED25519) to the list of known hosts.\r
# Shared connection to 10.137.8.2 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.137.8.2' (ED25519) to the list of known hosts.", "Shared connection to 10.137.8.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-3] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.146.8.2' (ED25519) to the list of known hosts.\r
# Shared connection to 10.146.8.2 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.146.8.2' (ED25519) to the list of known hosts.", "Shared connection to 10.146.8.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# Saturday 19 April 2025  19:17:20 +0000 (0:00:03.326)       0:00:03.579 ********
# Saturday 19 April 2025  19:17:20 +0000 (0:00:00.123)       0:00:03.702 ********
#
# TASK [bootstrap-os : Include tasks] ********************************************
# included: /home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml for worker-2, worker-3, dynamos, worker-1, control => (item=/home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml)
# Saturday 19 April 2025  19:17:20 +0000 (0:00:00.134)       0:00:03.837 ********
#
# TASK [bootstrap-os : Check if bootstrap is needed] *****************************
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [control] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.137.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.137.8.2 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.146.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.146.8.2 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# Saturday 19 April 2025  19:17:21 +0000 (0:00:00.602)       0:00:04.440 ********
#
# TASK [bootstrap-os : Check http::proxy in apt configuration files] *************
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [control] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.137.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.137.8.2 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.146.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.146.8.2 closed."], "stdout": "", "stdout_lines": []}
# Saturday 19 April 2025  19:17:22 +0000 (0:00:00.612)       0:00:05.053 ********
# Saturday 19 April 2025  19:17:22 +0000 (0:00:00.048)       0:00:05.101 ********
#
# TASK [bootstrap-os : Check https::proxy in apt configuration files] ************
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [control] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.137.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.137.8.2 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.146.8.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.146.8.2 closed."], "stdout": "", "stdout_lines": []}
# Saturday 19 April 2025  19:17:22 +0000 (0:00:00.620)       0:00:05.721 ********
# Saturday 19 April 2025  19:17:22 +0000 (0:00:00.047)       0:00:05.769 ********
# Saturday 19 April 2025  19:17:22 +0000 (0:00:00.039)       0:00:05.809 ********
# Saturday 19 April 2025  19:17:22 +0000 (0:00:00.091)       0:00:05.901 ********
#
# TASK [bootstrap-os : Ensure iproute2 is installed] *****************************
# ok: [worker-1] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1745037974, "cache_updated": false, "changed": false}
# ok: [control] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1745081234, "cache_updated": false, "changed": false}
# ok: [dynamos] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1745040571, "cache_updated": false, "changed": false}
# ok: [worker-2] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1745075687, "cache_updated": false, "changed": false}
# ok: [worker-3] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1745043287, "cache_updated": false, "changed": false}
# Saturday 19 April 2025  19:17:35 +0000 (0:00:12.453)       0:00:18.354 ********
# Saturday 19 April 2025  19:17:35 +0000 (0:00:00.037)       0:00:18.391 ********
# Saturday 19 April 2025  19:17:35 +0000 (0:00:00.037)       0:00:18.428 ********
#
# TASK [bootstrap-os : Create remote_tmp for it is used by another module] *******
# ok: [worker-1] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [control] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [dynamos] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-2] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-3] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# Saturday 19 April 2025  19:17:40 +0000 (0:00:05.327)       0:00:23.756 ********
#
# TASK [bootstrap-os : Gather facts] *********************************************
# ok: [dynamos]
# ok: [worker-1]
# ok: [control]
# ok: [worker-2]
# ok: [worker-3]
# Saturday 19 April 2025  19:17:46 +0000 (0:00:05.711)       0:00:29.467 ********
#
# TASK [bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora)] ***
# ok: [worker-1] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "worker-1.cluster.local", "ansible_hostname": "worker-1", "ansible_nodename": "worker-1"}, "changed": false, "name": "worker-1"}
# ok: [dynamos] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "dynamos.cluster.local", "ansible_hostname": "dynamos", "ansible_nodename": "dynamos"}, "changed": false, "name": "dynamos"}
# ok: [control] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "control.cluster.local", "ansible_hostname": "control", "ansible_nodename": "control"}, "changed": false, "name": "control"}
# ok: [worker-2] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "worker-2.cluster.local", "ansible_hostname": "worker-2", "ansible_nodename": "worker-2"}, "changed": false, "name": "worker-2"}
# ok: [worker-3] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "worker-3.cluster.local", "ansible_hostname": "worker-3", "ansible_nodename": "worker-3"}, "changed": false, "name": "worker-3"}
# Saturday 19 April 2025  19:17:52 +0000 (0:00:05.826)       0:00:35.294 ********
# Saturday 19 April 2025  19:17:52 +0000 (0:00:00.077)       0:00:35.372 ********
#
# TASK [bootstrap-os : Ensure bash_completion.d folder exists] *******************
# ok: [dynamos] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-1] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [control] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-2] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-3] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# Saturday 19 April 2025  19:17:57 +0000 (0:00:05.363)       0:00:40.735 ********
#
# TASK [kubespray-defaults : Gather ansible_default_ipv4] ************************
# ok: [worker-1]
# ok: [dynamos]
# ok: [control]
# ok: [worker-2]
# ok: [worker-3]
# Saturday 19 April 2025  19:18:03 +0000 (0:00:05.864)       0:00:46.600 ********
#
# TASK [kubespray-defaults : Set fallback_ip] ************************************
# ok: [dynamos] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-2] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-1] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-3] => {"ansible_facts": {"fallback_ip": "10.20.5.75"}, "changed": false}
# ok: [control] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# Saturday 19 April 2025  19:18:03 +0000 (0:00:00.090)       0:00:46.690 ********
# Saturday 19 April 2025  19:18:03 +0000 (0:00:00.017)       0:00:46.707 ********
# Saturday 19 April 2025  19:18:03 +0000 (0:00:00.051)       0:00:46.759 ********
#
# PLAY [Gather facts] ************************************************************
# Saturday 19 April 2025  19:18:03 +0000 (0:00:00.060)       0:00:46.819 ********
#
# TASK [Gather minimal facts] ****************************************************
# ok: [dynamos]
# ok: [worker-1]
# ok: [control]
# ok: [worker-3]
# ok: [worker-2]
# Saturday 19 April 2025  19:18:05 +0000 (0:00:01.353)       0:00:48.172 ********
#
# TASK [Gather necessary facts (network)] ****************************************
# ok: [dynamos]
# ok: [worker-1]
# ok: [control]
# ok: [worker-2]
# ok: [worker-3]
# Saturday 19 April 2025  19:18:06 +0000 (0:00:01.425)       0:00:49.598 ********
#
# TASK [Gather necessary facts (hardware)] ***************************************
# ok: [dynamos]
# ok: [worker-1]
# ok: [control]
# ok: [worker-2]
# ok: [worker-3]
#
# PLAY [Reset cluster] ***********************************************************
# Saturday 19 April 2025  19:18:08 +0000 (0:00:01.720)       0:00:51.318 ********
# Saturday 19 April 2025  19:18:08 +0000 (0:00:00.026)       0:00:51.344 ********
# Saturday 19 April 2025  19:18:08 +0000 (0:00:00.062)       0:00:51.406 ********
#
# TASK [Gather information about installed services] *****************************
# ok: [worker-1] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Mo ...
# ok: [control] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Mod ...
# ok: [dynamos] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Mod ...
# ok: [worker-2] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Mo ...
# ok: [worker-3] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Mo ...
# Saturday 19 April 2025  19:18:11 +0000 (0:00:03.180)       0:00:54.587 ********
# Saturday 19 April 2025  19:18:11 +0000 (0:00:00.080)       0:00:54.668 ********
# Saturday 19 April 2025  19:18:11 +0000 (0:00:00.077)       0:00:54.745 ********
# Saturday 19 April 2025  19:18:11 +0000 (0:00:00.019)       0:00:54.765 ********
# Saturday 19 April 2025  19:18:11 +0000 (0:00:00.063)       0:00:54.828 ********
# Saturday 19 April 2025  19:18:11 +0000 (0:00:00.110)       0:00:54.938 ********
#
# TASK [adduser : User | Create User Group] **************************************
# ok: [worker-1] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [control] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [dynamos] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [worker-2] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [worker-3] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# Saturday 19 April 2025  19:18:13 +0000 (0:00:01.822)       0:00:56.761 ********
#
# TASK [adduser : User | Create User] ********************************************
# ...
# changed: [dynamos] => (item=systemd-networkd) => {"ansible_loop_var": "item", "changed": true, "item": "systemd-networkd", "name": "systemd-networkd", "state": "started", "status": {"ActiveEnterTimestamp": "Fri 2025-04-18 14:09:56 UTC", "ActiveEnterTimestampMonotonic": "1767638898", "ActiveExitTimestamp": "Fri 2025-04-18 14:09:56 UTC", "ActiveExitTimestampMonotonic": "1767585256", "ActiveState": "active", "After": "systemd-journald.socket network-pre.target system.slice systemd-udevd.service systemd-sysusers.service systemd-sysctl.service -.mount systemd-networkd.socket", "AllowIsolate": "no", "AmbientCapabilities": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-18 14:09:56 UTC", "AssertTimestampMonotonic": "1767608678", "Before": "update-notifier-motd.timer multi-user.target systemd-networkd-wait-online.service ubuntu-advantage.service apt-daily.service initrd-switch-root.target network.target update-notifier-download.timer apt-daily-upgrade.service shutdown.target ua-timer.service", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BoundBy": "systemd-networkd-wait-online.service", "BusName": "org.freedesktop.network1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "640442000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime fdstore", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "yes", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-18 14:09:56 UTC", "ConditionTimestampMonotonic": "1767608635", "ConfigurationDirectoryMode": "0755", "Conflicts": "initrd-switch-root.target shutdown.target", "ControlGroup": "/system.slice/systemd-networkd.service", "ControlGroupId": "8208", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Configuration", "DeviceAllow": "char-* rw", "DevicePolicy": "auto", "Documentation": "\"man:systemd-networkd.service(8)\" \"man:org.freedesktop.network1(5)\"", "DynamicUser": "no", "EffectiveCPUs": "0-3", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "7594", "ExecMainStartTimestamp": "Fri 2025-04-18 14:09:56 UTC", "ExecMainStartTimestampMonotonic": "1767609940", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "512", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-networkd.service", "FreezerState": "running", "GID": "998", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgressPac ...
# changed: [worker-2] => (item=systemd-networkd) => {"ansible_loop_var": "item", "changed": true, "item": "systemd-networkd", "name": "systemd-networkd", "state": "started", "status": {"ActiveEnterTimestamp": "Fri 2025-04-18 14:12:58 UTC", "ActiveEnterTimestampMonotonic": "1953841943", "ActiveExitTimestamp": "Fri 2025-04-18 14:12:58 UTC", "ActiveExitTimestampMonotonic": "1953781552", "ActiveState": "active", "After": "network-pre.target systemd-networkd.socket systemd-udevd.service -.mount systemd-sysctl.service systemd-journald.socket systemd-sysusers.service system.slice", "AllowIsolate": "no", "AmbientCapabilities": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-18 14:12:58 UTC", "AssertTimestampMonotonic": "1953810315", "Before": "ua-timer.service apt-daily-upgrade.service network.target systemd-networkd-wait-online.service ubuntu-advantage.service apt-daily.service update-notifier-download.timer update-notifier-motd.timer multi-user.target shutdown.target initrd-switch-root.target", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BoundBy": "systemd-networkd-wait-online.service", "BusName": "org.freedesktop.network1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "724594000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime fdstore", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "yes", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-18 14:12:58 UTC", "ConditionTimestampMonotonic": "1953810259", "ConfigurationDirectoryMode": "0755", "Conflicts": "initrd-switch-root.target shutdown.target", "ControlGroup": "/system.slice/systemd-networkd.service", "ControlGroupId": "7809", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Configuration", "DeviceAllow": "char-* rw", "DevicePolicy": "auto", "Documentation": "\"man:systemd-networkd.service(8)\" \"man:org.freedesktop.network1(5)\"", "DynamicUser": "no", "EffectiveCPUs": "0-3", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "7574", "ExecMainStartTimestamp": "Fri 2025-04-18 14:12:58 UTC", "ExecMainStartTimestampMonotonic": "1953816080", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "512", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-networkd.service", "FreezerState": "running", "GID": "998", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgressPa ...
# changed: [worker-3] => (item=systemd-networkd) => {"ansible_loop_var": "item", "changed": true, "item": "systemd-networkd", "name": "systemd-networkd", "state": "started", "status": {"ActiveEnterTimestamp": "Fri 2025-04-18 14:12:22 UTC", "ActiveEnterTimestampMonotonic": "1826561114", "ActiveExitTimestamp": "Fri 2025-04-18 14:12:22 UTC", "ActiveExitTimestampMonotonic": "1826500631", "ActiveState": "active", "After": "systemd-sysctl.service system.slice systemd-journald.socket network-pre.target -.mount systemd-networkd.socket systemd-udevd.service systemd-sysusers.service", "AllowIsolate": "no", "AmbientCapabilities": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-18 14:12:22 UTC", "AssertTimestampMonotonic": "1826519500", "Before": "network.target apt-daily-upgrade.service ubuntu-advantage.service multi-user.target update-notifier-download.timer apt-daily.service systemd-networkd-wait-online.service update-notifier-motd.timer initrd-switch-root.target ua-timer.service shutdown.target", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BoundBy": "systemd-networkd-wait-online.service", "BusName": "org.freedesktop.network1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "163808000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime fdstore", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "yes", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-18 14:12:22 UTC", "ConditionTimestampMonotonic": "1826519430", "ConfigurationDirectoryMode": "0755", "Conflicts": "shutdown.target initrd-switch-root.target", "ControlGroup": "/system.slice/systemd-networkd.service", "ControlGroupId": "8789", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Configuration", "DeviceAllow": "char-* rw", "DevicePolicy": "auto", "Documentation": "\"man:systemd-networkd.service(8)\" \"man:org.freedesktop.network1(5)\"", "DynamicUser": "no", "EffectiveCPUs": "0-7", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "7811", "ExecMainStartTimestamp": "Fri 2025-04-18 14:12:22 UTC", "ExecMainStartTimestampMonotonic": "1826533163", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "512", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-networkd.service", "FreezerState": "running", "GID": "998", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgressPa ...
#
# PLAY RECAP *********************************************************************
# control                    : ok=123  changed=28   unreachable=0    failed=0    skipped=90   rescued=0    ignored=0
# dynamos                    : ok=108  changed=27   unreachable=0    failed=0    skipped=90   rescued=0    ignored=0
# worker-1                   : ok=105  changed=27   unreachable=0    failed=0    skipped=89   rescued=0    ignored=0
# worker-2                   : ok=104  changed=26   unreachable=0    failed=0    skipped=90   rescued=0    ignored=0
# worker-3                   : ok=106  changed=28   unreachable=0    failed=0    skipped=88   rescued=0    ignored=0
#
# Saturday 19 April 2025  19:22:11 +0000 (0:00:01.879)       0:04:54.104 ********
# ===============================================================================
# reset : Reset | delete some files and directories ---------------------- 77.43s
# reset : Reset | stop services ------------------------------------------ 17.14s
# bootstrap-os : Ensure iproute2 is installed ---------------------------- 12.45s
# reset : Reset | remove services ---------------------------------------- 10.01s
# reset : Reset | remove containerd binary files -------------------------- 9.16s
# kubernetes/preinstall : Write Kubespray DNS settings to systemd-resolved --- 6.63s
# network_plugin/cni : CNI | Copy cni plugins ----------------------------- 6.15s
# reset : Gather active network services ---------------------------------- 6.11s
# kubespray-defaults : Gather ansible_default_ipv4 ------------------------ 5.86s
# bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora) --- 5.83s
# bootstrap-os : Gather facts --------------------------------------------- 5.71s
# kubernetes/preinstall : Ensure kubelet expected parameters are set ------ 5.59s
# bootstrap-os : Ensure bash_completion.d folder exists ------------------- 5.36s
# bootstrap-os : Create remote_tmp for it is used by another module ------- 5.33s
# kubernetes/preinstall : Create kubernetes directories ------------------- 4.52s
# kubernetes/preinstall : Update package management cache (APT) ----------- 4.16s
# reset : Flush iptables -------------------------------------------------- 3.81s
# reset : Reset | unmount kubelet dirs ------------------------------------ 3.75s
# bootstrap-os : Fetch /etc/os-release ------------------------------------ 3.33s
# Gather information about installed services ----------------------------- 3.18s
