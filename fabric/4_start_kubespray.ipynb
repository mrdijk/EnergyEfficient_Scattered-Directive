# %%
import datetime
import json
import asyncio

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()

fablib.show_config();
# Out:
# <style type="text/css">
# #T_fe069 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_fe069 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_fe069 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_fe069_row0_col0, #T_fe069_row0_col1, #T_fe069_row1_col0, #T_fe069_row1_col1, #T_fe069_row2_col0, #T_fe069_row2_col1, #T_fe069_row3_col0, #T_fe069_row3_col1, #T_fe069_row4_col0, #T_fe069_row4_col1, #T_fe069_row5_col0, #T_fe069_row5_col1, #T_fe069_row6_col0, #T_fe069_row6_col1, #T_fe069_row7_col0, #T_fe069_row7_col1, #T_fe069_row8_col0, #T_fe069_row8_col1, #T_fe069_row9_col0, #T_fe069_row9_col1, #T_fe069_row10_col0, #T_fe069_row10_col1, #T_fe069_row11_col0, #T_fe069_row11_col1, #T_fe069_row12_col0, #T_fe069_row12_col1, #T_fe069_row13_col0, #T_fe069_row13_col1, #T_fe069_row14_col0, #T_fe069_row14_col1, #T_fe069_row15_col0, #T_fe069_row15_col1, #T_fe069_row16_col0, #T_fe069_row16_col1, #T_fe069_row17_col0, #T_fe069_row17_col1, #T_fe069_row18_col0, #T_fe069_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_fe069">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fe069_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_fe069_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_fe069_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_fe069_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_fe069_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_fe069_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_fe069_row5_col1" class="data row5 col1" >49f65ad7-d8a2-4ab9-8ca0-ba777a2e0ea2</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_fe069_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_fe069_row7_col1" class="data row7 col1" >jakejongejans_0000313927</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_fe069_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_fe069_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_fe069_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_fe069_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_fe069_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_fe069_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_fe069_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_fe069_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row16_col0" class="data row16 col0" >Version</td>
#       <td id="T_fe069_row16_col1" class="data row16 col1" >1.8.0</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row17_col0" class="data row17 col0" >Data directory</td>
#       <td id="T_fe069_row17_col1" class="data row17 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_fe069_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_fe069_row18_col1" class="data row18 col1" >DYNAMOS project</td>
#     </tr>
#   </tbody>
# </table>

# %%
slice = fablib.get_slice(name="DYNAMOS-on-FABRIC");
nodes = slice.get_nodes();

# %%
nodes[0].upload_file(local_file_path="node_scripts/start_kubespray.sh", remote_file_path="start.sh");
nodes[0].execute(f"chmod +x start.sh && ./start.sh");
# Out:
# Using /home/ubuntu/kubespray/ansible.cfg as config file
#
# PLAY [Check Ansible version] ***************************************************
# Friday 11 April 2025  11:59:06 +0000 (0:00:00.008)       0:00:00.008 **********
#  [WARNING]: While constructing a mapping from
# /home/ubuntu/kubespray/roles/bootstrap-os/tasks/main.yml, line 29, column 7,
# found a duplicate dict key (paths). Using last defined value only.
# [WARNING]: Skipping callback plugin 'ara_default', unable to load
#
# TASK [Check 2.16.4 <= Ansible version < 2.17.0] ********************************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:06 +0000 (0:00:00.018)       0:00:00.026 **********
#
# TASK [Check that python netaddr is installed] **********************************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:06 +0000 (0:00:00.047)       0:00:00.073 **********
#
# TASK [Check that jinja is not too old (install via pip)] ***********************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
#
# PLAY [Define groups for legacy less structured inventories] ********************
# Friday 11 April 2025  11:59:06 +0000 (0:00:00.014)       0:00:00.088 **********
#  [WARNING]: Could not match supplied host pattern, ignoring: bastion
#   [WARNING]: Could not match supplied host pattern, ignoring: calico_rr
#
# TASK [Match needed groups by their old names or definition] ********************
# changed: [node2] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node2] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [node3] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node3] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [node1] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node1] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
#
# PLAY [Install bastion ssh config] **********************************************
# skipping: no hosts matched
#
# PLAY [Bootstrap hosts for Ansible] *********************************************
# Friday 11 April 2025  11:59:06 +0000 (0:00:00.082)       0:00:00.171 **********
#  [WARNING]: raw module does not support the environment keyword
#
# TASK [bootstrap-os : Fetch /etc/os-release] ************************************
# ok: [node1] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.5.2' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.5.2 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.5.2' (ED25519) to the list of known hosts.", "Shared connection to 10.145.5.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [node2] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.5.3' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.5.3 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.5.3' (ED25519) to the list of known hosts.", "Shared connection to 10.145.5.3 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [node3] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.5.4' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.5.4 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.5.4' (ED25519) to the list of known hosts.", "Shared connection to 10.145.5.4 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# Friday 11 April 2025  11:59:07 +0000 (0:00:00.801)       0:00:00.973 **********
# Friday 11 April 2025  11:59:07 +0000 (0:00:00.066)       0:00:01.040 **********
#
# TASK [bootstrap-os : Include tasks] ********************************************
# included: /home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml for node2, node3, node1 => (item=/home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml)
# Friday 11 April 2025  11:59:07 +0000 (0:00:00.082)       0:00:01.122 **********
#
# TASK [bootstrap-os : Check if bootstrap is needed] *****************************
# ok: [node2] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.5.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.5.3 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [node3] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.5.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.5.4 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [node1] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.5.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.5.2 closed."], "stdout": "\r
# /usr/bin/python3\r
# ", "stdout_lines": ["", "/usr/bin/python3"]}
# Friday 11 April 2025  11:59:07 +0000 (0:00:00.173)       0:00:01.296 **********
#
# TASK [bootstrap-os : Check http::proxy in apt configuration files] *************
# ok: [node2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.5.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.5.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [node3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.5.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.5.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [node1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.5.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.5.2 closed."], "stdout": "", "stdout_lines": []}
# Friday 11 April 2025  11:59:07 +0000 (0:00:00.183)       0:00:01.480 **********
# Friday 11 April 2025  11:59:07 +0000 (0:00:00.032)       0:00:01.512 **********
#
# TASK [bootstrap-os : Check https::proxy in apt configuration files] ************
# ok: [node2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.5.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.5.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [node3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.5.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.5.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [node1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.5.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.5.2 closed."], "stdout": "", "stdout_lines": []}
# Friday 11 April 2025  11:59:07 +0000 (0:00:00.180)       0:00:01.692 **********
# Friday 11 April 2025  11:59:07 +0000 (0:00:00.032)       0:00:01.725 **********
# Friday 11 April 2025  11:59:07 +0000 (0:00:00.025)       0:00:01.751 **********
# Friday 11 April 2025  11:59:07 +0000 (0:00:00.055)       0:00:01.806 **********
#
# TASK [bootstrap-os : Ensure iproute2 is installed] *****************************
# ok: [node2] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744372401, "cache_updated": false, "changed": false}
# ok: [node3] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744372502, "cache_updated": false, "changed": false}
# ok: [node1] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744372300, "cache_updated": false, "changed": false}
# Friday 11 April 2025  11:59:09 +0000 (0:00:01.878)       0:00:03.685 **********
# Friday 11 April 2025  11:59:09 +0000 (0:00:00.025)       0:00:03.710 **********
# Friday 11 April 2025  11:59:09 +0000 (0:00:00.025)       0:00:03.736 **********
#
# TASK [bootstrap-os : Create remote_tmp for it is used by another module] *******
# changed: [node3] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# changed: [node2] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# changed: [node1] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# Friday 11 April 2025  11:59:10 +0000 (0:00:00.476)       0:00:04.212 **********
#
# TASK [bootstrap-os : Gather facts] *********************************************
# ok: [node3]
# ok: [node2]
# ok: [node1]
# Friday 11 April 2025  11:59:11 +0000 (0:00:00.726)       0:00:04.939 **********
#
# TASK [bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora)] ***
# changed: [node1] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "node1", "ansible_hostname": "node1", "ansible_nodename": "node1"}, "changed": true, "name": "node1"}
# changed: [node3] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "node3", "ansible_hostname": "node3", "ansible_nodename": "node3"}, "changed": true, "name": "node3"}
# changed: [node2] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "node2", "ansible_hostname": "node2", "ansible_nodename": "node2"}, "changed": true, "name": "node2"}
# Friday 11 April 2025  11:59:12 +0000 (0:00:01.159)       0:00:06.099 **********
# Friday 11 April 2025  11:59:12 +0000 (0:00:00.042)       0:00:06.141 **********
#
# TASK [bootstrap-os : Ensure bash_completion.d folder exists] *******************
# ok: [node2] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [node3] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [node1] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# Friday 11 April 2025  11:59:12 +0000 (0:00:00.375)       0:00:06.517 **********
#
# TASK [kubespray-defaults : Gather ansible_default_ipv4] ************************
# ok: [node2]
# ok: [node3]
# ok: [node1]
# Friday 11 April 2025  11:59:13 +0000 (0:00:00.865)       0:00:07.382 **********
#
# TASK [kubespray-defaults : Set fallback_ip] ************************************
# ok: [node2] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [node3] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [node1] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# Friday 11 April 2025  11:59:13 +0000 (0:00:00.129)       0:00:07.512 **********
# Friday 11 April 2025  11:59:13 +0000 (0:00:00.017)       0:00:07.529 **********
# Friday 11 April 2025  11:59:13 +0000 (0:00:00.098)       0:00:07.628 **********
#
# PLAY [Gather facts] ************************************************************
# Friday 11 April 2025  11:59:13 +0000 (0:00:00.041)       0:00:07.669 **********
#
# TASK [Gather minimal facts] ****************************************************
# ok: [node3]
# ok: [node2]
# ok: [node1]
# Friday 11 April 2025  11:59:14 +0000 (0:00:00.629)       0:00:08.299 **********
#
# TASK [Gather necessary facts (network)] ****************************************
# ok: [node3]
# ok: [node2]
# ok: [node1]
# Friday 11 April 2025  11:59:15 +0000 (0:00:00.671)       0:00:08.971 **********
#
# TASK [Gather necessary facts (hardware)] ***************************************
# ok: [node3]
# ok: [node1]
# ok: [node2]
#
# PLAY [Prepare for etcd install] ************************************************
# Friday 11 April 2025  11:59:16 +0000 (0:00:01.047)       0:00:10.018 **********
# Friday 11 April 2025  11:59:16 +0000 (0:00:00.034)       0:00:10.053 **********
# Friday 11 April 2025  11:59:16 +0000 (0:00:00.037)       0:00:10.090 **********
# Friday 11 April 2025  11:59:16 +0000 (0:00:00.020)       0:00:10.111 **********
# Friday 11 April 2025  11:59:16 +0000 (0:00:00.033)       0:00:10.144 **********
# Friday 11 April 2025  11:59:16 +0000 (0:00:00.038)       0:00:10.183 **********
#
# TASK [adduser : User | Create User Group] **************************************
# changed: [node2] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# changed: [node3] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# changed: [node1] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# Friday 11 April 2025  11:59:16 +0000 (0:00:00.420)       0:00:10.604 **********
#
# TASK [adduser : User | Create User] ********************************************
# changed: [node3] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# changed: [node2] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# changed: [node1] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# Friday 11 April 2025  11:59:17 +0000 (0:00:00.457)       0:00:11.061 **********
#
# TASK [kubernetes/preinstall : Check if /etc/fstab exists] **********************
# ok: [node3] => {"changed": false, "stat": {"atime": 1744371814.762, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [node2] => {"changed": false, "stat": {"atime": 1744371812.726, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [node1] => {"changed": false, "stat": {"atime": 1744371810.742, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# Friday 11 April 2025  11:59:17 +0000 (0:00:00.360)       0:00:11.422 **********
#
# TASK [kubernetes/preinstall : Remove swapfile from /etc/fstab] *****************
# ok: [node3] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [node2] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [node1] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [node3] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [node2] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [node1] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# Friday 11 April 2025  11:59:18 +0000 (0:00:00.631)       0:00:12.053 **********
#
# TASK [kubernetes/preinstall : Mask swap.target (persist swapoff)] **************
# changed: [node2] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Fri 2025-04-11 11:45:08 UTC", "ActiveEnterTimestampMonotonic": "3178050", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-11 11:45:08 UTC", "AssertTimestampMonotonic": "3178048", "Before": "sysinit.target shutdown.target run-user-1000.mount", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-11 11:45:08 UTC", "ConditionTimestampMonotonic": "3178047", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Fri 2025-04-11 11:45:08 UTC", "InactiveExitTimestampMonotonic": "3178050", "InvocationID": "e358fe298abf4114b524f3449a955ae6", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Fri 2025-04-11 11:45:08 UTC", "StateChangeTimestampMonotonic": "3178050", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# changed: [node3] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Fri 2025-04-11 11:45:11 UTC", "ActiveEnterTimestampMonotonic": "3760332", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-11 11:45:11 UTC", "AssertTimestampMonotonic": "3760330", "Before": "shutdown.target run-user-1000.mount sysinit.target", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-11 11:45:11 UTC", "ConditionTimestampMonotonic": "3760329", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Fri 2025-04-11 11:45:11 UTC", "InactiveExitTimestampMonotonic": "3760332", "InvocationID": "0d1cf212622c46efa81d4c811b3c3d5c", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Fri 2025-04-11 11:45:11 UTC", "StateChangeTimestampMonotonic": "3760332", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# changed: [node1] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Fri 2025-04-11 11:45:06 UTC", "ActiveEnterTimestampMonotonic": "3292074", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-11 11:45:06 UTC", "AssertTimestampMonotonic": "3292071", "Before": "run-user-1000.mount shutdown.target sysinit.target", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-11 11:45:06 UTC", "ConditionTimestampMonotonic": "3292070", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Fri 2025-04-11 11:45:06 UTC", "InactiveExitTimestampMonotonic": "3292074", "InvocationID": "c07fa47bbf7b47faa85eede2ff6fc4c4", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Fri 2025-04-11 11:45:06 UTC", "StateChangeTimestampMonotonic": "3292074", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# Friday 11 April 2025  11:59:18 +0000 (0:00:00.789)       0:00:12.842 **********
#
# TASK [kubernetes/preinstall : Disable swap] ************************************
# changed: [node2] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.002915", "end": "2025-04-11 11:59:19.280785", "msg": "", "rc": 0, "start": "2025-04-11 11:59:19.277870", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [node3] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.002955", "end": "2025-04-11 11:59:19.281911", "msg": "", "rc": 0, "start": "2025-04-11 11:59:19.278956", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [node1] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.003465", "end": "2025-04-11 11:59:19.288496", "msg": "", "rc": 0, "start": "2025-04-11 11:59:19.285031", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# Friday 11 April 2025  11:59:19 +0000 (0:00:00.376)       0:00:13.219 **********
# Friday 11 April 2025  11:59:19 +0000 (0:00:00.031)       0:00:13.251 **********
#
# TASK [kubernetes/preinstall : Check resolvconf] ********************************
# ok: [node2] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002648", "end": "2025-04-11 11:59:19.616696", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-11 11:59:19.614048", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [node3] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002766", "end": "2025-04-11 11:59:19.624143", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-11 11:59:19.621377", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [node1] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.004904", "end": "2025-04-11 11:59:19.635332", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-11 11:59:19.630428", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# Friday 11 April 2025  11:59:19 +0000 (0:00:00.310)       0:00:13.562 **********
#
# TASK [kubernetes/preinstall : Check existence of /etc/resolvconf/resolv.conf.d] ***
# ok: [node2] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [node3] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [node1] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# Friday 11 April 2025  11:59:19 +0000 (0:00:00.315)       0:00:13.877 **********
#
# TASK [kubernetes/preinstall : Check status of /etc/resolv.conf] ****************
# ok: [node2] => {"changed": false, "failed_when_result": false, "stat": {"atime": 1744371812.635, "block_size": 4096, "blocks": 0, "ctime": 1733820118.302475, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 1371, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": true, "isreg": false, "issock": false, "isuid": false, "lnk_source": "/run/systemd/resolve/stub-resolv.conf", "lnk_target": "../run/systemd/resolve/stub-resolv.conf", "mode": "0777", "mtime": 1733819929.0216625, "nlink": 1, "path": "/etc/resolv.conf", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 39, "uid": 0, "wgrp": true, "woth": true, "writeable": true, "wusr": true, "xgrp": true, "xoth": true, "xusr": true}}
# ok: [node3] => {"changed": false, "failed_when_result": false, "stat": {"atime": 1744371814.664, "block_size": 4096, "blocks": 0, "ctime": 1733820118.302475, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 1371, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": true, "isreg": false, "issock": false, "isuid": false, "lnk_source": "/run/systemd/resolve/stub-resolv.conf", "lnk_target": "../run/systemd/resolve/stub-resolv.conf", "mode": "0777", "mtime": 1733819929.0216625, "nlink": 1, "path": "/etc/resolv.conf", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 39, "uid": 0, "wgrp": true, "woth": true, "writeable": true, "wusr": true, "xgrp": true, "xoth": true, "xusr": true}}
# ok: [node1] => {"changed": false, "failed_when_result": false, "stat": {"atime": 1744371810.649, "block_size": 4096, "blocks": 0, "ctime": 1733820118.302475, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 1371, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": true, "isreg": false, "issock": false, "isuid": false, "lnk_source": "/run/systemd/resolve/stub-resolv.conf", "lnk_target": "../run/systemd/resolve/stub-resolv.conf", "mode": "0777", "mtime": 1733819929.0216625, "nlink": 1, "path": "/etc/resolv.conf", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 39, "uid": 0, "wgrp": true, "woth": true, "writeable": true, "wusr": true, "xgrp": true, "xoth": true, "xusr": true}}
# Friday 11 April 2025  11:59:20 +0000 (0:00:00.307)       0:00:14.185 **********
#
# TASK [kubernetes/preinstall : Fetch resolv.conf] *******************************
# ok: [node3] => {"changed": false, "content": "...", "encoding": "base64", "source": "/etc/resolv.conf"}
# ok: [node1] => {"changed": false, "content": "...", "encoding": "base64", "source": "/etc/resolv.conf"}
# ok: [node2] => {"changed": false, "content": "...", "encoding": "base64", "source": "/etc/resolv.conf"}
# Friday 11 April 2025  11:59:20 +0000 (0:00:00.344)       0:00:14.529 **********
#
# TASK [kubernetes/preinstall : NetworkManager | Check if host has NetworkManager] ***
# ok: [node2] => {"changed": false, "cmd": ["systemctl", "is-active", "--quiet", "NetworkManager.service"], "delta": "0:00:00.005463", "end": "2025-04-11 11:59:20.886911", "failed_when_result": false, "msg": "non-zero return code", "rc": 4, "start": "2025-04-11 11:59:20.881448", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# ok: [node3] => {"changed": false, "cmd": ["systemctl", "is-active", "--quiet", "NetworkManager.service"], "delta": "0:00:00.005540", "end": "2025-04-11 11:59:20.904633", "failed_when_result": false, "msg": "non-zero return code", "rc": 4, "start": "2025-04-11 11:59:20.899093", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# ok: [node1] => {"changed": false, "cmd": ["systemctl", "is-active", "--quiet", "NetworkManager.service"], "delta": "0:00:00.006242", "end": "2025-04-11 11:59:20.914931", "failed_when_result": false, "msg": "non-zero return code", "rc": 4, "start": "2025-04-11 11:59:20.908689", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# Friday 11 April 2025  11:59:20 +0000 (0:00:00.308)       0:00:14.838 **********
#
# TASK [kubernetes/preinstall : Check systemd-resolved] **************************
# ok: [node2] => {"changed": false, "cmd": ["systemctl", "is-active", "systemd-resolved"], "delta": "0:00:00.005581", "end": "2025-04-11 11:59:21.198173", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-11 11:59:21.192592", "stderr": "", "stderr_lines": [], "stdout": "active", "stdout_lines": ["active"]}
# ok: [node3] => {"changed": false, "cmd": ["systemctl", "is-active", "systemd-resolved"], "delta": "0:00:00.005784", "end": "2025-04-11 11:59:21.217143", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-11 11:59:21.211359", "stderr": "", "stderr_lines": [], "stdout": "active", "stdout_lines": ["active"]}
# ok: [node1] => {"changed": false, "cmd": ["systemctl", "is-active", "systemd-resolved"], "delta": "0:00:00.006154", "end": "2025-04-11 11:59:21.223366", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-11 11:59:21.217212", "stderr": "", "stderr_lines": [], "stdout": "active", "stdout_lines": ["active"]}
# Friday 11 April 2025  11:59:21 +0000 (0:00:00.311)       0:00:15.150 **********
#
# TASK [kubernetes/preinstall : Set default dns if remove_default_searchdomains is false] ***
# ok: [node2] => {"ansible_facts": {"default_searchdomains": ["default.svc.cluster.local", "svc.cluster.local"]}, "changed": false}
# ok: [node3] => {"ansible_facts": {"default_searchdomains": ["default.svc.cluster.local", "svc.cluster.local"]}, "changed": false}
# ok: [node1] => {"ansible_facts": {"default_searchdomains": ["default.svc.cluster.local", "svc.cluster.local"]}, "changed": false}
# Friday 11 April 2025  11:59:21 +0000 (0:00:00.063)       0:00:15.213 **********
#
# TASK [kubernetes/preinstall : Set dns facts] ***********************************
# ok: [node2] => {"ansible_facts": {"resolvconf": false}, "changed": false}
# ok: [node3] => {"ansible_facts": {"resolvconf": false}, "changed": false}
# ok: [node1] => {"ansible_facts": {"resolvconf": false}, "changed": false}
# Friday 11 April 2025  11:59:21 +0000 (0:00:00.059)       0:00:15.273 **********
#
# TASK [kubernetes/preinstall : Check if kubelet is configured] ******************
# ok: [node2] => {"changed": false, "stat": {"exists": false}}
# ok: [node3] => {"changed": false, "stat": {"exists": false}}
# ok: [node1] => {"changed": false, "stat": {"exists": false}}
# Friday 11 April 2025  11:59:21 +0000 (0:00:00.303)       0:00:15.576 **********
#
# TASK [kubernetes/preinstall : Check if early DNS configuration stage] **********
# ok: [node2] => {"ansible_facts": {"dns_early": true}, "changed": false}
# ok: [node3] => {"ansible_facts": {"dns_early": true}, "changed": false}
# ok: [node1] => {"ansible_facts": {"dns_early": true}, "changed": false}
# Friday 11 April 2025  11:59:21 +0000 (0:00:00.057)       0:00:15.633 **********
#
# TASK [kubernetes/preinstall : Target resolv.conf files] ************************
# ok: [node2] => {"ansible_facts": {"base": "", "head": "", "resolvconffile": "/etc/resolv.conf"}, "changed": false}
# ok: [node3] => {"ansible_facts": {"base": "", "head": "", "resolvconffile": "/etc/resolv.conf"}, "changed": false}
# ok: [node1] => {"ansible_facts": {"base": "", "head": "", "resolvconffile": "/etc/resolv.conf"}, "changed": false}
# Friday 11 April 2025  11:59:21 +0000 (0:00:00.063)       0:00:15.697 **********
# Friday 11 April 2025  11:59:21 +0000 (0:00:00.035)       0:00:15.733 **********
#
# TASK [kubernetes/preinstall : Check if /etc/dhclient.conf exists] **************
# ok: [node2] => {"changed": false, "stat": {"exists": false}}
# ok: [node3] => {"changed": false, "stat": {"exists": false}}
# ok: [node1] => {"changed": false, "stat": {"exists": false}}
# Friday 11 April 2025  11:59:22 +0000 (0:00:00.302)       0:00:16.036 **********
# Friday 11 April 2025  11:59:22 +0000 (0:00:00.032)       0:00:16.068 **********
#
# TASK [kubernetes/preinstall : Check if /etc/dhcp/dhclient.conf exists] *********
# ok: [node2] => {"changed": false, "stat": {"exists": false}}
# ok: [node3] => {"changed": false, "stat": {"exists": false}}
# ok: [node1] => {"changed": false, "stat": {"exists": false}}
# Friday 11 April 2025  11:59:22 +0000 (0:00:00.304)       0:00:16.373 **********
# Friday 11 April 2025  11:59:22 +0000 (0:00:00.035)       0:00:16.408 **********
# Friday 11 April 2025  11:59:22 +0000 (0:00:00.031)       0:00:16.439 **********
#
# TASK [kubernetes/preinstall : Target dhclient hook file for Debian family] *****
# ok: [node2] => {"ansible_facts": {"dhclienthookfile": "/etc/dhcp/dhclient-exit-hooks.d/zdnsupdate"}, "changed": false}
# ok: [node3] => {"ansible_facts": {"dhclienthookfile": "/etc/dhcp/dhclient-exit-hooks.d/zdnsupdate"}, "changed": false}
# ok: [node1] => {"ansible_facts": {"dhclienthookfile": "/etc/dhcp/dhclient-exit-hooks.d/zdnsupdate"}, "changed": false}
# Friday 11 April 2025  11:59:22 +0000 (0:00:00.063)       0:00:16.503 **********
# Friday 11 April 2025  11:59:22 +0000 (0:00:00.031)       0:00:16.534 **********
#
# TASK [kubernetes/preinstall : Check /usr readonly] *****************************
# ok: [node2] => {"changed": false, "stat": {"atime": 1733820100.273303, "block_size": 4096, "blocks": 8, "ctime": 1733820076.0830724, "dev": 64769, "device_type": 0, "executable": true, "exists": true, "gid": 0, "gr_name": "root", "inode": 1747, "isblk": false, "ischr": false, "isdir": true, "isfifo": false, "isgid": false, "islnk": false, "isreg": false, "issock": false, "isuid": false, "mode": "0755", "mtime": 1733819905.571436, "nlink": 12, "path": "/usr", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 4096, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": true, "xoth": true, "xusr": true}}
# ok: [node3] => {"changed": false, "stat": {"atime": 1733820100.273303, "block_size": 4096, "blocks": 8, "ctime": 1733820076.0830724, "dev": 64769, "device_type": 0, "executable": true, "exists": true, "gid": 0, "gr_name": "root", "inode": 1747, "isblk": false, "ischr": false, "isdir": true, "isfifo": false, "isgid": false, "islnk": false, "isreg": false, "issock": false, "isuid": false, "mode": "0755", "mtime": 1733819905.571436, "nlink": 12, "path": "/usr", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 4096, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": true, "xoth": true, "xusr": true}}
# ok: [node1] => {"changed": false, "stat": {"atime": 1733820100.273303, "block_size": 4096, "blocks": 8, "ctime": 1733820076.0830724, "dev": 64769, "device_type": 0, "executable": true, "exists": true, "gid": 0, "gr_name": "root", "inode": 1747, "isblk": false, "ischr": false, "isdir": true, "isfifo": false, "isgid": false, "islnk": false, "isreg": false, "issock": false, "isuid": false, "mode": "0755", "mtime": 1733819905.571436, "nlink": 12, "path": "/usr", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 4096, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": true, "xoth": true, "xusr": true}}
# Friday 11 April 2025  11:59:22 +0000 (0:00:00.304)       0:00:16.839 **********
# Friday 11 April 2025  11:59:22 +0000 (0:00:00.033)       0:00:16.873 **********
# Friday 11 April 2025  11:59:22 +0000 (0:00:00.018)       0:00:16.891 **********
#
# TASK [kubernetes/preinstall : Stop if kube_control_plane group is empty] *******
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:23 +0000 (0:00:00.033)       0:00:16.925 **********
#
# TASK [kubernetes/preinstall : Stop if etcd group is empty in external etcd mode] ***
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:23 +0000 (0:00:00.034)       0:00:16.959 **********
#
# TASK [kubernetes/preinstall : Stop if non systemd OS type] *********************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node3] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:23 +0000 (0:00:00.064)       0:00:17.024 **********
#
# TASK [kubernetes/preinstall : Stop if the os does not support] *****************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node3] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:23 +0000 (0:00:00.061)       0:00:17.086 **********
#
# TASK [kubernetes/preinstall : Stop if unknown network plugin] ******************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node3] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:23 +0000 (0:00:00.063)       0:00:17.149 **********
# Friday 11 April 2025  11:59:23 +0000 (0:00:00.044)       0:00:17.194 **********
#
# TASK [kubernetes/preinstall : Stop if unsupported version of Kubernetes] *******
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node3] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:23 +0000 (0:00:00.063)       0:00:17.257 **********
#
# TASK [kubernetes/preinstall : Stop if known booleans are set as strings (Use JSON format on CLI: -e "{'key': true }")] ***
# ok: [node2] => (item={'name': 'download_run_once', 'value': False}) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": {
#         "name": "download_run_once",
#         "value": false
#     },
#     "msg": "All assertions passed"
# }
# ok: [node2] => (item={'name': 'deploy_netchecker', 'value': False}) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": {
#         "name": "deploy_netchecker",
#         "value": false
#     },
#     "msg": "All assertions passed"
# }
# ok: [node2] => (item={'name': 'download_always_pull', 'value': False}) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": {
#         "name": "download_always_pull",
#         "value": false
#     },
#     "msg": "All assertions passed"
# }
# ok: [node2] => (item={'name': 'helm_enabled', 'value': False}) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": {
#         "name": "helm_enabled",
#         "value": false
#     },
#     "msg": "All assertions passed"
# }
# ok: [node2] => (item={'name': 'openstack_lbaas_enabled', 'value': False}) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": {
#         "name": "openstack_lbaas_enabled",
#         "value": false
#     },
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:23 +0000 (0:00:00.070)       0:00:17.327 **********
#
# TASK [kubernetes/preinstall : Stop if even number of etcd hosts] ***************
# ok: [node1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:23 +0000 (0:00:00.054)       0:00:17.382 **********
#
# TASK [kubernetes/preinstall : Stop if memory is too small for control plane nodes] ***
# ok: [node1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:23 +0000 (0:00:00.053)       0:00:17.436 **********
#
# TASK [kubernetes/preinstall : Stop if memory is too small for nodes] ***********
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node3] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:59:23 +0000 (0:00:00.054)       0:00:17.490 **********
#
# TASK [kubernetes/preinstall : Stop if cgroups are not enabled on nodes] ********
# ok: [node2] => {"changed": false, "cmd": ["stat", "-fc", "%T", "/sys/fs/cgroup/"], "delta": "0:00:00.002977", "end": "2025-04-11 11:59:23.855447", "msg": "", "rc": 0, "start": "2025-04-11 11:59:23.852470", "stderr": "", "stderr_lines": [], "stdout": "cgroup2fs", "stdout_lines": ["cgroup2fs"]}
# ...
# changed: [node1] => (item={'key': '::1', 'value': ['ip6-loopback', 'localhost6', 'ip6-localhost', 'localhost6.localdomain']}) => {"ansible_loop_var": "item", "backup": "/etc/hosts.35435.2025-04-11@12:07:44~", "changed": true, "item": {"key": "::1", "value": ["ip6-loopback", "localhost6", "ip6-localhost", "localhost6.localdomain"]}, "msg": "line replaced"}
# Friday 11 April 2025  12:07:44 +0000 (0:00:00.459)       0:08:38.044 **********
# Friday 11 April 2025  12:07:44 +0000 (0:00:00.096)       0:08:38.141 **********
# Friday 11 April 2025  12:07:44 +0000 (0:00:00.182)       0:08:38.324 **********
# Friday 11 April 2025  12:07:44 +0000 (0:00:00.097)       0:08:38.422 **********
# Friday 11 April 2025  12:07:44 +0000 (0:00:00.102)       0:08:38.524 **********
# Friday 11 April 2025  12:07:44 +0000 (0:00:00.098)       0:08:38.622 **********
# Friday 11 April 2025  12:07:44 +0000 (0:00:00.182)       0:08:38.805 **********
# Friday 11 April 2025  12:07:44 +0000 (0:00:00.038)       0:08:38.843 **********
# Friday 11 April 2025  12:07:44 +0000 (0:00:00.035)       0:08:38.879 **********
# Friday 11 April 2025  12:07:45 +0000 (0:00:00.035)       0:08:38.914 **********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | Restart systemd-resolved] ***
# changed: [node2] => {"changed": true, "name": "systemd-resolved", "state": "started", "status": {"ActiveEnterTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ActiveEnterTimestampMonotonic": "876635529", "ActiveExitTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ActiveExitTimestampMonotonic": "876561050", "ActiveState": "active", "After": "systemd-journald.socket tmp.mount systemd-tmpfiles-setup.service systemd-sysusers.service systemd-sysctl.service -.mount system.slice \"run-credentials-systemd\\\\x2dresolved.service.mount\"", "AllowIsolate": "no", "AmbientCapabilities": "cap_setpcap cap_net_bind_service cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-11 11:59:42 UTC", "AssertTimestampMonotonic": "876574539", "Before": "initrd-switch-root.target sysinit.target network.target nss-lookup.target shutdown.target", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BusName": "org.freedesktop.resolve1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "125196000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_setpcap cap_net_bind_service cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ConditionTimestampMonotonic": "876574538", "ConfigurationDirectoryMode": "0755", "Conflicts": "shutdown.target initrd-switch-root.target", "ControlGroup": "/system.slice/systemd-resolved.service", "ControlGroupId": "10801", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Name Resolution", "DeviceAllow": "char-rtc r", "DevicePolicy": "closed", "Documentation": "\"man:systemd-resolved.service(8)\" \"man:org.freedesktop.resolve1(5)\" https://www.freedesktop.org/wiki/Software/systemd/writing-network-configuration-managers https://www.freedesktop.org/wiki/Software/systemd/writing-resolver-clients", "DynamicUser": "no", "EffectiveCPUs": "0-1", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "21208", "ExecMainStartTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ExecMainStartTimestampMonotonic": "876585061", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "0", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-resolved.service", "FreezerState": "running", "GID": "991", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgressPackets": "[no data]", "IPIngressBytes": "[no data]", "IPIngressPackets": "[no data]", "Id": "systemd-resolved.service", "IgnoreOnIsolate": "no", "IgnoreSIGP ...
# changed: [node3] => {"changed": true, "name": "systemd-resolved", "state": "started", "status": {"ActiveEnterTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ActiveEnterTimestampMonotonic": "874661602", "ActiveExitTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ActiveExitTimestampMonotonic": "874594621", "ActiveState": "active", "After": "systemd-sysctl.service systemd-journald.socket systemd-tmpfiles-setup.service \"run-credentials-systemd\\\\x2dresolved.service.mount\" system.slice systemd-sysusers.service tmp.mount -.mount", "AllowIsolate": "no", "AmbientCapabilities": "cap_setpcap cap_net_bind_service cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-11 11:59:42 UTC", "AssertTimestampMonotonic": "874604538", "Before": "network.target shutdown.target nss-lookup.target initrd-switch-root.target sysinit.target", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BusName": "org.freedesktop.resolve1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "132108000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_setpcap cap_net_bind_service cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ConditionTimestampMonotonic": "874604537", "ConfigurationDirectoryMode": "0755", "Conflicts": "shutdown.target initrd-switch-root.target", "ControlGroup": "/system.slice/systemd-resolved.service", "ControlGroupId": "10717", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Name Resolution", "DeviceAllow": "char-rtc r", "DevicePolicy": "closed", "Documentation": "\"man:systemd-resolved.service(8)\" \"man:org.freedesktop.resolve1(5)\" https://www.freedesktop.org/wiki/Software/systemd/writing-network-configuration-managers https://www.freedesktop.org/wiki/Software/systemd/writing-resolver-clients", "DynamicUser": "no", "EffectiveCPUs": "0-1", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "21037", "ExecMainStartTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ExecMainStartTimestampMonotonic": "874610128", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "0", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-resolved.service", "FreezerState": "running", "GID": "991", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgressPackets": "[no data]", "IPIngressBytes": "[no data]", "IPIngressPackets": "[no data]", "Id": "systemd-resolved.service", "IgnoreOnIsolate": "no", "IgnoreSIGP ...
# changed: [node1] => {"changed": true, "name": "systemd-resolved", "state": "started", "status": {"ActiveEnterTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ActiveEnterTimestampMonotonic": "879253709", "ActiveExitTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ActiveExitTimestampMonotonic": "879186216", "ActiveState": "active", "After": "tmp.mount systemd-sysusers.service system.slice systemd-journald.socket -.mount \"run-credentials-systemd\\\\x2dresolved.service.mount\" systemd-tmpfiles-setup.service systemd-sysctl.service", "AllowIsolate": "no", "AmbientCapabilities": "cap_setpcap cap_net_bind_service cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-11 11:59:42 UTC", "AssertTimestampMonotonic": "879196582", "Before": "shutdown.target sysinit.target network.target nss-lookup.target initrd-switch-root.target", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BusName": "org.freedesktop.resolve1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "125711000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_setpcap cap_net_bind_service cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ConditionTimestampMonotonic": "879196581", "ConfigurationDirectoryMode": "0755", "Conflicts": "shutdown.target initrd-switch-root.target", "ControlGroup": "/system.slice/systemd-resolved.service", "ControlGroupId": "11171", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Name Resolution", "DeviceAllow": "char-rtc r", "DevicePolicy": "closed", "Documentation": "\"man:systemd-resolved.service(8)\" \"man:org.freedesktop.resolve1(5)\" https://www.freedesktop.org/wiki/Software/systemd/writing-network-configuration-managers https://www.freedesktop.org/wiki/Software/systemd/writing-resolver-clients", "DynamicUser": "no", "EffectiveCPUs": "0-1", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "22462", "ExecMainStartTimestamp": "Fri 2025-04-11 11:59:42 UTC", "ExecMainStartTimestampMonotonic": "879202116", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-resolved ; argv[]=/usr/lib/systemd/systemd-resolved ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "0", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-resolved.service", "FreezerState": "running", "GID": "991", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgressPackets": "[no data]", "IPIngressBytes": "[no data]", "IPIngressPackets": "[no data]", "Id": "systemd-resolved.service", "IgnoreOnIsolate": "no", "IgnoreSIGP ...
# Friday 11 April 2025  12:07:45 +0000 (0:00:00.529)       0:08:39.444 **********
# Friday 11 April 2025  12:07:45 +0000 (0:00:00.169)       0:08:39.614 **********
#
# PLAY RECAP *********************************************************************
# node1                      : ok=571  changed=128  unreachable=0    failed=0    skipped=926  rescued=0    ignored=3
# node2                      : ok=480  changed=97   unreachable=0    failed=0    skipped=685  rescued=0    ignored=1
# node3                      : ok=456  changed=93   unreachable=0    failed=0    skipped=620  rescued=0    ignored=1
#
# Friday 11 April 2025  12:07:45 +0000 (0:00:00.133)       0:08:39.747 **********
# ===============================================================================
# container-engine/containerd : Download_file | Download item ------------ 38.13s
# download : Download_file | Download item ------------------------------- 32.70s
# kubernetes/kubeadm : Join to cluster if needed ------------------------- 16.08s
# container-engine/runc : Download_file | Download item ------------------ 15.95s
# container-engine/crictl : Download_file | Download item ---------------- 15.09s
# container-engine/nerdctl : Download_file | Download item ---------------- 9.57s
# kubernetes/control-plane : Kubeadm | Initialize first control plane node --- 7.41s
# etcd : Restart etcd ----------------------------------------------------- 6.08s
# download : Download_file | Download item -------------------------------- 5.35s
# etcd : Configure | Check if etcd cluster is healthy --------------------- 5.26s
# container-engine/docker : Docker | Remove docker package ---------------- 5.25s
# kubernetes-apps/network_plugin/flannel : Flannel | Wait for flannel subnet.env file presence --- 5.22s
# download : Download_container | Download image if required -------------- 4.90s
# kubernetes/preinstall : Install packages requirements ------------------- 4.81s
# download : Download_container | Download image if required -------------- 4.79s
# download : Download_container | Download image if required -------------- 4.73s
# download : Download_container | Download image if required -------------- 4.69s
# download : Download_container | Download image if required -------------- 4.53s
# download : Download_container | Download image if required -------------- 4.41s
# kubernetes-apps/ansible : Kubernetes Apps | CoreDNS --------------------- 4.16s

# %%
nodes[0].upload_file(local_file_path="node_scripts/reset_kubespray.sh", remote_file_path="reset.sh");
nodes[0].execute(f"chmod +x reset.sh && ./reset.sh");
# Out:
# Using /home/ubuntu/kubespray/ansible.cfg as config file
#
# PLAY [Check Ansible version] ***************************************************
# Friday 11 April 2025  11:22:27 +0000 (0:00:00.042)       0:00:00.042 **********
#  [WARNING]: While constructing a mapping from
# /home/ubuntu/kubespray/roles/bootstrap-os/tasks/main.yml, line 29, column 7,
# found a duplicate dict key (paths). Using last defined value only.
# [WARNING]: Skipping callback plugin 'ara_default', unable to load
#
# TASK [Check 2.16.4 <= Ansible version < 2.17.0] ********************************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:22:27 +0000 (0:00:00.070)       0:00:00.113 **********
#
# TASK [Check that python netaddr is installed] **********************************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Friday 11 April 2025  11:22:27 +0000 (0:00:00.098)       0:00:00.212 **********
#
# TASK [Check that jinja is not too old (install via pip)] ***********************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
#
# PLAY [Define groups for legacy less structured inventories] ********************
# Friday 11 April 2025  11:22:27 +0000 (0:00:00.107)       0:00:00.320 **********
#  [WARNING]: Could not match supplied host pattern, ignoring: bastion
#   [WARNING]: Could not match supplied host pattern, ignoring: calico_rr
#
# TASK [Match needed groups by their old names or definition] ********************
# changed: [node2] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node2] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [node3] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node3] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [node1] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node1] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
#
# PLAY [Install bastion ssh config] **********************************************
# skipping: no hosts matched
#
# PLAY [Bootstrap hosts for Ansible] *********************************************
# Friday 11 April 2025  11:22:28 +0000 (0:00:00.206)       0:00:00.526 **********
#  [WARNING]: raw module does not support the environment keyword
#
# TASK [bootstrap-os : Fetch /etc/os-release] ************************************
# ok: [node2] => {"changed": false, "rc": 0, "stderr": "Shared connection to 10.145.1.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.3 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [node3] => {"changed": false, "rc": 0, "stderr": "Shared connection to 10.145.1.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.4 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [node1] => {"changed": false, "rc": 0, "stderr": "Shared connection to 10.145.1.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# Friday 11 April 2025  11:22:28 +0000 (0:00:00.260)       0:00:00.787 **********
# Friday 11 April 2025  11:22:28 +0000 (0:00:00.232)       0:00:01.019 **********
#
# TASK [bootstrap-os : Include tasks] ********************************************
# included: /home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml for node2, node3, node1 => (item=/home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml)
# Friday 11 April 2025  11:22:28 +0000 (0:00:00.334)       0:00:01.353 **********
#
# TASK [bootstrap-os : Check if bootstrap is needed] *****************************
# ok: [node2] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.1.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.3 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [node3] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.1.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.4 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [node1] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.1.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.2 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# Friday 11 April 2025  11:22:29 +0000 (0:00:00.255)       0:00:01.609 **********
#
# TASK [bootstrap-os : Check http::proxy in apt configuration files] *************
# ok: [node2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.1.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [node3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.1.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [node1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.1.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.2 closed."], "stdout": "\r
# ", "stdout_lines": [""]}
# Friday 11 April 2025  11:22:29 +0000 (0:00:00.270)       0:00:01.880 **********
# Friday 11 April 2025  11:22:29 +0000 (0:00:00.136)       0:00:02.016 **********
#
# TASK [bootstrap-os : Check https::proxy in apt configuration files] ************
# ok: [node2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.1.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [node3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.1.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [node1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.1.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.2 closed."], "stdout": "", "stdout_lines": []}
# Friday 11 April 2025  11:22:29 +0000 (0:00:00.273)       0:00:02.289 **********
# Friday 11 April 2025  11:22:30 +0000 (0:00:00.188)       0:00:02.477 **********
# Friday 11 April 2025  11:22:30 +0000 (0:00:00.156)       0:00:02.634 **********
# Friday 11 April 2025  11:22:30 +0000 (0:00:00.224)       0:00:02.859 **********
#
# TASK [bootstrap-os : Ensure iproute2 is installed] *****************************
# ok: [node2] => {"cache_update_time": 1744366497, "cache_updated": false, "changed": false}
# ok: [node3] => {"cache_update_time": 1744366497, "cache_updated": false, "changed": false}
# ok: [node1] => {"cache_update_time": 1744366497, "cache_updated": false, "changed": false}
# Friday 11 April 2025  11:22:31 +0000 (0:00:01.214)       0:00:04.073 **********
# Friday 11 April 2025  11:22:31 +0000 (0:00:00.153)       0:00:04.227 **********
# Friday 11 April 2025  11:22:32 +0000 (0:00:00.235)       0:00:04.463 **********
#
# TASK [bootstrap-os : Create remote_tmp for it is used by another module] *******
# ok: [node3] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [node2] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [node1] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# Friday 11 April 2025  11:22:32 +0000 (0:00:00.540)       0:00:05.004 **********
#
# TASK [bootstrap-os : Gather facts] *********************************************
# ok: [node3]
# ok: [node2]
# ok: [node1]
# Friday 11 April 2025  11:22:33 +0000 (0:00:00.830)       0:00:05.834 **********
#
# TASK [bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora)] ***
# ok: [node3] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "node3.cluster.local", "ansible_hostname": "node3", "ansible_nodename": "node3"}, "changed": false, "name": "node3"}
# ok: [node2] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "node2.cluster.local", "ansible_hostname": "node2", "ansible_nodename": "node2"}, "changed": false, "name": "node2"}
# ok: [node1] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "node1.cluster.local", "ansible_hostname": "node1", "ansible_nodename": "node1"}, "changed": false, "name": "node1"}
# Friday 11 April 2025  11:22:34 +0000 (0:00:01.040)       0:00:06.874 **********
# Friday 11 April 2025  11:22:34 +0000 (0:00:00.209)       0:00:07.084 **********
#
# TASK [bootstrap-os : Ensure bash_completion.d folder exists] *******************
# ok: [node2] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [node3] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [node1] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# Friday 11 April 2025  11:22:35 +0000 (0:00:00.600)       0:00:07.685 **********
# Friday 11 April 2025  11:22:35 +0000 (0:00:00.218)       0:00:07.903 **********
#
# TASK [kubespray-defaults : Set fallback_ip] ************************************
# ok: [node2] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [node3] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [node1] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# Friday 11 April 2025  11:22:35 +0000 (0:00:00.174)       0:00:08.077 **********
# Friday 11 April 2025  11:22:35 +0000 (0:00:00.121)       0:00:08.198 **********
# Friday 11 April 2025  11:22:35 +0000 (0:00:00.150)       0:00:08.349 **********
#
# PLAY [Gather facts] ************************************************************
# Friday 11 April 2025  11:22:36 +0000 (0:00:00.356)       0:00:08.705 **********
#
# TASK [Gather minimal facts] ****************************************************
# ok: [node2]
# ok: [node3]
# ok: [node1]
# Friday 11 April 2025  11:22:36 +0000 (0:00:00.501)       0:00:09.206 **********
#
# TASK [Gather necessary facts (network)] ****************************************
# ok: [node2]
# ok: [node3]
# ok: [node1]
# Friday 11 April 2025  11:22:37 +0000 (0:00:00.757)       0:00:09.964 **********
#
# TASK [Gather necessary facts (hardware)] ***************************************
# ok: [node2]
# ok: [node3]
# ok: [node1]
#
# PLAY [Reset cluster] ***********************************************************
# Friday 11 April 2025  11:22:38 +0000 (0:00:00.949)       0:00:10.913 **********
# Friday 11 April 2025  11:22:38 +0000 (0:00:00.062)       0:00:10.976 **********
# Friday 11 April 2025  11:22:38 +0000 (0:00:00.182)       0:00:11.158 **********
#
# TASK [Gather information about installed services] *****************************
# ok: [node3] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Modem ...
# ok: [node2] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Modem ...
# ok: [node1] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Modem ...
# Friday 11 April 2025  11:22:41 +0000 (0:00:02.910)       0:00:14.069 **********
# Friday 11 April 2025  11:22:41 +0000 (0:00:00.263)       0:00:14.332 **********
# Friday 11 April 2025  11:22:42 +0000 (0:00:00.189)       0:00:14.522 **********
# Friday 11 April 2025  11:22:42 +0000 (0:00:00.066)       0:00:14.588 **********
# Friday 11 April 2025  11:22:42 +0000 (0:00:00.139)       0:00:14.728 **********
# Friday 11 April 2025  11:22:42 +0000 (0:00:00.326)       0:00:15.054 **********
#
# TASK [adduser : User | Create User Group] **************************************
# ok: [node3] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [node2] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [node1] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# Friday 11 April 2025  11:22:43 +0000 (0:00:00.390)       0:00:15.445 **********
#
# TASK [adduser : User | Create User] ********************************************
# ok: [node2] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# ok: [node1] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# ok: [node3] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# Friday 11 April 2025  11:22:43 +0000 (0:00:00.569)       0:00:16.014 **********
#
# TASK [kubernetes/preinstall : Check if /etc/fstab exists] **********************
# ok: [node1] => {"changed": false, "stat": {"atime": 1744295354.683, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [node2] => {"changed": false, "stat": {"atime": 1744295355.753, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [node3] => {"changed": false, "stat": {"atime": 1744295355.654, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# Friday 11 April 2025  11:22:44 +0000 (0:00:00.468)       0:00:16.483 **********
#
# TASK [kubernetes/preinstall : Remove swapfile from /etc/fstab] *****************
# ok: [node2] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [node3] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [node1] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [node2] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [node3] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [node1] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# Friday 11 April 2025  11:22:44 +0000 (0:00:00.750)       0:00:17.233 **********
#
# TASK [kubernetes/preinstall : Mask swap.target (persist swapoff)] **************
# ok: [node3] => {"changed": false, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Thu 2025-04-10 14:30:48 UTC", "ActiveEnterTimestampMonotonic": "3519392", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Thu 2025-04-10 14:30:48 UTC", "AssertTimestampMonotonic": "3519389", "Before": "\"var-lib-kubelet-pods-8f5e7bc9\\\\x2de4af\\\\x2d4768\\\\x2da953\\\\x2def3d3ab82cc2-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2drrhc5.mount\" \"var-lib-kubelet-pods-999fdc7d\\\\x2d1a4d\\\\x2d4ed2\\\\x2da3c1\\\\x2de703e8b5e36f-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2dthjfw.mount\" run-containerd-io.containerd.grpc.v1.cri-sandboxes-d32eea13ff4de4afb6c3d09fdf7c8e6d29843cb4525a37788af35c0896260ace-shm.mount run-containerd-io.containerd.grpc.v1.cri-sandboxes-121db5f9f753e0820046f46548784ec0f3269ce18afef11a9053867009cfa0b7-shm.mount run-containerd-io.containerd.grpc.v1.cri-sandboxes-8da67b62af87bd3086bf8f69f2aaaa895b37a8e3d0ba40f9a8f0abb859e16151-shm.mount run-user-1000.mount run-containerd-io.containerd.grpc.v1.cri-sandboxes-e02f06c41dea69810bd1b8b38291121254df52bec0c38437bb91fd758d892a8a-shm.mount sysinit.target \"var-lib-kubelet-pods-ff10b5f5\\\\x2dfdf7\\\\x2d4e20\\\\x2dad94\\\\x2d04abe02fd9da-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2dg6v58.mount\" run-containerd-io.containerd.grpc.v1.cri-sandboxes-ba3da7a54a98caf93c5369fe61899ec2a864b4ad971776cf696fd425dce1da3b-shm.mount \"var-lib-kubelet-pods-11184585\\\\x2d30d2\\\\x2d41ac\\\\x2d938e\\\\x2d630e0af9fe99-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2d85jn8.mount\"", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "no", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Thu 2025-04-10 14:30:48 UTC", "ConditionTimestampMonotonic": "3519388", "DefaultDependencies": "yes", "Description": "swap.target", "FailureAction": "none", "FragmentPath": "/etc/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Thu 2025-04-10 14:30:48 UTC", "InactiveExitTimestampMonotonic": "3519392", "InvocationID": "ab81e0dddb504656894f373b654d3cff", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadError": "org.freedesktop.systemd1.UnitMasked \"Unit swap.target is masked.\"", "LoadState": "masked", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Thu 2025-04-10 14:30:48 UTC", "StateChangeTimestampMonotonic": "3519392", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "masked", "WantedBy": "sysinit.target"}}
# ok: [node2] => {"changed": false, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Thu 2025-04-10 14:30:51 UTC", "ActiveEnterTimestampMonotonic": "3678255", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Thu 2025-04-10 14:30:51 UTC", "AssertTimestampMonotonic": "3678252", "Before": "run-containerd-io.containerd.grpc.v1.cri-sandboxes-438e1bd214eea5cf8bed44e816766612711bfa1e93a0d0597b680048169392fb-shm.mount \"var-lib-kubelet-pods-c0c97f45\\\\x2d3da6\\\\x2d4053\\\\x2da3c5\\\\x2d9614d49871b6-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2dsjk8g.mount\" run-containerd-io.containerd.grpc.v1.cri-sandboxes-52a755fdc5e24bd6170648c9ecc5ba7924713332f6167c6fdc3161507f639f55-shm.mount run-containerd-io.containerd.grpc.v1.cri-sandboxes-3b9124334a77ef09c553ca5db4abd01c693b0db8820f1b83cd8596f5642ffc9c-shm.mount \"var-lib-kubelet-pods-e9fa155b\\\\x2d79ae\\\\x2d4909\\\\x2db6b2\\\\x2dea5d6735d24d-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2d6t4nd.mount\" run-containerd-io.containerd.grpc.v1.cri-sandboxes-35f1e1033ccfe96be182065ce12d9fa7d574700c20847b93e973394ca97aaddb-shm.mount \"var-lib-kubelet-pods-5b43b896\\\\x2d745a\\\\x2d4c4e\\\\x2db7b2\\\\x2df3124e57971e-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2dllhzk.mount\" run-containerd-io.containerd.grpc.v1.cri-sandboxes-6ede742d726fc7af0d7115761362bcb76a29f5ac2624521b4f60f1dd360314cb-shm.mount sysinit.target run-containerd-io.containerd.grpc.v1.cri-sandboxes-dd4efeea5716b838792bc8ce02830ba73292c6819d2bac4f64c12fabc40c0bfc-shm.mount run-user-1000.mount \"var-lib-kubelet-pods-1daeb2a1\\\\x2d9e9d\\\\x2d4b69\\\\x2d9e88\\\\x2dac7066e23f0f-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2dhxqmj.mount\" \"var-lib-kubelet-pods-90ae9541\\\\x2d78ff\\\\x2d4c8f\\\\x2d8f27\\\\x2de339795f3ce0-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2dkkkv8.mount\"", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "no", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Thu 2025-04-10 14:30:51 UTC", "ConditionTimestampMonotonic": "3678251", "DefaultDependencies": "yes", "Description": "swap.target", "FailureAction": "none", "FragmentPath": "/etc/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Thu 2025-04-10 14:30:51 UTC", "InactiveExitTimestampMonotonic": "3678255", "InvocationID": "ffa11b668226472b889517779146f7a0", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadError": "org.freedesktop.systemd1.UnitMasked \"Unit swap.target is masked.\"", "LoadState": "masked", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Thu 2025-04-10 14:30:51 UTC", "StateChangeTimestampMonotonic": "3678255", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "masked", "WantedBy": "sysinit.target"}}
# ok: [node1] => {"changed": false, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Thu 2025-04-10 14:30:51 UTC", "ActiveEnterTimestampMonotonic": "3440752", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Thu 2025-04-10 14:30:51 UTC", "AssertTimestampMonotonic": "3440749", "Before": "\"var-lib-kubelet-pods-48e4c756\\\\x2d213b\\\\x2d484e\\\\x2db8fb\\\\x2d6e35450f43c5-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2df5lj7.mount\" run-containerd-io.containerd.grpc.v1.cri-sandboxes-90e18a6475591eba6ec75781017c828d67ffeb9b4bbee6ede3b492ff7ce94443-shm.mount \"var-lib-kubelet-pods-2b604d94\\\\x2d7fdd\\\\x2d4410\\\\x2d897f\\\\x2d654123e200e1-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2dxghvg.mount\" run-containerd-io.containerd.grpc.v1.cri-sandboxes-5eb119b3275c5bfd4a4e511fe50462e5e5acf879d6a7985c9ecff02733d60f09-shm.mount run-containerd-io.containerd.grpc.v1.cri-sandboxes-b3ba1ba782764aa929062614b635d13b1553e96ac489c0c1335cf7000ee05513-shm.mount run-containerd-io.containerd.grpc.v1.cri-sandboxes-5921e1f73680ddbced93119033dfe4aea871e0c1d4209f589506a85f006a459b-shm.mount sysinit.target run-containerd-io.containerd.grpc.v1.cri-sandboxes-73a696023a882259e7a08b6a8a9fa47106b6a8ab573bdbd900d69cd443b1d91c-shm.mount \"var-lib-kubelet-pods-9b02f3fc\\\\x2d3dba\\\\x2d4f71\\\\x2dbdf3\\\\x2d488bded8962b-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2dfdlcm.mount\" \"var-lib-kubelet-pods-9fd20201\\\\x2d26ac\\\\x2d4bd6\\\\x2da361\\\\x2dd723ace617b2-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2dk6sl9.mount\" run-containerd-io.containerd.grpc.v1.cri-sandboxes-de0a40a28d0761f12953e2e87dd1e4f2cf7fe1af9dbe63484b07bb596e24718c-shm.mount \"var-lib-kubelet-pods-691cbf10\\\\x2db01e\\\\x2d4b3d\\\\x2d9bba\\\\x2d12c3683bc266-volumes-kubernetes.io\\\\x7eprojected-kube\\\\x2dapi\\\\x2daccess\\\\x2d5zdqd.mount\" run-containerd-io.containerd.grpc.v1.cri-sandboxes-0291df2fd747a7c3294cfad9aedfd302a7424c38345dc2b81a4c48abac2535ed-shm.mount run-user-1000.mount run-containerd-io.containerd.grpc.v1.cri-sandboxes-e92e47dd2509c34c2b2ee4528d1e112d09bafa553bf89657bd466461167f77e4-shm.mount", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "no", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Thu 2025-04-10 14:30:51 UTC", "ConditionTimestampMonotonic": "3440748", "DefaultDependencies": "yes", "Description": "swap.target", "FailureAction": "none", "FragmentPath": "/etc/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Thu 2025-04-10 14:30:51 UTC", "InactiveExitTimestampMonotonic": "3440752", "InvocationID": "f681f1fcf0a8495295df37e2e3ff606c", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadError": "org.freedesktop.systemd1.UnitMasked \"Unit swap.target is masked.\"", "LoadState": "masked", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Thu 2025-04-10 14:30:51 UTC", "StateChangeTimestampMonotonic": "3440752", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "masked", "WantedBy": "sysinit.target"}}
# Friday 11 April 2025  11:22:45 +0000 (0:00:00.671)       0:00:17.904 **********
#
# TASK [kubernetes/preinstall : Disable swap] ************************************
# changed: [node2] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.002858", "end": "2025-04-11 11:22:45.800398", "msg": "", "rc": 0, "start": "2025-04-11 11:22:45.797540", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [node1] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.005905", "end": "2025-04-11 11:22:45.825283", "msg": "", "rc": 0, "start": "2025-04-11 11:22:45.819378", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [node3] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.002947", "end": "2025-04-11 11:22:45.888268", "msg": "", "rc": 0, "start": "2025-04-11 11:22:45.885321", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# Friday 11 April 2025  11:22:45 +0000 (0:00:00.457)       0:00:18.361 **********
# Friday 11 April 2025  11:22:46 +0000 (0:00:00.147)       0:00:18.509 **********
#
# TASK [kubernetes/preinstall : Check resolvconf] ********************************
# ok: [node1] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.006964", "end": "2025-04-11 11:22:46.339341", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-11 11:22:46.332377", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [node2] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002556", "end": "2025-04-11 11:22:46.324669", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-11 11:22:46.322113", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [node3] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002539", "end": "2025-04-11 11:22:46.448511", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-11 11:22:46.445972", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# Friday 11 April 2025  11:22:46 +0000 (0:00:00.418)       0:00:18.927 **********
#
# TASK [kubernetes/preinstall : Check existence of /etc/resolvconf/resolv.conf.d] ***
# ok: [node1] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [node2] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [node3] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# Friday 11 April 2025  11:22:46 +0000 (0:00:00.312)       0:00:19.240 **********
#
# TASK [kubernetes/preinstall : Check status of /etc/resolv.conf] ****************
# ...
# Friday 11 April 2025  11:24:25 +0000 (0:00:01.810)       0:01:58.024 **********
#
# TASK [reset : Restart active network services] *********************************
# changed: [node2] => (item=systemd-networkd) => {"ansible_loop_var": "item", "changed": true, "item": "systemd-networkd", "name": "systemd-networkd", "state": "started", "status": {"ActiveEnterTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ActiveEnterTimestampMonotonic": "73850237308", "ActiveExitTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ActiveExitTimestampMonotonic": "73850180515", "ActiveState": "active", "After": "systemd-networkd.socket network-pre.target systemd-sysctl.service system.slice systemd-sysusers.service systemd-journald.socket -.mount systemd-udevd.service", "AllowIsolate": "no", "AmbientCapabilities": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-11 11:01:37 UTC", "AssertTimestampMonotonic": "73850205643", "Before": "ubuntu-advantage.service systemd-networkd-wait-online.service multi-user.target update-notifier-download.timer update-notifier-motd.timer ua-timer.service network.target apt-daily.service initrd-switch-root.target shutdown.target apt-daily-upgrade.service", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BoundBy": "systemd-networkd-wait-online.service", "BusName": "org.freedesktop.network1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "51638000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime fdstore", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "yes", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ConditionTimestampMonotonic": "73850205596", "ConfigurationDirectoryMode": "0755", "Conflicts": "initrd-switch-root.target shutdown.target", "ControlGroup": "/system.slice/systemd-networkd.service", "ControlGroupId": "39622", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Configuration", "DeviceAllow": "char-* rw", "DevicePolicy": "auto", "Documentation": "\"man:systemd-networkd.service(8)\" \"man:org.freedesktop.network1(5)\"", "DynamicUser": "no", "EffectiveCPUs": "0-1", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "128527", "ExecMainStartTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ExecMainStartTimestampMonotonic": "73850211132", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "512", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-networkd.service", "FreezerState": "running", "GID": "998", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgre ...
# changed: [node1] => (item=systemd-networkd) => {"ansible_loop_var": "item", "changed": true, "item": "systemd-networkd", "name": "systemd-networkd", "state": "started", "status": {"ActiveEnterTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ActiveEnterTimestampMonotonic": "73848155457", "ActiveExitTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ActiveExitTimestampMonotonic": "73848090199", "ActiveState": "active", "After": "systemd-sysusers.service systemd-journald.socket systemd-udevd.service -.mount network-pre.target systemd-networkd.socket system.slice systemd-sysctl.service", "AllowIsolate": "no", "AmbientCapabilities": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-11 11:01:37 UTC", "AssertTimestampMonotonic": "73848106838", "Before": "systemd-networkd-wait-online.service multi-user.target ubuntu-advantage.service network.target update-notifier-download.timer apt-daily-upgrade.service initrd-switch-root.target update-notifier-motd.timer apt-daily.service shutdown.target ua-timer.service", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BoundBy": "systemd-networkd-wait-online.service", "BusName": "org.freedesktop.network1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "74233000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime fdstore", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "yes", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ConditionTimestampMonotonic": "73848106791", "ConfigurationDirectoryMode": "0755", "Conflicts": "shutdown.target initrd-switch-root.target", "ControlGroup": "/system.slice/systemd-networkd.service", "ControlGroupId": "44742", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Configuration", "DeviceAllow": "char-* rw", "DevicePolicy": "auto", "Documentation": "\"man:systemd-networkd.service(8)\" \"man:org.freedesktop.network1(5)\"", "DynamicUser": "no", "EffectiveCPUs": "0-1", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "179225", "ExecMainStartTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ExecMainStartTimestampMonotonic": "73848114108", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "512", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-networkd.service", "FreezerState": "running", "GID": "998", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgre ...
# changed: [node3] => (item=systemd-networkd) => {"ansible_loop_var": "item", "changed": true, "item": "systemd-networkd", "name": "systemd-networkd", "state": "started", "status": {"ActiveEnterTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ActiveEnterTimestampMonotonic": "73852114372", "ActiveExitTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ActiveExitTimestampMonotonic": "73852063735", "ActiveState": "active", "After": "systemd-networkd.socket system.slice network-pre.target systemd-udevd.service systemd-sysctl.service systemd-sysusers.service -.mount systemd-journald.socket", "AllowIsolate": "no", "AmbientCapabilities": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Fri 2025-04-11 11:01:37 UTC", "AssertTimestampMonotonic": "73852083306", "Before": "ubuntu-advantage.service update-notifier-download.timer apt-daily.service multi-user.target initrd-switch-root.target update-notifier-motd.timer shutdown.target apt-daily-upgrade.service network.target ua-timer.service systemd-networkd-wait-online.service", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BoundBy": "systemd-networkd-wait-online.service", "BusName": "org.freedesktop.network1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "43743000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime fdstore", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "yes", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ConditionTimestampMonotonic": "73852083264", "ConfigurationDirectoryMode": "0755", "Conflicts": "shutdown.target initrd-switch-root.target", "ControlGroup": "/system.slice/systemd-networkd.service", "ControlGroupId": "38748", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Configuration", "DeviceAllow": "char-* rw", "DevicePolicy": "auto", "Documentation": "\"man:systemd-networkd.service(8)\" \"man:org.freedesktop.network1(5)\"", "DynamicUser": "no", "EffectiveCPUs": "0-1", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "128670", "ExecMainStartTimestamp": "Fri 2025-04-11 11:01:37 UTC", "ExecMainStartTimestampMonotonic": "73852087120", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "512", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-networkd.service", "FreezerState": "running", "GID": "998", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPEgre ...
#
# PLAY RECAP *********************************************************************
# node1                      : ok=122  changed=27   unreachable=0    failed=0    skipped=91   rescued=0    ignored=1
# node2                      : ok=108  changed=27   unreachable=0    failed=0    skipped=90   rescued=0    ignored=1
# node3                      : ok=104  changed=26   unreachable=0    failed=0    skipped=90   rescued=0    ignored=1
#
# Friday 11 April 2025  11:24:26 +0000 (0:00:00.741)       0:01:58.766 **********
# ===============================================================================
# reset : Reset | stop services ------------------------------------------ 17.54s
# reset : Reset | delete some files and directories ---------------------- 15.54s
# kubernetes/preinstall : Ensure kubelet expected parameters are set ------ 4.38s
# network_plugin/cni : CNI | Copy cni plugins ----------------------------- 3.23s
# Gather information about installed services ----------------------------- 2.91s
# kubernetes/preinstall : Update package management cache (APT) ----------- 2.67s
# reset : Reset | remove services ----------------------------------------- 2.05s
# reset : Reset | remove containerd binary files -------------------------- 1.91s
# reset : Gather active network services ---------------------------------- 1.81s
# bootstrap-os : Ensure iproute2 is installed ----------------------------- 1.21s
# reset : Flush iptables -------------------------------------------------- 1.11s
# reset : Reset | unmount kubelet dirs ------------------------------------ 1.08s
# bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora) --- 1.04s
# kubernetes/preinstall : Install packages requirements ------------------- 1.02s
# Gather necessary facts (hardware) --------------------------------------- 0.95s
# kubernetes/preinstall : Create kubernetes directories ------------------- 0.88s
# reset : Reset | stop all cri pods --------------------------------------- 0.87s
# reset : Reset | systemctl daemon-reload --------------------------------- 0.83s
# bootstrap-os : Gather facts --------------------------------------------- 0.83s
# kubernetes/preinstall : Preinstall | Restart systemd-resolved ----------- 0.81s
