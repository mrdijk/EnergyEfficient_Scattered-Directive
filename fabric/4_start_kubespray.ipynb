# %%
import datetime
import json
import asyncio

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()

fablib.show_config();
# Out:
# <style type="text/css">
# #T_e5d4a tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e5d4a tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e5d4a caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_e5d4a_row0_col0, #T_e5d4a_row0_col1, #T_e5d4a_row1_col0, #T_e5d4a_row1_col1, #T_e5d4a_row2_col0, #T_e5d4a_row2_col1, #T_e5d4a_row3_col0, #T_e5d4a_row3_col1, #T_e5d4a_row4_col0, #T_e5d4a_row4_col1, #T_e5d4a_row5_col0, #T_e5d4a_row5_col1, #T_e5d4a_row6_col0, #T_e5d4a_row6_col1, #T_e5d4a_row7_col0, #T_e5d4a_row7_col1, #T_e5d4a_row8_col0, #T_e5d4a_row8_col1, #T_e5d4a_row9_col0, #T_e5d4a_row9_col1, #T_e5d4a_row10_col0, #T_e5d4a_row10_col1, #T_e5d4a_row11_col0, #T_e5d4a_row11_col1, #T_e5d4a_row12_col0, #T_e5d4a_row12_col1, #T_e5d4a_row13_col0, #T_e5d4a_row13_col1, #T_e5d4a_row14_col0, #T_e5d4a_row14_col1, #T_e5d4a_row15_col0, #T_e5d4a_row15_col1, #T_e5d4a_row16_col0, #T_e5d4a_row16_col1, #T_e5d4a_row17_col0, #T_e5d4a_row17_col1, #T_e5d4a_row18_col0, #T_e5d4a_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_e5d4a">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e5d4a_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_e5d4a_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_e5d4a_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_e5d4a_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_e5d4a_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_e5d4a_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_e5d4a_row5_col1" class="data row5 col1" >49f65ad7-d8a2-4ab9-8ca0-ba777a2e0ea2</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_e5d4a_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_e5d4a_row7_col1" class="data row7 col1" >jakejongejans_0000313927</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_e5d4a_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_e5d4a_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_e5d4a_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_e5d4a_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_e5d4a_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_e5d4a_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_e5d4a_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_e5d4a_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row16_col0" class="data row16 col0" >Version</td>
#       <td id="T_e5d4a_row16_col1" class="data row16 col1" >1.8.0</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row17_col0" class="data row17 col0" >Data directory</td>
#       <td id="T_e5d4a_row17_col1" class="data row17 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_e5d4a_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_e5d4a_row18_col1" class="data row18 col1" >DYNAMOS project</td>
#     </tr>
#   </tbody>
# </table>

# %%
slice = fablib.get_slice(name="DYNAMOS-on-FABRIC");
nodes = slice.get_nodes();

# %%
nodes[0].upload_file(local_file_path="node_scripts/start_kubespray.sh", remote_file_path="start.sh");
nodes[0].execute(f"chmod +x start.sh && ./start.sh");
# Out:
# Using /home/ubuntu/kubespray/ansible.cfg as config file
#
# PLAY [Check Ansible version] ***************************************************
# Wednesday 16 April 2025  08:26:18 +0000 (0:00:00.008)       0:00:00.008 *******
#
# TASK [Check 2.16.4 <= Ansible version < 2.17.0] ********************************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Wednesday 16 April 2025  08:26:18 +0000 (0:00:00.018)       0:00:00.027 *******
#  [WARNING]: While constructing a mapping from
# /home/ubuntu/kubespray/roles/bootstrap-os/tasks/main.yml, line 29, column 7,
# found a duplicate dict key (paths). Using last defined value only.
# [WARNING]: Skipping callback plugin 'ara_default', unable to load
#
# TASK [Check that python netaddr is installed] **********************************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Wednesday 16 April 2025  08:26:18 +0000 (0:00:00.048)       0:00:00.075 *******
#
# TASK [Check that jinja is not too old (install via pip)] ***********************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
#
# PLAY [Define groups for legacy less structured inventories] ********************
# Wednesday 16 April 2025  08:26:18 +0000 (0:00:00.015)       0:00:00.091 *******
#  [WARNING]: Could not match supplied host pattern, ignoring: bastion
# [WARNING]: Could not match supplied host pattern, ignoring: calico_rr
#
# TASK [Match needed groups by their old names or definition] ********************
# changed: [dynamos] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [dynamos] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-1] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-1] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-2] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-2] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-3] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-3] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [control] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [control] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
#
# PLAY [Install bastion ssh config] **********************************************
# skipping: no hosts matched
#
# PLAY [Bootstrap hosts for Ansible] *********************************************
# Wednesday 16 April 2025  08:26:18 +0000 (0:00:00.084)       0:00:00.175 *******
#  [WARNING]: raw module does not support the environment keyword
#
# TASK [bootstrap-os : Fetch /etc/os-release] ************************************
# ok: [control] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.2' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.2' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-1] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.4' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.4' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.4 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-2] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.5' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.5' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.5 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-3] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.6' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.6 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.6' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.6 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [dynamos] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.3' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.3' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.3 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# Wednesday 16 April 2025  08:26:19 +0000 (0:00:00.851)       0:00:01.027 *******
# Wednesday 16 April 2025  08:26:19 +0000 (0:00:00.067)       0:00:01.095 *******
#
# TASK [bootstrap-os : Include tasks] ********************************************
# included: /home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml for dynamos, worker-1, worker-2, worker-3, control => (item=/home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml)
# Wednesday 16 April 2025  08:26:19 +0000 (0:00:00.083)       0:00:01.178 *******
#
# TASK [bootstrap-os : Check if bootstrap is needed] *****************************
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.5 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.6 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.6 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [control] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# Wednesday 16 April 2025  08:26:20 +0000 (0:00:00.180)       0:00:01.358 *******
#
# TASK [bootstrap-os : Check http::proxy in apt configuration files] *************
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.5 closed."], "stdout": "", "stdout_lines": []}
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.6 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.6 closed."], "stdout": "", "stdout_lines": []}
# ok: [control] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "", "stdout_lines": []}
# Wednesday 16 April 2025  08:26:20 +0000 (0:00:00.188)       0:00:01.547 *******
# Wednesday 16 April 2025  08:26:20 +0000 (0:00:00.041)       0:00:01.589 *******
#
# TASK [bootstrap-os : Check https::proxy in apt configuration files] ************
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.5 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.6 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.6 closed."], "stdout": "", "stdout_lines": []}
# ok: [control] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "", "stdout_lines": []}
# Wednesday 16 April 2025  08:26:20 +0000 (0:00:00.180)       0:00:01.769 *******
# Wednesday 16 April 2025  08:26:20 +0000 (0:00:00.038)       0:00:01.808 *******
# Wednesday 16 April 2025  08:26:20 +0000 (0:00:00.033)       0:00:01.841 *******
# Wednesday 16 April 2025  08:26:20 +0000 (0:00:00.061)       0:00:01.903 *******
#
# TASK [bootstrap-os : Ensure iproute2 is installed] *****************************
# ok: [control] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744790948, "cache_updated": false, "changed": false}
# ok: [worker-2] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744790964, "cache_updated": false, "changed": false}
# ok: [worker-3] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744790970, "cache_updated": false, "changed": false}
# ok: [dynamos] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744790957, "cache_updated": false, "changed": false}
# ok: [worker-1] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744790973, "cache_updated": false, "changed": false}
# Wednesday 16 April 2025  08:26:22 +0000 (0:00:01.957)       0:00:03.861 *******
# Wednesday 16 April 2025  08:26:22 +0000 (0:00:00.033)       0:00:03.894 *******
# Wednesday 16 April 2025  08:26:22 +0000 (0:00:00.033)       0:00:03.928 *******
#
# TASK [bootstrap-os : Create remote_tmp for it is used by another module] *******
# changed: [control] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# changed: [worker-2] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# changed: [dynamos] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# changed: [worker-3] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# changed: [worker-1] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# Wednesday 16 April 2025  08:26:23 +0000 (0:00:00.541)       0:00:04.469 *******
#
# TASK [bootstrap-os : Gather facts] *********************************************
# ok: [worker-1]
# ok: [worker-2]
# ok: [dynamos]
# ok: [control]
# ok: [worker-3]
# Wednesday 16 April 2025  08:26:23 +0000 (0:00:00.838)       0:00:05.308 *******
#
# TASK [bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora)] ***
# ok: [control] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "control", "ansible_hostname": "control", "ansible_nodename": "control"}, "changed": false, "name": "control"}
# ok: [worker-1] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "worker-1", "ansible_hostname": "worker-1", "ansible_nodename": "worker-1"}, "changed": false, "name": "worker-1"}
# ok: [worker-2] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "worker-2", "ansible_hostname": "worker-2", "ansible_nodename": "worker-2"}, "changed": false, "name": "worker-2"}
# ok: [worker-3] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "worker-3", "ansible_hostname": "worker-3", "ansible_nodename": "worker-3"}, "changed": false, "name": "worker-3"}
# ok: [dynamos] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "dynamos", "ansible_hostname": "dynamos", "ansible_nodename": "dynamos"}, "changed": false, "name": "dynamos"}
# Wednesday 16 April 2025  08:26:25 +0000 (0:00:01.179)       0:00:06.487 *******
# Wednesday 16 April 2025  08:26:25 +0000 (0:00:00.050)       0:00:06.538 *******
#
# TASK [bootstrap-os : Ensure bash_completion.d folder exists] *******************
# ok: [worker-2] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-1] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [dynamos] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [control] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-3] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# Wednesday 16 April 2025  08:26:25 +0000 (0:00:00.400)       0:00:06.938 *******
#
# TASK [kubespray-defaults : Gather ansible_default_ipv4] ************************
# ok: [control]
# ok: [worker-2]
# ok: [worker-1]
# ok: [dynamos]
# ok: [worker-3]
# Wednesday 16 April 2025  08:26:26 +0000 (0:00:00.896)       0:00:07.834 *******
#
# TASK [kubespray-defaults : Set fallback_ip] ************************************
# ok: [dynamos] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-2] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-1] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-3] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [control] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# Wednesday 16 April 2025  08:26:26 +0000 (0:00:00.072)       0:00:07.906 *******
# Wednesday 16 April 2025  08:26:26 +0000 (0:00:00.017)       0:00:07.924 *******
# Wednesday 16 April 2025  08:26:26 +0000 (0:00:00.044)       0:00:07.968 *******
#
# PLAY [Gather facts] ************************************************************
# Wednesday 16 April 2025  08:26:26 +0000 (0:00:00.052)       0:00:08.021 *******
#
# TASK [Gather minimal facts] ****************************************************
# ok: [control]
# ok: [worker-1]
# ok: [dynamos]
# ok: [worker-2]
# ok: [worker-3]
# Wednesday 16 April 2025  08:26:27 +0000 (0:00:00.778)       0:00:08.800 *******
#
# TASK [Gather necessary facts (network)] ****************************************
# ok: [control]
# ok: [worker-2]
# ok: [worker-1]
# ok: [dynamos]
# ok: [worker-3]
# Wednesday 16 April 2025  08:26:28 +0000 (0:00:00.769)       0:00:09.569 *******
#
# TASK [Gather necessary facts (hardware)] ***************************************
# ok: [control]
# ok: [worker-1]
# ok: [worker-2]
# ok: [dynamos]
# ok: [worker-3]
#
# PLAY [Prepare for etcd install] ************************************************
# Wednesday 16 April 2025  08:26:29 +0000 (0:00:01.136)       0:00:10.705 *******
# Wednesday 16 April 2025  08:26:29 +0000 (0:00:00.047)       0:00:10.753 *******
# Wednesday 16 April 2025  08:26:29 +0000 (0:00:00.047)       0:00:10.800 *******
# Wednesday 16 April 2025  08:26:29 +0000 (0:00:00.018)       0:00:10.819 *******
# Wednesday 16 April 2025  08:26:29 +0000 (0:00:00.047)       0:00:10.867 *******
# Wednesday 16 April 2025  08:26:29 +0000 (0:00:00.055)       0:00:10.923 *******
#
# TASK [adduser : User | Create User Group] **************************************
# changed: [control] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# changed: [worker-1] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# changed: [worker-2] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# changed: [dynamos] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# changed: [worker-3] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# Wednesday 16 April 2025  08:26:30 +0000 (0:00:00.393)       0:00:11.316 *******
#
# TASK [adduser : User | Create User] ********************************************
# changed: [control] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# changed: [worker-2] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# changed: [worker-1] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# changed: [dynamos] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# changed: [worker-3] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# Wednesday 16 April 2025  08:26:30 +0000 (0:00:00.497)       0:00:11.814 *******
#
# TASK [kubernetes/preinstall : Check if /etc/fstab exists] **********************
# ok: [worker-2] => {"changed": false, "stat": {"atime": 1744790269.723, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [worker-1] => {"changed": false, "stat": {"atime": 1744790269.746, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [control] => {"changed": false, "stat": {"atime": 1744790267.677, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [worker-3] => {"changed": false, "stat": {"atime": 1744790274.648, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [dynamos] => {"changed": false, "stat": {"atime": 1744790268.668, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# Wednesday 16 April 2025  08:26:30 +0000 (0:00:00.394)       0:00:12.209 *******
#
# TASK [kubernetes/preinstall : Remove swapfile from /etc/fstab] *****************
# ok: [worker-2] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [worker-1] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [control] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [dynamos] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [worker-3] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [worker-2] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [worker-1] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [control] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [dynamos] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [worker-3] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# Wednesday 16 April 2025  08:26:31 +0000 (0:00:00.727)       0:00:12.936 *******
#
# TASK [kubernetes/preinstall : Mask swap.target (persist swapoff)] **************
# changed: [worker-2] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Wed 2025-04-16 07:59:38 UTC", "ActiveEnterTimestampMonotonic": "4517612", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Wed 2025-04-16 07:59:38 UTC", "AssertTimestampMonotonic": "4517610", "Before": "shutdown.target run-user-1000.mount sysinit.target", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Wed 2025-04-16 07:59:38 UTC", "ConditionTimestampMonotonic": "4517609", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Wed 2025-04-16 07:59:38 UTC", "InactiveExitTimestampMonotonic": "4517612", "InvocationID": "3bc11aee49ef4fbb949d66de26e5f2f7", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Wed 2025-04-16 07:59:38 UTC", "StateChangeTimestampMonotonic": "4517612", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# changed: [worker-1] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Wed 2025-04-16 07:59:40 UTC", "ActiveEnterTimestampMonotonic": "4691796", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Wed 2025-04-16 07:59:40 UTC", "AssertTimestampMonotonic": "4691792", "Before": "shutdown.target run-user-1000.mount sysinit.target", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Wed 2025-04-16 07:59:40 UTC", "ConditionTimestampMonotonic": "4691791", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Wed 2025-04-16 07:59:40 UTC", "InactiveExitTimestampMonotonic": "4691796", "InvocationID": "74b4faf9cbc944fcba6c0e873f3020bd", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Wed 2025-04-16 07:59:40 UTC", "StateChangeTimestampMonotonic": "4691796", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# changed: [control] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Wed 2025-04-16 07:59:31 UTC", "ActiveEnterTimestampMonotonic": "4069444", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Wed 2025-04-16 07:59:31 UTC", "AssertTimestampMonotonic": "4069441", "Before": "shutdown.target sysinit.target run-user-1000.mount", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Wed 2025-04-16 07:59:31 UTC", "ConditionTimestampMonotonic": "4069441", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Wed 2025-04-16 07:59:31 UTC", "InactiveExitTimestampMonotonic": "4069444", "InvocationID": "1e1d6e110c72413ab5bbae7ee522cacc", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Wed 2025-04-16 07:59:31 UTC", "StateChangeTimestampMonotonic": "4069444", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# changed: [worker-3] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Wed 2025-04-16 07:59:48 UTC", "ActiveEnterTimestampMonotonic": "4228073", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Wed 2025-04-16 07:59:48 UTC", "AssertTimestampMonotonic": "4228070", "Before": "run-user-1000.mount sysinit.target shutdown.target", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Wed 2025-04-16 07:59:48 UTC", "ConditionTimestampMonotonic": "4228069", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Wed 2025-04-16 07:59:48 UTC", "InactiveExitTimestampMonotonic": "4228073", "InvocationID": "0c94b8fc00454bcf804e3effb9aa9933", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Wed 2025-04-16 07:59:48 UTC", "StateChangeTimestampMonotonic": "4228073", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# changed: [dynamos] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Wed 2025-04-16 07:59:43 UTC", "ActiveEnterTimestampMonotonic": "5494673", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Wed 2025-04-16 07:59:43 UTC", "AssertTimestampMonotonic": "5494670", "Before": "sysinit.target run-user-1000.mount shutdown.target", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Wed 2025-04-16 07:59:43 UTC", "ConditionTimestampMonotonic": "5494669", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Wed 2025-04-16 07:59:43 UTC", "InactiveExitTimestampMonotonic": "5494673", "InvocationID": "32529b66622944faacdef884fe54e193", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Wed 2025-04-16 07:59:43 UTC", "StateChangeTimestampMonotonic": "5494673", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# Wednesday 16 April 2025  08:26:32 +0000 (0:00:00.845)       0:00:13.782 *******
#
# TASK [kubernetes/preinstall : Disable swap] ************************************
# changed: [worker-2] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.004305", "end": "2025-04-16 08:26:32.836532", "msg": "", "rc": 0, "start": "2025-04-16 08:26:32.832227", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [worker-1] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.007277", "end": "2025-04-16 08:26:32.832476", "msg": "", "rc": 0, "start": "2025-04-16 08:26:32.825199", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [dynamos] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.007354", "end": "2025-04-16 08:26:32.844644", "msg": "", "rc": 0, "start": "2025-04-16 08:26:32.837290", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [control] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.004157", "end": "2025-04-16 08:26:32.847854", "msg": "", "rc": 0, "start": "2025-04-16 08:26:32.843697", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [worker-3] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.007580", "end": "2025-04-16 08:26:32.845390", "msg": "", "rc": 0, "start": "2025-04-16 08:26:32.837810", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# Wednesday 16 April 2025  08:26:32 +0000 (0:00:00.400)       0:00:14.183 *******
# Wednesday 16 April 2025  08:26:32 +0000 (0:00:00.053)       0:00:14.237 *******
#
# TASK [kubernetes/preinstall : Check resolvconf] ********************************
# ok: [worker-2] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002627", "end": "2025-04-16 08:26:33.222775", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-16 08:26:33.220148", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [dynamos] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.004958", "end": "2025-04-16 08:26:33.218161", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-16 08:26:33.213203", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [worker-1] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.005158", "end": "2025-04-16 08:26:33.210191", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-16 08:26:33.205033", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [worker-3] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.004581", "end": "2025-04-16 08:26:33.243223", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-16 08:26:33.238642", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [control] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.003208", "end": "2025-04-16 08:26:33.261422", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-16 08:26:33.258214", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# Wednesday 16 April 2025  08:26:33 +0000 (0:00:00.356)       0:00:14.593 *******
#
# TASK [kubernetes/preinstall : Check existence of /etc/resolvconf/resolv.conf.d] ***
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ok: [control] => {"changed": false, "failed_when_result": false, "stat": {"exists": false}}
# ...
# [preflight] Reading configuration from the cluster...
# [preflight] FYI: You can look at this config file with 'kubectl -n kube-system get cm kubeadm-config -o yaml'
# [kubelet-start] Writing kubelet configuration to file \"/var/lib/kubelet/config.yaml\"
# [kubelet-start] Writing kubelet environment file with flags to file \"/var/lib/kubelet/kubeadm-flags.env\"
# [kubelet-start] Starting the kubelet
# [kubelet-check] Waiting for a healthy kubelet at http://127.0.0.1:10248/healthz. This can take up to 4m0s
# [kubelet-check] The kubelet is healthy after 501.601012ms
# [kubelet-start] Waiting for the kubelet to perform the TLS Bootstrap
#
# This node has joined the cluster:
# * Certificate signing request was sent to apiserver and a response was received.
# * The Kubelet was informed of the new secure connection details.
#
# Run 'kubectl get nodes' on the control-plane to see this node join the cluster.", "stdout_lines": ["[preflight] Running pre-flight checks", "[preflight] Reading configuration from the cluster...", "[preflight] FYI: You can look at this config file with 'kubectl -n kube-system get cm kubeadm-config -o yaml'", "[kubelet-start] Writing kubelet configuration to file \"/var/lib/kubelet/config.yaml\"", "[kubelet-start] Writing kubelet environment file with flags to file \"/var/lib/kubelet/kubeadm-flags.env\"", "[kubelet-start] Starting the kubelet", "[kubelet-check] Waiting for a healthy kubelet at http://127.0.0.1:10248/healthz. This can take up to 4m0s", "[kubelet-check] The kubelet is healthy after 501.601012ms", "[kubelet-start] Waiting for the kubelet to perform the TLS Bootstrap", "", "This node has joined the cluster:", "* Certificate signing request was sent to apiserver and a response was received.", "* The Kubelet was informed of the new secure connection details.", "", "Run 'kubectl get nodes' on the control-plane to see this node join the cluster."]}
# Wednesday 16 April 2025  08:44:04 +0000 (0:00:11.252)       0:17:46.242 *******
#
# TASK [kubernetes/kubeadm : Update server field in kubelet kubeconfig] **********
# changed: [dynamos] => {"backup": "/etc/kubernetes/kubelet.conf.25297.2025-04-16@08:44:05~", "changed": true, "msg": "line replaced"}
# changed: [worker-1] => {"backup": "/etc/kubernetes/kubelet.conf.25652.2025-04-16@08:44:05~", "changed": true, "msg": "line replaced"}
# changed: [worker-2] => {"backup": "/etc/kubernetes/kubelet.conf.25688.2025-04-16@08:44:05~", "changed": true, "msg": "line replaced"}
# changed: [worker-3] => {"backup": "/etc/kubernetes/kubelet.conf.25583.2025-04-16@08:44:05~", "changed": true, "msg": "line replaced"}
# Wednesday 16 April 2025  08:44:05 +0000 (0:00:00.505)       0:17:46.747 *******
# Wednesday 16 April 2025  08:44:05 +0000 (0:00:00.559)       0:17:47.307 *******
#
# TASK [kubernetes/kubeadm : Get current resourceVersion of kube-proxy configmap] ***
# changed: [dynamos -> control(10.145.3.2)] => {"changed": true, "cmd": ["/usr/local/bin/kubectl", "--kubeconfig", "/etc/kubernetes/admin.conf", "get", "configmap", "kube-proxy", "-n", "kube-system", "-o", "jsonpath={.metadata.resourceVersion}"], "delta": "0:00:00.061384", "end": "2025-04-16 08:44:06.273443", "msg": "", "rc": 0, "start": "2025-04-16 08:44:06.212059", "stderr": "", "stderr_lines": [], "stdout": "268", "stdout_lines": ["268"]}
# Wednesday 16 April 2025  08:44:06 +0000 (0:00:00.331)       0:17:47.638 *******
#
# TASK [kubernetes/kubeadm : Update server field in kube-proxy kubeconfig] *******
# changed: [dynamos -> control(10.145.3.2)] => {"changed": true, "cmd": "set -o pipefail && /usr/local/bin/kubectl --kubeconfig /etc/kubernetes/admin.conf get configmap kube-proxy -n kube-system -o yaml | sed 's#server:.*#server: https://127.0.0.1:6443#g' | /usr/local/bin/kubectl --kubeconfig /etc/kubernetes/admin.conf replace -f -", "delta": "0:00:00.207835", "end": "2025-04-16 08:44:06.832597", "msg": "", "rc": 0, "start": "2025-04-16 08:44:06.624762", "stderr": "", "stderr_lines": [], "stdout": "configmap/kube-proxy replaced", "stdout_lines": ["configmap/kube-proxy replaced"]}
# Wednesday 16 April 2025  08:44:06 +0000 (0:00:00.556)       0:17:48.194 *******
# Wednesday 16 April 2025  08:44:06 +0000 (0:00:00.078)       0:17:48.273 *******
#
# TASK [kubernetes/kubeadm : Get new resourceVersion of kube-proxy configmap] ****
# changed: [dynamos -> control(10.145.3.2)] => {"changed": true, "cmd": ["/usr/local/bin/kubectl", "--kubeconfig", "/etc/kubernetes/admin.conf", "get", "configmap", "kube-proxy", "-n", "kube-system", "-o", "jsonpath={.metadata.resourceVersion}"], "delta": "0:00:00.070775", "end": "2025-04-16 08:44:07.233089", "msg": "", "rc": 0, "start": "2025-04-16 08:44:07.162314", "stderr": "", "stderr_lines": [], "stdout": "569", "stdout_lines": ["569"]}
# Wednesday 16 April 2025  08:44:07 +0000 (0:00:00.323)       0:17:48.596 *******
#
# TASK [kubernetes/kubeadm : Set ca.crt file permission] *************************
# ok: [dynamos] => {"changed": false, "gid": 0, "group": "root", "mode": "0644", "owner": "root", "path": "/etc/kubernetes/ssl/ca.crt", "size": 1107, "state": "file", "uid": 0}
# ok: [worker-1] => {"changed": false, "gid": 0, "group": "root", "mode": "0644", "owner": "root", "path": "/etc/kubernetes/ssl/ca.crt", "size": 1107, "state": "file", "uid": 0}
# ok: [worker-2] => {"changed": false, "gid": 0, "group": "root", "mode": "0644", "owner": "root", "path": "/etc/kubernetes/ssl/ca.crt", "size": 1107, "state": "file", "uid": 0}
# ok: [worker-3] => {"changed": false, "gid": 0, "group": "root", "mode": "0644", "owner": "root", "path": "/etc/kubernetes/ssl/ca.crt", "size": 1107, "state": "file", "uid": 0}
# ok: [control] => {"changed": false, "gid": 0, "group": "root", "mode": "0644", "owner": "root", "path": "/etc/kubernetes/ssl/ca.crt", "size": 1107, "state": "file", "uid": 0}
# Wednesday 16 April 2025  08:44:07 +0000 (0:00:00.364)       0:17:48.961 *******
#
# TASK [kubernetes/kubeadm : Restart all kube-proxy pods to ensure that they load the new configmap] ***
# changed: [dynamos -> control(10.145.3.2)] => {"changed": true, "cmd": ["/usr/local/bin/kubectl", "--kubeconfig", "/etc/kubernetes/admin.conf", "delete", "pod", "-n", "kube-system", "-l", "k8s-app=kube-proxy", "--force", "--grace-period=0"], "delta": "0:00:00.157598", "end": "2025-04-16 08:44:08.216278", "msg": "", "rc": 0, "start": "2025-04-16 08:44:08.058680", "stderr": "Warning: Immediate deletion does not wait for confirmation that the running resource has been terminated. The resource may continue to run on the cluster indefinitely.", "stderr_lines": ["Warning: Immediate deletion does not wait for confirmation that the running resource has been terminated. The resource may continue to run on the cluster indefinitely."], "stdout": "pod \"kube-proxy-2788v\" force deleted
# pod \"kube-proxy-6bqk5\" force deleted
# pod \"kube-proxy-ggf2k\" force deleted
# pod \"kube-proxy-p2d95\" force deleted
# pod \"kube-proxy-pb4px\" force deleted", "stdout_lines": ["pod \"kube-proxy-2788v\" force deleted", "pod \"kube-proxy-6bqk5\" force deleted", "pod \"kube-proxy-ggf2k\" force deleted", "pod \"kube-proxy-p2d95\" force deleted", "pod \"kube-proxy-pb4px\" force deleted"]}
# Wednesday 16 April 2025  08:44:08 +0000 (0:00:00.633)       0:17:49.594 *******
# Wednesday 16 April 2025  08:44:08 +0000 (0:00:00.546)       0:17:50.140 *******
#
# TASK [kubernetes/node-label : Kubernetes Apps | Wait for kube-apiserver] *******
# ok: [control] => {"attempts": 1, "audit_id": "209a8e9b-085d-4c3a-a5a4-05330cde3a93", "cache_control": "no-cache, private", "changed": false, "connection": "close", "content_length": "2", "content_type": "text/plain; charset=utf-8", "cookies": {}, "cookies_string": "", "date": "Wed, 16 Apr 2025 08:44:09 GMT", "elapsed": 0, "msg": "OK (2 bytes)", "redirected": false, "status": 200, "url": "https://127.0.0.1:6443/healthz", "x_content_type_options": "nosniff", "x_kubernetes_pf_flowschema_uid": "4ca879c4-9dbe-474c-8e78-26270276ba61", "x_kubernetes_pf_prioritylevel_uid": "4b464558-7b1e-4576-bf9d-be3cfbf43442"}
# Wednesday 16 April 2025  08:44:09 +0000 (0:00:00.715)       0:17:50.856 *******
#
# TASK [kubernetes/node-label : Set role node label to empty list] ***************
# ok: [dynamos] => {"ansible_facts": {"role_node_labels": []}, "changed": false}
# ok: [worker-1] => {"ansible_facts": {"role_node_labels": []}, "changed": false}
# ok: [worker-2] => {"ansible_facts": {"role_node_labels": []}, "changed": false}
# ok: [worker-3] => {"ansible_facts": {"role_node_labels": []}, "changed": false}
# ok: [control] => {"ansible_facts": {"role_node_labels": []}, "changed": false}
# Wednesday 16 April 2025  08:44:09 +0000 (0:00:00.240)       0:17:51.096 *******
# Wednesday 16 April 2025  08:44:09 +0000 (0:00:00.209)       0:17:51.306 *******
#
# TASK [kubernetes/node-label : Set inventory node label to empty list] **********
# ok: [dynamos] => {"ansible_facts": {"inventory_node_labels": []}, "changed": false}
# ok: [worker-1] => {"ansible_facts": {"inventory_node_labels": []}, "changed": false}
# ok: [worker-2] => {"ansible_facts": {"inventory_node_labels": []}, "changed": false}
# ok: [worker-3] => {"ansible_facts": {"inventory_node_labels": []}, "changed": false}
# ok: [control] => {"ansible_facts": {"inventory_node_labels": []}, "changed": false}
# Wednesday 16 April 2025  08:44:10 +0000 (0:00:00.392)       0:17:51.698 *******
# Wednesday 16 April 2025  08:44:10 +0000 (0:00:00.214)       0:17:51.913 *******
#
# TASK [kubernetes/node-label : debug] *******************************************
# ok: [dynamos] => {
#     "role_node_labels": []
# }
# ok: [worker-1] => {
#     "role_node_labels": []
# }
# ok: [worker-2] => {
#     "role_node_labels": []
# }
# ok: [worker-3] => {
#     "role_node_labels": []
# }
# ok: [control] => {
#     "role_node_labels": []
# }
# Wednesday 16 April 2025  08:44:10 +0000 (0:00:00.208)       0:17:52.121 *******
#
# TASK [kubernetes/node-label : debug] *******************************************
# ok: [dynamos] => {
#     "inventory_node_labels": []
# }
# ok: [worker-1] => {
#     "inventory_node_labels": []
# }
# ok: [worker-2] => {
#     "inventory_node_labels": []
# }
# ok: [worker-3] => {
#     "inventory_node_labels": []
# }
# ok: [control] => {
#     "inventory_node_labels": []
# }
# Wednesday 16 April 2025  08:44:11 +0000 (0:00:00.408)       0:17:52.529 *******
# Wednesday 16 April 2025  08:44:11 +0000 (0:00:00.316)       0:17:52.845 *******
#
# TASK [kubernetes/node-taint : Set role and inventory node taint to empty list] ***
# ok: [dynamos] => {"ansible_facts": {"inventory_node_taints": [], "role_node_taints": []}, "changed": false}
# ok: [worker-1] => {"ansible_facts": {"inventory_node_taints": [], "role_node_taints": []}, "changed": false}
# ok: [worker-2] => {"ansible_facts": {"inventory_node_taints": [], "role_node_taints": []}, "changed": false}
# ok: [worker-3] => {"ansible_facts": {"inventory_node_taints": [], "role_node_taints": []}, "changed": false}
# ok: [control] => {"ansible_facts": {"inventory_node_taints": [], "role_node_taints": []}, "changed": false}
# Wednesday 16 April 2025  08:44:11 +0000 (0:00:00.395)       0:17:53.241 *******
# Wednesday 16 April 2025  08:44:12 +0000 (0:00:00.217)       0:17:53.458 *******
# Wednesday 16 April 2025  08:44:12 +0000 (0:00:00.369)       0:17:53.827 *******
#
# TASK [kubernetes/node-taint : debug] *******************************************
# ok: [dynamos] => {
#     "role_node_taints": []
# }
# ok: [worker-1] => {
#     "role_node_taints": []
# }
# ok: [worker-2] => {
#     "role_node_taints": []
# }
# ok: [worker-3] => {
#     "role_node_taints": []
# }
# ok: [control] => {
#     "role_node_taints": []
# }
# Wednesday 16 April 2025  08:44:12 +0000 (0:00:00.241)       0:17:54.069 *******
#
# TASK [kubernetes/node-taint : debug] *******************************************
# ok: [dynamos] => {
#     "inventory_node_taints": []
# }
# ok: [worker-1] => {
#     "inventory_node_taints": []
# }
# ok: [worker-2] => {
#     "inventory_node_taints": []
# }
# ok: [worker-3] => {
#     "inventory_node_taints": []
# }
# ok: [control] => {
#     "inventory_node_taints": []
# }
# Wednesday 16 April 2025  08:44:13 +0000 (0:00:00.248)       0:17:54.318 *******
# Wednesday 16 April 2025  08:44:13 +0000 (0:00:00.620)       0:17:54.938 *******
#
# TASK [network_plugin/cni : CNI | make sure /opt/cni/bin exists] ****************
# changed: [dynamos] => {"changed": true, "gid": 0, "group": "root", "mode": "0755", "owner": "kube", "path": "/opt/cni/bin", "size": 4096, "state": "directory", "uid": 997}
# changed: [worker-2] => {"changed": true, "gid": 0, "group": "root", "mode": "0755", "owner": "kube", "path": "/opt/cni/bin", "size": 4096, "state": "directory", "uid": 997}
# changed: [worker-1] => {"changed": true, "gid": 0, "group": "root", "mode": "0755", "owner": "kube", "path": "/opt/cni/bin", "size": 4096, "state": "directory", "uid": 997}
# changed: [control] => {"changed": true, "gid": 0, "group": "root", "mode": "0755", "owner": "kube", "path": "/opt/cni/bin", "size": 4096, "state": "directory", "uid": 997}
# changed: [worker-3] => {"changed": true, "gid": 0, "group": "root", "mode": "0755", "owner": "kube", "path": "/opt/cni/bin", "size": 4096, "state": "directory", "uid": 997}
# Wednesday 16 April 2025  08:44:14 +0000 (0:00:00.409)       0:17:55.347 *******
#
# TASK [network_plugin/cni : CNI | Copy cni plugins] *****************************
# changed: [dynamos] => {"changed": true, "dest": "/opt/cni/bin", "extract_results": {"cmd": ["/usr/bin/tar", "--extract", "-C", "/opt/cni/bin", "-z", "--owner=kube", "-f", "/tmp/releases/cni-plugins-linux-amd64-v1.4.1.tgz"], "err": "", "out": "", "rc": 0}, "gid": 0, "group": "root", "handler": "TgzArchive", "mode": "0755", "owner": "kube", "size": 4096, "src": "/tmp/releases/cni-plugins-linux-amd64-v1.4.1.tgz", "state": "directory", "uid": 997}
# changed: [worker-2] => {"changed": true, "dest": "/opt/cni/bin", "extract_results": {"cmd": ["/usr/bin/tar", "--extract", "-C", "/opt/cni/bin", "-z", "--owner=kube", "-f", "/tmp/releases/cni-plugins-linux-amd64-v1.4.1.tgz"], "err": "", "out": "", "rc": 0}, "gid": 0, "group": "root", "handler": "TgzArchive", "mode": "0755", "owner": "kube", "size": 4096, "src": "/tmp/releases/cni-plugins-linux-amd64-v1.4.1.tgz", "state": "directory", "uid": 997}
# changed: [worker-3] => {"changed": true, "dest": "/opt/cni/bin", "extract_results": {"cmd": ["/usr/bin/tar", "--extract", "-C", "/opt/cni/bin", "-z", "--owner=kube", "-f", "/tmp/releases/cni-plugins-linux-amd64-v1.4.1.tgz"], "err": "", "out": "", "rc": 0}, "gid": 0, "group": "root", "handler": "TgzArchive", "mode": "0755", "owner": "kube", "size": 4096, "src": "/tmp/releases/cni-plugins-linux-amd64-v1.4.1.tgz", "state": "directory", "uid": 997}
# changed: [control] => {"changed": true, "dest": "/opt/cni/bin", "extract_results": {"cmd": ["/usr/bin/tar", "--extract", "-C", "/opt/cni/bin", "-z", "--owner=kube", "-f", "/tmp/releases/cni-plugins-linux-amd64-v1.4.1.tgz"], "err": "", "out": "", "rc": 0}, "gid": 0, "group": "root", "handler": "TgzArchive", "mode": "0755", "owner": "kube", "size": 4096, "src": "/tmp/releases/cni-plugins-linux-amd64-v1.4.1.tgz", "state": "directory", "uid": 997}
# changed: [worker-1] => {"changed": true, "dest": "/opt/cni/bin", "extract_results": {"cmd": ["/usr/bin/tar", "--extract", "-C", "/opt/cni/bin", "-z", "--owner=kube", "-f", "/tmp/releases/cni-plugins-linux-amd64-v1.4.1.tgz"], "err": "", "out": "", "rc": 0}, "gid": 0, "group": "root", "handler": "TgzArchive", "mode": "0755", "owner": "kube", "size": 4096, "src": "/tmp/releases/cni-plugins-linux-amd64-v1.4.1.tgz", "state": "directory", "uid": 997}
# Wednesday 16 April 2025  08:44:17 +0000 (0:00:03.023)       0:17:58.371 *******
# Wednesday 16 April 2025  08:44:17 +0000 (0:00:00.208)       0:17:58.579 *******
# Wednesday 16 April 2025  08:44:17 +0000 (0:00:00.370)       0:17:58.950 *******
# Wednesday 16 April 2025  08:44:17 +0000 (0:00:00.214)       0:17:59.165 *******

# %%
# nodes[0].upload_file(local_file_path="node_scripts/reset_kubespray.sh", remote_file_path="reset.sh");
# nodes[0].execute(f"chmod +x reset.sh && ./reset.sh");
