# %%
import datetime
import json
import asyncio

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()

fablib.show_config();
# Out:
# <style type="text/css">
# #T_0e467 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0e467 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0e467 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_0e467_row0_col0, #T_0e467_row0_col1, #T_0e467_row1_col0, #T_0e467_row1_col1, #T_0e467_row2_col0, #T_0e467_row2_col1, #T_0e467_row3_col0, #T_0e467_row3_col1, #T_0e467_row4_col0, #T_0e467_row4_col1, #T_0e467_row5_col0, #T_0e467_row5_col1, #T_0e467_row6_col0, #T_0e467_row6_col1, #T_0e467_row7_col0, #T_0e467_row7_col1, #T_0e467_row8_col0, #T_0e467_row8_col1, #T_0e467_row9_col0, #T_0e467_row9_col1, #T_0e467_row10_col0, #T_0e467_row10_col1, #T_0e467_row11_col0, #T_0e467_row11_col1, #T_0e467_row12_col0, #T_0e467_row12_col1, #T_0e467_row13_col0, #T_0e467_row13_col1, #T_0e467_row14_col0, #T_0e467_row14_col1, #T_0e467_row15_col0, #T_0e467_row15_col1, #T_0e467_row16_col0, #T_0e467_row16_col1, #T_0e467_row17_col0, #T_0e467_row17_col1, #T_0e467_row18_col0, #T_0e467_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_0e467">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0e467_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_0e467_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_0e467_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_0e467_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_0e467_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_0e467_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_0e467_row5_col1" class="data row5 col1" >49f65ad7-d8a2-4ab9-8ca0-ba777a2e0ea2</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_0e467_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_0e467_row7_col1" class="data row7 col1" >jakejongejans_0000313927</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_0e467_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_0e467_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_0e467_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_0e467_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_0e467_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_0e467_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_0e467_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_0e467_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row16_col0" class="data row16 col0" >Version</td>
#       <td id="T_0e467_row16_col1" class="data row16 col1" >1.8.0</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row17_col0" class="data row17 col0" >Data directory</td>
#       <td id="T_0e467_row17_col1" class="data row17 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_0e467_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_0e467_row18_col1" class="data row18 col1" >DYNAMOS project Energy Efficiency</td>
#     </tr>
#   </tbody>
# </table>

# %%
slice = fablib.get_slice(name="DYNAMOS-on-FABRIC");
nodes = slice.get_nodes();

# %%
nodes[0].upload_file(local_file_path="node_scripts/start_kubespray.sh", remote_file_path="start.sh");
nodes[0].execute(f"chmod +x start.sh && ./start.sh");
# Out:
# Using /home/ubuntu/kubespray/ansible.cfg as config file
#
# PLAY [Check Ansible version] ***************************************************
# Monday 07 April 2025  13:14:47 +0000 (0:00:00.008)       0:00:00.008 **********
#  [WARNING]: While constructing a mapping from
# /home/ubuntu/kubespray/roles/bootstrap-os/tasks/main.yml, line 29, column 7,
# found a duplicate dict key (paths). Using last defined value only.
# [WARNING]: Skipping callback plugin 'ara_default', unable to load
#
# TASK [Check 2.16.4 <= Ansible version < 2.17.0] ********************************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Monday 07 April 2025  13:14:47 +0000 (0:00:00.017)       0:00:00.025 **********
#
# TASK [Check that python netaddr is installed] **********************************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Monday 07 April 2025  13:14:47 +0000 (0:00:00.048)       0:00:00.074 **********
#
# TASK [Check that jinja is not too old (install via pip)] ***********************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
#
# PLAY [Define groups for legacy less structured inventories] ********************
# Monday 07 April 2025  13:14:47 +0000 (0:00:00.015)       0:00:00.090 **********
#  [WARNING]: Could not match supplied host pattern, ignoring: bastion
#   [WARNING]: Could not match supplied host pattern, ignoring: calico_rr
#
# TASK [Match needed groups by their old names or definition] ********************
# changed: [node2] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node2] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [node3] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node3] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [node1] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node1] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
#
# PLAY [Install bastion ssh config] **********************************************
# skipping: no hosts matched
#
# PLAY [Bootstrap hosts for Ansible] *********************************************
# Monday 07 April 2025  13:14:47 +0000 (0:00:00.080)       0:00:00.171 **********
#  [WARNING]: raw module does not support the environment keyword
#
# TASK [bootstrap-os : Fetch /etc/os-release] ************************************
# fatal: [node2]: UNREACHABLE! => {"changed": false, "msg": "Failed to connect to the host via ssh: ssh: Could not resolve hostname node2: Temporary failure in name resolution", "unreachable": true}
# fatal: [node3]: UNREACHABLE! => {"changed": false, "msg": "Failed to connect to the host via ssh: ssh: Could not resolve hostname node3: Temporary failure in name resolution", "unreachable": true}
# ok: [node1] => {"changed": false, "rc": 0, "stderr": "Shared connection to 10.145.1.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
#
# NO MORE HOSTS LEFT *************************************************************
#
# PLAY RECAP *********************************************************************
# node1                      : ok=2    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# node2                      : ok=4    changed=1    unreachable=1    failed=0    skipped=0    rescued=0    ignored=0
# node3                      : ok=1    changed=1    unreachable=1    failed=0    skipped=0    rescued=0    ignored=0
#
# Monday 07 April 2025  13:14:47 +0000 (0:00:00.174)       0:00:00.345 **********
# ===============================================================================
# bootstrap-os : Fetch /etc/os-release ------------------------------------ 0.17s
# Match needed groups by their old names or definition -------------------- 0.08s
# Check that python netaddr is installed ---------------------------------- 0.05s
# Check 2.16.4 <= Ansible version < 2.17.0 -------------------------------- 0.02s
# Check that jinja is not too old (install via pip) ----------------------- 0.02s

# %%
nodes[0].upload_file(local_file_path="node_scripts/reset_kubespray.sh", remote_file_path="reset.sh");
nodes[0].execute(f"chmod +x reset.sh && ./reset.sh");
# Out:
# Using /home/ubuntu/kubespray/ansible.cfg as config file
#
# PLAY [Check Ansible version] ***************************************************
# Monday 07 April 2025  13:13:00 +0000 (0:00:00.008)       0:00:00.008 **********
#  [WARNING]: While constructing a mapping from
# /home/ubuntu/kubespray/roles/bootstrap-os/tasks/main.yml, line 29, column 7,
# found a duplicate dict key (paths). Using last defined value only.
# [WARNING]: Skipping callback plugin 'ara_default', unable to load
#
# TASK [Check 2.16.4 <= Ansible version < 2.17.0] ********************************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Monday 07 April 2025  13:13:00 +0000 (0:00:00.016)       0:00:00.025 **********
#
# TASK [Check that python netaddr is installed] **********************************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Monday 07 April 2025  13:13:00 +0000 (0:00:00.046)       0:00:00.071 **********
#
# TASK [Check that jinja is not too old (install via pip)] ***********************
# ok: [node2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
#
# PLAY [Define groups for legacy less structured inventories] ********************
# Monday 07 April 2025  13:13:00 +0000 (0:00:00.014)       0:00:00.085 **********
#  [WARNING]: Could not match supplied host pattern, ignoring: bastion
#   [WARNING]: Could not match supplied host pattern, ignoring: calico_rr
#
# TASK [Match needed groups by their old names or definition] ********************
# changed: [node2] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node2] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node2] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [node3] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node3] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node3] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [node1] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [node1] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [node1] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
#
# PLAY [Install bastion ssh config] **********************************************
# skipping: no hosts matched
#
# PLAY [Bootstrap hosts for Ansible] *********************************************
# Monday 07 April 2025  13:13:00 +0000 (0:00:00.080)       0:00:00.166 **********
#  [WARNING]: raw module does not support the environment keyword
#
# TASK [bootstrap-os : Fetch /etc/os-release] ************************************
# fatal: [node2]: UNREACHABLE! => {"changed": false, "msg": "Failed to connect to the host via ssh: ssh: Could not resolve hostname node2: Temporary failure in name resolution", "unreachable": true}
# fatal: [node3]: UNREACHABLE! => {"changed": false, "msg": "Failed to connect to the host via ssh: ssh: Could not resolve hostname node3: Temporary failure in name resolution", "unreachable": true}
# ok: [node1] => {"changed": false, "rc": 0, "stderr": "Shared connection to 10.145.1.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.1.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
#
# NO MORE HOSTS LEFT *************************************************************
#
# PLAY RECAP *********************************************************************
# node1                      : ok=2    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# node2                      : ok=4    changed=1    unreachable=1    failed=0    skipped=0    rescued=0    ignored=0
# node3                      : ok=1    changed=1    unreachable=1    failed=0    skipped=0    rescued=0    ignored=0
#
# Monday 07 April 2025  13:13:00 +0000 (0:00:00.174)       0:00:00.341 **********
# ===============================================================================
# bootstrap-os : Fetch /etc/os-release ------------------------------------ 0.17s
# Match needed groups by their old names or definition -------------------- 0.08s
# Check that python netaddr is installed ---------------------------------- 0.05s
# Check 2.16.4 <= Ansible version < 2.17.0 -------------------------------- 0.02s
# Check that jinja is not too old (install via pip) ----------------------- 0.01s
