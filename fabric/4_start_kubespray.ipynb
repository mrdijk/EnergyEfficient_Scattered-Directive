# %%
import datetime
import json
import asyncio

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()

fablib.show_config();
# Out:
# <style type="text/css">
# #T_22525 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_22525 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_22525 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_22525_row0_col0, #T_22525_row0_col1, #T_22525_row1_col0, #T_22525_row1_col1, #T_22525_row2_col0, #T_22525_row2_col1, #T_22525_row3_col0, #T_22525_row3_col1, #T_22525_row4_col0, #T_22525_row4_col1, #T_22525_row5_col0, #T_22525_row5_col1, #T_22525_row6_col0, #T_22525_row6_col1, #T_22525_row7_col0, #T_22525_row7_col1, #T_22525_row8_col0, #T_22525_row8_col1, #T_22525_row9_col0, #T_22525_row9_col1, #T_22525_row10_col0, #T_22525_row10_col1, #T_22525_row11_col0, #T_22525_row11_col1, #T_22525_row12_col0, #T_22525_row12_col1, #T_22525_row13_col0, #T_22525_row13_col1, #T_22525_row14_col0, #T_22525_row14_col1, #T_22525_row15_col0, #T_22525_row15_col1, #T_22525_row16_col0, #T_22525_row16_col1, #T_22525_row17_col0, #T_22525_row17_col1, #T_22525_row18_col0, #T_22525_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_22525">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_22525_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_22525_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_22525_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_22525_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_22525_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_22525_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_22525_row5_col1" class="data row5 col1" >49f65ad7-d8a2-4ab9-8ca0-ba777a2e0ea2</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_22525_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_22525_row7_col1" class="data row7 col1" >jakejongejans_0000313927</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_22525_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_22525_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_22525_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_22525_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_22525_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_22525_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_22525_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_22525_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_22525_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row16_col0" class="data row16 col0" >Version</td>
#       <td id="T_22525_row16_col1" class="data row16 col1" >1.8.0</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row17_col0" class="data row17 col0" >Data directory</td>
#       <td id="T_22525_row17_col1" class="data row17 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_22525_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_22525_row18_col1" class="data row18 col1" >DYNAMOS project</td>
#     </tr>
#   </tbody>
# </table>

# %%
slice = fablib.get_slice(name="DYNAMOS-on-FABRIC");
nodes = slice.get_nodes();

# %%
nodes[0].upload_file(local_file_path="node_scripts/start_kubespray.sh", remote_file_path="start.sh");
nodes[0].execute(f"chmod +x start.sh && ./start.sh");
# Out:
# Using /home/ubuntu/kubespray/ansible.cfg as config file
#
# PLAY [Check Ansible version] ***************************************************
# Tuesday 15 April 2025  15:02:18 +0000 (0:00:00.008)       0:00:00.008 *********
#
# TASK [Check 2.16.4 <= Ansible version < 2.17.0] ********************************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Tuesday 15 April 2025  15:02:18 +0000 (0:00:00.020)       0:00:00.028 *********
#  [WARNING]: While constructing a mapping from
# /home/ubuntu/kubespray/roles/bootstrap-os/tasks/main.yml, line 29, column 7,
# found a duplicate dict key (paths). Using last defined value only.
# [WARNING]: Skipping callback plugin 'ara_default', unable to load
#
# TASK [Check that python netaddr is installed] **********************************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Tuesday 15 April 2025  15:02:18 +0000 (0:00:00.078)       0:00:00.106 *********
#
# TASK [Check that jinja is not too old (install via pip)] ***********************
# ok: [dynamos] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
#
# PLAY [Define groups for legacy less structured inventories] ********************
# Tuesday 15 April 2025  15:02:18 +0000 (0:00:00.023)       0:00:00.130 *********
#  [WARNING]: Could not match supplied host pattern, ignoring: bastion
#   [WARNING]: Could not match supplied host pattern, ignoring: calico_rr
#
# TASK [Match needed groups by their old names or definition] ********************
# changed: [dynamos] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [dynamos] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [dynamos] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-1] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-1] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-1] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-2] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-2] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-3] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-3] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [control] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [control] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
#
# PLAY [Install bastion ssh config] **********************************************
# skipping: no hosts matched
#
# PLAY [Bootstrap hosts for Ansible] *********************************************
# Tuesday 15 April 2025  15:02:18 +0000 (0:00:00.108)       0:00:00.239 *********
#  [WARNING]: raw module does not support the environment keyword
#
# TASK [bootstrap-os : Fetch /etc/os-release] ************************************
# ok: [control] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.2' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.2' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [dynamos] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.3' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.3' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.3 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-2] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.5' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.5' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.5 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-3] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.6' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.6 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.6' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.6 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-1] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.4' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.4' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.4 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# Tuesday 15 April 2025  15:02:19 +0000 (0:00:00.871)       0:00:01.110 *********
# Tuesday 15 April 2025  15:02:19 +0000 (0:00:00.081)       0:00:01.192 *********
#
# TASK [bootstrap-os : Include tasks] ********************************************
# included: /home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml for dynamos, worker-1, worker-2, worker-3, control => (item=/home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml)
# Tuesday 15 April 2025  15:02:19 +0000 (0:00:00.107)       0:00:01.299 *********
#
# TASK [bootstrap-os : Check if bootstrap is needed] *****************************
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.5 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.6 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.6 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [control] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# Tuesday 15 April 2025  15:02:19 +0000 (0:00:00.207)       0:00:01.507 *********
#
# TASK [bootstrap-os : Check http::proxy in apt configuration files] *************
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.5 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.6 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.6 closed."], "stdout": "", "stdout_lines": []}
# ok: [control] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "", "stdout_lines": []}
# Tuesday 15 April 2025  15:02:19 +0000 (0:00:00.218)       0:00:01.725 *********
# Tuesday 15 April 2025  15:02:19 +0000 (0:00:00.057)       0:00:01.782 *********
#
# TASK [bootstrap-os : Check https::proxy in apt configuration files] ************
# ok: [dynamos] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-1] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.5 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.6 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.6 closed."], "stdout": "", "stdout_lines": []}
# ok: [control] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "", "stdout_lines": []}
# Tuesday 15 April 2025  15:02:20 +0000 (0:00:00.202)       0:00:01.985 *********
# Tuesday 15 April 2025  15:02:20 +0000 (0:00:00.074)       0:00:02.059 *********
# Tuesday 15 April 2025  15:02:20 +0000 (0:00:00.046)       0:00:02.105 *********
# Tuesday 15 April 2025  15:02:20 +0000 (0:00:00.078)       0:00:02.183 *********
#
# TASK [bootstrap-os : Ensure iproute2 is installed] *****************************
# ok: [worker-2] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744729002, "cache_updated": false, "changed": false}
# ok: [worker-1] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744728882, "cache_updated": false, "changed": false}
# ok: [dynamos] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744728887, "cache_updated": false, "changed": false}
# ok: [worker-3] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744729071, "cache_updated": false, "changed": false}
# ok: [control] => {"ansible_facts": {"discovered_interpreter_python": "/usr/bin/python3"}, "cache_update_time": 1744728890, "cache_updated": false, "changed": false}
# Tuesday 15 April 2025  15:02:22 +0000 (0:00:01.932)       0:00:04.116 *********
# Tuesday 15 April 2025  15:02:22 +0000 (0:00:00.049)       0:00:04.165 *********
# Tuesday 15 April 2025  15:02:22 +0000 (0:00:00.048)       0:00:04.214 *********
#
# TASK [bootstrap-os : Create remote_tmp for it is used by another module] *******
# changed: [worker-3] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# changed: [dynamos] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# changed: [worker-2] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# changed: [control] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# changed: [worker-1] => {"changed": true, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# Tuesday 15 April 2025  15:02:22 +0000 (0:00:00.599)       0:00:04.813 *********
#
# TASK [bootstrap-os : Gather facts] *********************************************
# ok: [worker-2]
# ok: [worker-1]
# ok: [dynamos]
# ok: [worker-3]
# ok: [control]
# Tuesday 15 April 2025  15:02:23 +0000 (0:00:00.866)       0:00:05.680 *********
#
# TASK [bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora)] ***
# ok: [dynamos] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "dynamos", "ansible_hostname": "dynamos", "ansible_nodename": "dynamos"}, "changed": false, "name": "dynamos"}
# ok: [worker-3] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "worker-3", "ansible_hostname": "worker-3", "ansible_nodename": "worker-3"}, "changed": false, "name": "worker-3"}
# ok: [worker-2] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "worker-2", "ansible_hostname": "worker-2", "ansible_nodename": "worker-2"}, "changed": false, "name": "worker-2"}
# ok: [worker-1] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "worker-1", "ansible_hostname": "worker-1", "ansible_nodename": "worker-1"}, "changed": false, "name": "worker-1"}
# ok: [control] => {"ansible_facts": {"ansible_domain": "", "ansible_fqdn": "control", "ansible_hostname": "control", "ansible_nodename": "control"}, "changed": false, "name": "control"}
# Tuesday 15 April 2025  15:02:24 +0000 (0:00:01.152)       0:00:06.833 *********
# Tuesday 15 April 2025  15:02:24 +0000 (0:00:00.067)       0:00:06.900 *********
#
# TASK [bootstrap-os : Ensure bash_completion.d folder exists] *******************
# ok: [dynamos] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-1] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-3] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-2] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [control] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# Tuesday 15 April 2025  15:02:25 +0000 (0:00:00.430)       0:00:07.331 *********
#
# TASK [kubespray-defaults : Gather ansible_default_ipv4] ************************
# ok: [dynamos]
# ok: [worker-2]
# ok: [worker-3]
# ok: [worker-1]
# ok: [control]
# Tuesday 15 April 2025  15:02:26 +0000 (0:00:00.883)       0:00:08.214 *********
#
# TASK [kubespray-defaults : Set fallback_ip] ************************************
# ok: [dynamos] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-2] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-1] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-3] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [control] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# Tuesday 15 April 2025  15:02:26 +0000 (0:00:00.090)       0:00:08.304 *********
# Tuesday 15 April 2025  15:02:26 +0000 (0:00:00.023)       0:00:08.328 *********
# Tuesday 15 April 2025  15:02:26 +0000 (0:00:00.053)       0:00:08.381 *********
#
# PLAY [Gather facts] ************************************************************
# Tuesday 15 April 2025  15:02:26 +0000 (0:00:00.063)       0:00:08.445 *********
#
# TASK [Gather minimal facts] ****************************************************
# ok: [dynamos]
# ok: [worker-2]
# ok: [worker-3]
# ok: [worker-1]
# ok: [control]
# Tuesday 15 April 2025  15:02:27 +0000 (0:00:00.662)       0:00:09.107 *********
#
# TASK [Gather necessary facts (network)] ****************************************
# ok: [dynamos]
# ok: [worker-2]
# ok: [worker-3]
# ok: [worker-1]
# ok: [control]
# Tuesday 15 April 2025  15:02:27 +0000 (0:00:00.713)       0:00:09.821 *********
#
# TASK [Gather necessary facts (hardware)] ***************************************
# ok: [dynamos]
# ok: [worker-3]
# ok: [worker-1]
# ok: [worker-2]
# ok: [control]
#
# PLAY [Prepare for etcd install] ************************************************
# Tuesday 15 April 2025  15:02:29 +0000 (0:00:01.170)       0:00:10.991 *********
# Tuesday 15 April 2025  15:02:29 +0000 (0:00:00.057)       0:00:11.049 *********
# Tuesday 15 April 2025  15:02:29 +0000 (0:00:00.057)       0:00:11.107 *********
# Tuesday 15 April 2025  15:02:29 +0000 (0:00:00.023)       0:00:11.130 *********
# Tuesday 15 April 2025  15:02:29 +0000 (0:00:00.060)       0:00:11.191 *********
# Tuesday 15 April 2025  15:02:29 +0000 (0:00:00.068)       0:00:11.259 *********
#
# TASK [adduser : User | Create User Group] **************************************
# changed: [dynamos] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# changed: [worker-3] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# changed: [worker-2] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# changed: [worker-1] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# changed: [control] => {"changed": true, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# Tuesday 15 April 2025  15:02:29 +0000 (0:00:00.411)       0:00:11.670 *********
#
# TASK [adduser : User | Create User] ********************************************
# changed: [dynamos] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# changed: [worker-2] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# changed: [worker-1] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# changed: [worker-3] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# changed: [control] => {"changed": true, "comment": "Kubernetes user", "create_home": false, "group": 988, "home": "/home/kube", "name": "kube", "shell": "/sbin/nologin", "state": "present", "system": true, "uid": 997}
# Tuesday 15 April 2025  15:02:30 +0000 (0:00:00.500)       0:00:12.171 *********
#
# TASK [kubernetes/preinstall : Check if /etc/fstab exists] **********************
# ok: [worker-3] => {"changed": false, "stat": {"atime": 1744728412.685, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [worker-2] => {"changed": false, "stat": {"atime": 1744728412.682, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [dynamos] => {"changed": false, "stat": {"atime": 1744728412.789, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [control] => {"changed": false, "stat": {"atime": 1744728412.703, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [worker-1] => {"changed": false, "stat": {"atime": 1744728412.69, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# Tuesday 15 April 2025  15:02:30 +0000 (0:00:00.381)       0:00:12.553 *********
#
# TASK [kubernetes/preinstall : Remove swapfile from /etc/fstab] *****************
# ok: [worker-2] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [dynamos] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [worker-3] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [worker-1] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [control] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [dynamos] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [worker-2] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [worker-3] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [worker-1] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [control] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# Tuesday 15 April 2025  15:02:31 +0000 (0:00:00.675)       0:00:13.228 *********
#
# TASK [kubernetes/preinstall : Mask swap.target (persist swapoff)] **************
# changed: [worker-2] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Tue 2025-04-15 14:48:53 UTC", "ActiveEnterTimestampMonotonic": "4410938", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Tue 2025-04-15 14:48:53 UTC", "AssertTimestampMonotonic": "4410935", "Before": "run-user-1000.mount sysinit.target shutdown.target", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Tue 2025-04-15 14:48:53 UTC", "ConditionTimestampMonotonic": "4410934", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Tue 2025-04-15 14:48:53 UTC", "InactiveExitTimestampMonotonic": "4410938", "InvocationID": "a1e3c7b13aa64dcdbbf5fee4f31c2106", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Tue 2025-04-15 14:48:53 UTC", "StateChangeTimestampMonotonic": "4410938", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# changed: [worker-3] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Tue 2025-04-15 14:48:41 UTC", "ActiveEnterTimestampMonotonic": "4494964", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Tue 2025-04-15 14:48:41 UTC", "AssertTimestampMonotonic": "4494961", "Before": "shutdown.target run-user-1000.mount sysinit.target", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Tue 2025-04-15 14:48:41 UTC", "ConditionTimestampMonotonic": "4494960", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Tue 2025-04-15 14:48:41 UTC", "InactiveExitTimestampMonotonic": "4494964", "InvocationID": "a36cf684ba0b4ff4aa3c9adc607cd364", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Tue 2025-04-15 14:48:41 UTC", "StateChangeTimestampMonotonic": "4494964", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# changed: [dynamos] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Tue 2025-04-15 14:48:43 UTC", "ActiveEnterTimestampMonotonic": "4090608", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Tue 2025-04-15 14:48:43 UTC", "AssertTimestampMonotonic": "4090605", "Before": "shutdown.target sysinit.target run-user-1000.mount", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Tue 2025-04-15 14:48:43 UTC", "ConditionTimestampMonotonic": "4090604", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Tue 2025-04-15 14:48:43 UTC", "InactiveExitTimestampMonotonic": "4090608", "InvocationID": "2d4725a09ef444109bc8207ef34611f7", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Tue 2025-04-15 14:48:43 UTC", "StateChangeTimestampMonotonic": "4090608", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# changed: [control] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Tue 2025-04-15 14:48:48 UTC", "ActiveEnterTimestampMonotonic": "4531758", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Tue 2025-04-15 14:48:48 UTC", "AssertTimestampMonotonic": "4531755", "Before": "sysinit.target shutdown.target run-user-1000.mount", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Tue 2025-04-15 14:48:48 UTC", "ConditionTimestampMonotonic": "4531754", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Tue 2025-04-15 14:48:48 UTC", "InactiveExitTimestampMonotonic": "4531758", "InvocationID": "f7739ad5d2424fdca71974439aaeeb28", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Tue 2025-04-15 14:48:48 UTC", "StateChangeTimestampMonotonic": "4531758", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# changed: [worker-1] => {"changed": true, "name": "swap.target", "status": {"ActiveEnterTimestamp": "Tue 2025-04-15 14:48:57 UTC", "ActiveEnterTimestampMonotonic": "4252729", "ActiveExitTimestampMonotonic": "0", "ActiveState": "active", "AllowIsolate": "no", "AssertResult": "yes", "AssertTimestamp": "Tue 2025-04-15 14:48:57 UTC", "AssertTimestampMonotonic": "4252727", "Before": "sysinit.target run-user-1000.mount shutdown.target", "CanFreeze": "no", "CanIsolate": "no", "CanReload": "no", "CanStart": "yes", "CanStop": "yes", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Tue 2025-04-15 14:48:57 UTC", "ConditionTimestampMonotonic": "4252726", "Conflicts": "shutdown.target", "DefaultDependencies": "yes", "Description": "Swaps", "Documentation": "\"man:systemd.special(7)\"", "FailureAction": "none", "FragmentPath": "/usr/lib/systemd/system/swap.target", "FreezerState": "running", "Id": "swap.target", "IgnoreOnIsolate": "no", "InactiveEnterTimestampMonotonic": "0", "InactiveExitTimestamp": "Tue 2025-04-15 14:48:57 UTC", "InactiveExitTimestampMonotonic": "4252729", "InvocationID": "ee3087eef2ee4c85b567d2f9ee126fef", "JobRunningTimeoutUSec": "infinity", "JobTimeoutAction": "none", "JobTimeoutUSec": "infinity", "LoadState": "loaded", "Names": "swap.target", "NeedDaemonReload": "no", "OnFailureJobMode": "replace", "OnSuccessJobMode": "fail", "Perpetual": "no", "RefuseManualStart": "no", "RefuseManualStop": "no", "StartLimitAction": "none", "StartLimitBurst": "5", "StartLimitIntervalUSec": "10s", "StateChangeTimestamp": "Tue 2025-04-15 14:48:57 UTC", "StateChangeTimestampMonotonic": "4252729", "StopWhenUnneeded": "no", "SubState": "active", "SuccessAction": "none", "SurviveFinalKillSignal": "no", "Transient": "no", "UnitFilePreset": "enabled", "UnitFileState": "static", "WantedBy": "sysinit.target"}}
# Tuesday 15 April 2025  15:02:32 +0000 (0:00:00.839)       0:00:14.068 *********
#
# TASK [kubernetes/preinstall : Disable swap] ************************************
# changed: [dynamos] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.003121", "end": "2025-04-15 15:02:32.469576", "msg": "", "rc": 0, "start": "2025-04-15 15:02:32.466455", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [worker-3] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.002912", "end": "2025-04-15 15:02:32.471702", "msg": "", "rc": 0, "start": "2025-04-15 15:02:32.468790", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [worker-2] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.003376", "end": "2025-04-15 15:02:32.469612", "msg": "", "rc": 0, "start": "2025-04-15 15:02:32.466236", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [control] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.003554", "end": "2025-04-15 15:02:32.472708", "msg": "", "rc": 0, "start": "2025-04-15 15:02:32.469154", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# changed: [worker-1] => {"changed": true, "cmd": ["/sbin/swapoff", "-a"], "delta": "0:00:00.005391", "end": "2025-04-15 15:02:32.493510", "msg": "", "rc": 0, "start": "2025-04-15 15:02:32.488119", "stderr": "", "stderr_lines": [], "stdout": "", "stdout_lines": []}
# Tuesday 15 April 2025  15:02:32 +0000 (0:00:00.386)       0:00:14.454 *********
# Tuesday 15 April 2025  15:02:32 +0000 (0:00:00.084)       0:00:14.539 *********
#
# TASK [kubernetes/preinstall : Check resolvconf] ********************************
# ok: [dynamos] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002586", "end": "2025-04-15 15:02:32.880408", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-15 15:02:32.877822", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [worker-1] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.005092", "end": "2025-04-15 15:02:32.905872", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-15 15:02:32.900780", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [worker-2] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.004505", "end": "2025-04-15 15:02:32.909400", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-15 15:02:32.904895", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [worker-3] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.002552", "end": "2025-04-15 15:02:32.920369", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-15 15:02:32.917817", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# ok: [control] => {"changed": false, "cmd": ["which", "resolvconf"], "delta": "0:00:00.004750", "end": "2025-04-15 15:02:32.953808", "failed_when_result": false, "msg": "", "rc": 0, "start": "2025-04-15 15:02:32.949058", "stderr": "", "stderr_lines": [], "stdout": "/usr/sbin/resolvconf", "stdout_lines": ["/usr/sbin/resolvconf"]}
# Tuesday 15 April 2025  15:02:32 +0000 (0:00:00.372)       0:00:14.911 *********

# %%
nodes[0].upload_file(local_file_path="node_scripts/reset_kubespray.sh", remote_file_path="reset.sh");
nodes[0].execute(f"chmod +x reset.sh && ./reset.sh");
# Out:
# Using /home/ubuntu/kubespray/ansible.cfg as config file
#
# PLAY [Check Ansible version] ***************************************************
# Tuesday 15 April 2025  12:28:07 +0000 (0:00:00.037)       0:00:00.037 *********
#  [WARNING]: While constructing a mapping from
# /home/ubuntu/kubespray/roles/bootstrap-os/tasks/main.yml, line 29, column 7,
# found a duplicate dict key (paths). Using last defined value only.
# [WARNING]: Skipping callback plugin 'ara_default', unable to load
#
# TASK [Check 2.16.4 <= Ansible version < 2.17.0] ********************************
# ok: [worker-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Tuesday 15 April 2025  12:28:07 +0000 (0:00:00.046)       0:00:00.083 *********
#
# TASK [Check that python netaddr is installed] **********************************
# ok: [worker-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Tuesday 15 April 2025  12:28:07 +0000 (0:00:00.074)       0:00:00.158 *********
#
# TASK [Check that jinja is not too old (install via pip)] ***********************
# ok: [worker-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
#
# PLAY [Define groups for legacy less structured inventories] ********************
# Tuesday 15 April 2025  12:28:07 +0000 (0:00:00.066)       0:00:00.225 *********
#
# TASK [Match needed groups by their old names or definition] ********************
# changed: [worker-2] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-2] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-2] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
#  [WARNING]: Could not match supplied host pattern, ignoring: bastion
#   [WARNING]: Could not match supplied host pattern, ignoring: calico_rr
#  changed: [worker-3] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-3] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-3] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [worker-4] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [worker-4] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [worker-4] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [worker-4] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [worker-4] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
# changed: [control] => (item={'key': 'kube_control_plane', 'value': ['kube-master']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": true, "item": {"key": "kube_control_plane", "value": ["kube-master"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'kube_node', 'value': ['kube-node']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "kube_node", "value": ["kube-node"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'calico_rr', 'value': ['calico-rr']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "calico_rr", "value": ["calico-rr"]}, "parent_groups": ["all"]}
# ok: [control] => (item={'key': 'no_floating', 'value': ['no-floating']}) => {"add_group": "_all", "ansible_loop_var": "item", "changed": false, "item": {"key": "no_floating", "value": ["no-floating"]}, "parent_groups": ["all"]}
# changed: [control] => (item={'key': 'k8s_cluster', 'value': ['kube_node', 'kube_control_plane', 'calico_rr']}) => {"add_group": "k8s_cluster", "ansible_loop_var": "item", "changed": true, "item": {"key": "k8s_cluster", "value": ["kube_node", "kube_control_plane", "calico_rr"]}, "parent_groups": ["all"]}
#
# PLAY [Install bastion ssh config] **********************************************
# skipping: no hosts matched
#
# PLAY [Bootstrap hosts for Ansible] *********************************************
# Tuesday 15 April 2025  12:28:07 +0000 (0:00:00.214)       0:00:00.439 *********
#  [WARNING]: raw module does not support the environment keyword
#
# TASK [bootstrap-os : Fetch /etc/os-release] ************************************
# ok: [control] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.2' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.2' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.2 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-4] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.5' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.5' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.5 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-2] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.3' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.3' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.3 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# ok: [worker-3] => {"changed": false, "rc": 0, "stderr": "Warning: Permanently added '10.145.3.4' (ED25519) to the list of known hosts.\r
# Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Warning: Permanently added '10.145.3.4' (ED25519) to the list of known hosts.", "Shared connection to 10.145.3.4 closed."], "stdout": "PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"\r
# NAME=\"Ubuntu\"\r
# VERSION_ID=\"24.04\"\r
# VERSION=\"24.04.2 LTS (Noble Numbat)\"\r
# VERSION_CODENAME=noble\r
# ID=ubuntu\r
# ID_LIKE=debian\r
# HOME_URL=\"https://www.ubuntu.com/\"\r
# SUPPORT_URL=\"https://help.ubuntu.com/\"\r
# BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"\r
# PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"\r
# UBUNTU_CODENAME=noble\r
# LOGO=ubuntu-logo\r
# ", "stdout_lines": ["PRETTY_NAME=\"Ubuntu 24.04.2 LTS\"", "NAME=\"Ubuntu\"", "VERSION_ID=\"24.04\"", "VERSION=\"24.04.2 LTS (Noble Numbat)\"", "VERSION_CODENAME=noble", "ID=ubuntu", "ID_LIKE=debian", "HOME_URL=\"https://www.ubuntu.com/\"", "SUPPORT_URL=\"https://help.ubuntu.com/\"", "BUG_REPORT_URL=\"https://bugs.launchpad.net/ubuntu/\"", "PRIVACY_POLICY_URL=\"https://www.ubuntu.com/legal/terms-and-policies/privacy-policy\"", "UBUNTU_CODENAME=noble", "LOGO=ubuntu-logo"]}
# Tuesday 15 April 2025  12:28:08 +0000 (0:00:00.851)       0:00:01.291 *********
# Tuesday 15 April 2025  12:28:08 +0000 (0:00:00.205)       0:00:01.496 *********
#
# TASK [bootstrap-os : Include tasks] ********************************************
# included: /home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml for worker-2, worker-3, worker-4, control => (item=/home/ubuntu/kubespray/roles/bootstrap-os/tasks/ubuntu.yml)
# Tuesday 15 April 2025  12:28:08 +0000 (0:00:00.325)       0:00:01.822 *********
#
# TASK [bootstrap-os : Check if bootstrap is needed] *****************************
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [worker-4] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.5 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# ok: [control] => {"changed": false, "failed_when_result": false, "rc": 0, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "/usr/bin/python3\r
# ", "stdout_lines": ["/usr/bin/python3"]}
# Tuesday 15 April 2025  12:28:09 +0000 (0:00:00.232)       0:00:02.054 *********
#
# TASK [bootstrap-os : Check http::proxy in apt configuration files] *************
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-4] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.5 closed."], "stdout": "", "stdout_lines": []}
# ok: [control] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "", "stdout_lines": []}
# Tuesday 15 April 2025  12:28:09 +0000 (0:00:00.234)       0:00:02.289 *********
# Tuesday 15 April 2025  12:28:09 +0000 (0:00:00.189)       0:00:02.478 *********
#
# TASK [bootstrap-os : Check https::proxy in apt configuration files] ************
# ok: [worker-2] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.3 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.3 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-3] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.4 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.4 closed."], "stdout": "", "stdout_lines": []}
# ok: [worker-4] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.5 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.5 closed."], "stdout": "", "stdout_lines": []}
# ok: [control] => {"changed": false, "failed_when_result": false, "msg": "non-zero return code", "rc": 1, "stderr": "Shared connection to 10.145.3.2 closed.\r
# ", "stderr_lines": ["Shared connection to 10.145.3.2 closed."], "stdout": "", "stdout_lines": []}
# Tuesday 15 April 2025  12:28:09 +0000 (0:00:00.232)       0:00:02.710 *********
# Tuesday 15 April 2025  12:28:09 +0000 (0:00:00.184)       0:00:02.895 *********
# Tuesday 15 April 2025  12:28:10 +0000 (0:00:00.171)       0:00:03.067 *********
# Tuesday 15 April 2025  12:28:10 +0000 (0:00:00.201)       0:00:03.269 *********
#
# TASK [bootstrap-os : Ensure iproute2 is installed] *****************************
# ok: [worker-4] => {"cache_update_time": 1744709140, "cache_updated": false, "changed": false}
# ok: [control] => {"cache_update_time": 1744707215, "cache_updated": false, "changed": false}
# ok: [worker-2] => {"cache_update_time": 1744710190, "cache_updated": false, "changed": false}
# ok: [worker-3] => {"cache_update_time": 1744709140, "cache_updated": false, "changed": false}
# Tuesday 15 April 2025  12:28:11 +0000 (0:00:01.008)       0:00:04.277 *********
# Tuesday 15 April 2025  12:28:11 +0000 (0:00:00.170)       0:00:04.447 *********
# Tuesday 15 April 2025  12:28:11 +0000 (0:00:00.144)       0:00:04.591 *********
#
# TASK [bootstrap-os : Create remote_tmp for it is used by another module] *******
# ok: [worker-4] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-2] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-3] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# ok: [control] => {"changed": false, "gid": 0, "group": "root", "mode": "0700", "owner": "root", "path": "/root/.ansible/tmp", "size": 4096, "state": "directory", "uid": 0}
# Tuesday 15 April 2025  12:28:12 +0000 (0:00:00.418)       0:00:05.010 *********
#
# TASK [bootstrap-os : Gather facts] *********************************************
# ok: [control]
# ok: [worker-4]
# ok: [worker-3]
# ok: [worker-2]
# Tuesday 15 April 2025  12:28:12 +0000 (0:00:00.658)       0:00:05.668 *********
#
# TASK [bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora)] ***
# ok: [worker-4] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "worker-4.cluster.local", "ansible_hostname": "worker-4", "ansible_nodename": "worker-4"}, "changed": false, "name": "worker-4"}
# ok: [control] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "control.cluster.local", "ansible_hostname": "control", "ansible_nodename": "control"}, "changed": false, "name": "control"}
# ok: [worker-2] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "worker-2.cluster.local", "ansible_hostname": "worker-2", "ansible_nodename": "worker-2"}, "changed": false, "name": "worker-2"}
# ok: [worker-3] => {"ansible_facts": {"ansible_domain": "cluster.local", "ansible_fqdn": "worker-3.cluster.local", "ansible_hostname": "worker-3", "ansible_nodename": "worker-3"}, "changed": false, "name": "worker-3"}
# Tuesday 15 April 2025  12:28:14 +0000 (0:00:01.766)       0:00:07.435 *********
# Tuesday 15 April 2025  12:28:14 +0000 (0:00:00.197)       0:00:07.632 *********
#
# TASK [bootstrap-os : Ensure bash_completion.d folder exists] *******************
# ok: [worker-2] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-3] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [worker-4] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# ok: [control] => {"changed": false, "gid": 0, "group": "root", "mode": "0755", "owner": "root", "path": "/etc/bash_completion.d/", "size": 4096, "state": "directory", "uid": 0}
# Tuesday 15 April 2025  12:28:15 +0000 (0:00:00.552)       0:00:08.184 *********
# Tuesday 15 April 2025  12:28:15 +0000 (0:00:00.202)       0:00:08.387 *********
#
# TASK [kubespray-defaults : Set fallback_ip] ************************************
# ok: [worker-2] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-3] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [worker-4] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# ok: [control] => {"ansible_facts": {"fallback_ip": "127.0.0.1"}, "changed": false}
# Tuesday 15 April 2025  12:28:15 +0000 (0:00:00.217)       0:00:08.605 *********
# Tuesday 15 April 2025  12:28:15 +0000 (0:00:00.048)       0:00:08.653 *********
# Tuesday 15 April 2025  12:28:15 +0000 (0:00:00.202)       0:00:08.856 *********
#
# PLAY [Gather facts] ************************************************************
# Tuesday 15 April 2025  12:28:16 +0000 (0:00:00.337)       0:00:09.194 *********
#
# TASK [Gather minimal facts] ****************************************************
# ok: [worker-2]
# ok: [worker-4]
# ok: [worker-3]
# ok: [control]
# Tuesday 15 April 2025  12:28:16 +0000 (0:00:00.487)       0:00:09.682 *********
#
# TASK [Gather necessary facts (network)] ****************************************
# ok: [worker-4]
# ok: [control]
# ok: [worker-3]
# ok: [worker-2]
# Tuesday 15 April 2025  12:28:17 +0000 (0:00:00.639)       0:00:10.321 *********
#
# TASK [Gather necessary facts (hardware)] ***************************************
# ok: [worker-2]
# ok: [worker-4]
# ok: [worker-3]
# ok: [control]
#
# PLAY [Reset cluster] ***********************************************************
# Tuesday 15 April 2025  12:28:18 +0000 (0:00:00.882)       0:00:11.204 *********
# Tuesday 15 April 2025  12:28:18 +0000 (0:00:00.054)       0:00:11.259 *********
# Tuesday 15 April 2025  12:28:18 +0000 (0:00:00.192)       0:00:11.452 *********
#
# TASK [Gather information about installed services] *****************************
# ok: [worker-4] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Mo ...
# ok: [control] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Mod ...
# ok: [worker-3] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Mo ...
# ok: [worker-2] => {"ansible_facts": {"services": {"ModemManager.service": {"name": "ModemManager.service", "source": "systemd", "state": "running", "status": "enabled"}, "NetworkManager.service": {"name": "NetworkManager.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "apparmor": {"name": "apparmor", "source": "sysv", "state": "running"}, "apparmor.service": {"name": "apparmor.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apport": {"name": "apport", "source": "sysv", "state": "running"}, "apport-autoreport.service": {"name": "apport-autoreport.service", "source": "systemd", "state": "stopped", "status": "static"}, "apport-coredump-hook@.service": {"name": "apport-coredump-hook@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport-forward@.service": {"name": "apport-forward@.service", "source": "systemd", "state": "unknown", "status": "static"}, "apport.service": {"name": "apport.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "apt-daily-upgrade.service": {"name": "apt-daily-upgrade.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-daily.service": {"name": "apt-daily.service", "source": "systemd", "state": "stopped", "status": "static"}, "apt-news.service": {"name": "apt-news.service", "source": "systemd", "state": "inactive", "status": "static"}, "auditd.service": {"name": "auditd.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "autovt@.service": {"name": "autovt@.service", "source": "systemd", "state": "unknown", "status": "alias"}, "blk-availability.service": {"name": "blk-availability.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "bolt.service": {"name": "bolt.service", "source": "systemd", "state": "inactive", "status": "static"}, "cloud-config.service": {"name": "cloud-config.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-final.service": {"name": "cloud-final.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init-hotplugd.service": {"name": "cloud-init-hotplugd.service", "source": "systemd", "state": "stopped", "status": "static"}, "cloud-init-local.service": {"name": "cloud-init-local.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "cloud-init.service": {"name": "cloud-init.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "connman.service": {"name": "connman.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-getty.service": {"name": "console-getty.service", "source": "systemd", "state": "inactive", "status": "disabled"}, "console-screen.service": {"name": "console-screen.service", "source": "systemd", "state": "stopped", "status": "not-found"}, "console-setup.service": {"name": "console-setup.service", "source": "systemd", "state": "stopped", "status": "enabled"}, "console-setup.sh": {"name": "console-setup.sh", "source": "sysv", "state": "stopped"}, "container-getty@.service": {"name": "container-getty@.service", "source": "systemd", "state": "unknown", "status": "static"}, "containerd.service": {"name": "containerd.service", "source": "systemd", "state": "running", "status": "enabled"}, "cron": {"name": "cron", "source": "sysv", "state": "running"}, "cron.service": {"name": "cron.service", "source": "systemd", "state": "running", "status": "enabled"}, "cryptdisks": {"name": "cryptdisks", "source": "sysv", "state": "stopped"}, "cryptdisks-early": {"name": "cryptdisks-early", "source": "sysv", "state": "stopped"}, "cryptdisks-early.service": {"name": "cryptdisks-early.service", "source": "systemd", "state": "inactive", "status": "masked"}, "cryptdisks.service": {"name": "cryptdisks.service", "source": "systemd", "state": "inactive", "status": "masked"}, "dbus": {"name": "dbus", "source": "sysv", "state": "running"}, "dbus-org.freedesktop.ModemManager1.service": {"name": "dbus-org.freedesktop.Mo ...
# Tuesday 15 April 2025  12:28:21 +0000 (0:00:02.640)       0:00:14.092 *********
# Tuesday 15 April 2025  12:28:21 +0000 (0:00:00.187)       0:00:14.279 *********
# Tuesday 15 April 2025  12:28:21 +0000 (0:00:00.154)       0:00:14.434 *********
# Tuesday 15 April 2025  12:28:21 +0000 (0:00:00.075)       0:00:14.510 *********
# Tuesday 15 April 2025  12:28:21 +0000 (0:00:00.173)       0:00:14.683 *********
# Tuesday 15 April 2025  12:28:22 +0000 (0:00:00.349)       0:00:15.032 *********
#
# TASK [adduser : User | Create User Group] **************************************
# ok: [control] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [worker-3] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [worker-2] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# ok: [worker-4] => {"changed": false, "gid": 988, "name": "kube-cert", "state": "present", "system": true}
# Tuesday 15 April 2025  12:28:22 +0000 (0:00:00.453)       0:00:15.486 *********
#
# TASK [adduser : User | Create User] ********************************************
# ok: [control] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# ok: [worker-4] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# ok: [worker-3] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# ok: [worker-2] => {"append": false, "changed": false, "comment": "Kubernetes user", "group": 988, "home": "/home/kube", "move_home": false, "name": "kube", "shell": "/sbin/nologin", "state": "present", "uid": 997}
# Tuesday 15 April 2025  12:28:23 +0000 (0:00:00.566)       0:00:16.052 *********
#
# TASK [kubernetes/preinstall : Check if /etc/fstab exists] **********************
# ok: [worker-2] => {"changed": false, "stat": {"atime": 1744636088.675, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [control] => {"changed": false, "stat": {"atime": 1744636087.788, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [worker-3] => {"changed": false, "stat": {"atime": 1744636087.709, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# ok: [worker-4] => {"changed": false, "stat": {"atime": 1744636087.7, "block_size": 4096, "blocks": 8, "ctime": 1733820091.8902233, "dev": 64769, "device_type": 0, "executable": false, "exists": true, "gid": 0, "gr_name": "root", "inode": 275, "isblk": false, "ischr": false, "isdir": false, "isfifo": false, "isgid": false, "islnk": false, "isreg": true, "issock": false, "isuid": false, "mode": "0644", "mtime": 1733820091.8902233, "nlink": 1, "path": "/etc/fstab", "pw_name": "root", "readable": true, "rgrp": true, "roth": true, "rusr": true, "size": 146, "uid": 0, "wgrp": false, "woth": false, "writeable": true, "wusr": true, "xgrp": false, "xoth": false, "xusr": false}}
# Tuesday 15 April 2025  12:28:23 +0000 (0:00:00.437)       0:00:16.490 *********
#
# TASK [kubernetes/preinstall : Remove swapfile from /etc/fstab] *****************
# ok: [worker-3] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [control] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [worker-2] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [worker-4] => (item=swap) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "swap", "name": "swap", "opts": "defaults", "passno": "0"}
# ok: [control] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [worker-3] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [worker-2] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# ok: [worker-4] => (item=none) => {"ansible_loop_var": "item", "backup_file": "", "boot": "yes", "changed": false, "dump": "0", "fstab": "/etc/fstab", "fstype": "swap", "item": "none", "name": "none", "opts": "defaults", "passno": "0"}
# Tuesday 15 April 2025  12:28:24 +0000 (0:00:00.598)       0:00:17.088 *********
#
# TASK [kubernetes/preinstall : Mask swap.target (persist swapoff)] **************
# ...
# changed: [worker-3] => (item=systemd-networkd) => {"ansible_loop_var": "item", "changed": true, "item": "systemd-networkd", "name": "systemd-networkd", "state": "started", "status": {"ActiveEnterTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ActiveEnterTimestampMonotonic": "73034533428", "ActiveExitTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ActiveExitTimestampMonotonic": "73034470545", "ActiveState": "active", "After": "systemd-sysusers.service systemd-sysctl.service systemd-udevd.service systemd-networkd.socket system.slice network-pre.target systemd-journald.socket -.mount", "AllowIsolate": "no", "AmbientCapabilities": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Tue 2025-04-15 09:27:03 UTC", "AssertTimestampMonotonic": "73034488563", "Before": "update-notifier-motd.timer network.target apt-daily-upgrade.service ubuntu-advantage.service multi-user.target systemd-networkd-wait-online.service shutdown.target update-notifier-download.timer ua-timer.service apt-daily.service initrd-switch-root.target", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BoundBy": "systemd-networkd-wait-online.service", "BusName": "org.freedesktop.network1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "186611000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime fdstore", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "yes", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ConditionTimestampMonotonic": "73034488505", "ConfigurationDirectoryMode": "0755", "Conflicts": "shutdown.target initrd-switch-root.target", "ControlGroup": "/system.slice/systemd-networkd.service", "ControlGroupId": "29289", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Configuration", "DeviceAllow": "char-* rw", "DevicePolicy": "auto", "Documentation": "\"man:systemd-networkd.service(8)\" \"man:org.freedesktop.network1(5)\"", "DynamicUser": "no", "EffectiveCPUs": "0-7", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "73342", "ExecMainStartTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ExecMainStartTimestampMonotonic": "73034498082", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "512", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-networkd.service", "FreezerState": "running", "GID": "998", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPE ...
# changed: [worker-2] => (item=systemd-networkd) => {"ansible_loop_var": "item", "changed": true, "item": "systemd-networkd", "name": "systemd-networkd", "state": "started", "status": {"ActiveEnterTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ActiveEnterTimestampMonotonic": "73019600813", "ActiveExitTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ActiveExitTimestampMonotonic": "73019544590", "ActiveState": "active", "After": "systemd-networkd.socket systemd-sysctl.service systemd-sysusers.service systemd-udevd.service network-pre.target system.slice systemd-journald.socket -.mount", "AllowIsolate": "no", "AmbientCapabilities": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Tue 2025-04-15 09:27:03 UTC", "AssertTimestampMonotonic": "73019563532", "Before": "multi-user.target update-notifier-download.timer ubuntu-advantage.service apt-daily-upgrade.service network.target initrd-switch-root.target apt-daily.service ua-timer.service update-notifier-motd.timer shutdown.target systemd-networkd-wait-online.service", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BoundBy": "systemd-networkd-wait-online.service", "BusName": "org.freedesktop.network1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "193639000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime fdstore", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "yes", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ConditionTimestampMonotonic": "73019563478", "ConfigurationDirectoryMode": "0755", "Conflicts": "initrd-switch-root.target shutdown.target", "ControlGroup": "/system.slice/systemd-networkd.service", "ControlGroupId": "31259", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Configuration", "DeviceAllow": "char-* rw", "DevicePolicy": "auto", "Documentation": "\"man:systemd-networkd.service(8)\" \"man:org.freedesktop.network1(5)\"", "DynamicUser": "no", "EffectiveCPUs": "0-7", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "75769", "ExecMainStartTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ExecMainStartTimestampMonotonic": "73019575174", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "512", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-networkd.service", "FreezerState": "running", "GID": "998", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPE ...
# changed: [worker-4] => (item=systemd-networkd) => {"ansible_loop_var": "item", "changed": true, "item": "systemd-networkd", "name": "systemd-networkd", "state": "started", "status": {"ActiveEnterTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ActiveEnterTimestampMonotonic": "73025982484", "ActiveExitTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ActiveExitTimestampMonotonic": "73025924985", "ActiveState": "active", "After": "systemd-sysctl.service system.slice network-pre.target systemd-sysusers.service systemd-journald.socket -.mount systemd-udevd.service systemd-networkd.socket", "AllowIsolate": "no", "AmbientCapabilities": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "AssertResult": "yes", "AssertTimestamp": "Tue 2025-04-15 09:27:03 UTC", "AssertTimestampMonotonic": "73025946547", "Before": "shutdown.target apt-daily-upgrade.service multi-user.target initrd-switch-root.target systemd-networkd-wait-online.service ua-timer.service update-notifier-download.timer apt-daily.service update-notifier-motd.timer ubuntu-advantage.service network.target", "BlockIOAccounting": "no", "BlockIOWeight": "[not set]", "BoundBy": "systemd-networkd-wait-online.service", "BusName": "org.freedesktop.network1", "CPUAccounting": "yes", "CPUAffinityFromNUMA": "no", "CPUQuotaPerSecUSec": "infinity", "CPUQuotaPeriodUSec": "infinity", "CPUSchedulingPolicy": "0", "CPUSchedulingPriority": "0", "CPUSchedulingResetOnFork": "no", "CPUShares": "[not set]", "CPUUsageNSec": "124521000", "CPUWeight": "[not set]", "CacheDirectoryMode": "0755", "CanClean": "runtime fdstore", "CanFreeze": "yes", "CanIsolate": "no", "CanReload": "yes", "CanStart": "yes", "CanStop": "yes", "CapabilityBoundingSet": "cap_net_bind_service cap_net_broadcast cap_net_admin cap_net_raw", "CleanResult": "success", "CollectMode": "inactive", "ConditionResult": "yes", "ConditionTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ConditionTimestampMonotonic": "73025946503", "ConfigurationDirectoryMode": "0755", "Conflicts": "initrd-switch-root.target shutdown.target", "ControlGroup": "/system.slice/systemd-networkd.service", "ControlGroupId": "28854", "ControlPID": "0", "CoredumpFilter": "0x33", "CoredumpReceive": "no", "DefaultDependencies": "no", "DefaultMemoryLow": "0", "DefaultMemoryMin": "0", "DefaultStartupMemoryLow": "0", "Delegate": "no", "Description": "Network Configuration", "DeviceAllow": "char-* rw", "DevicePolicy": "auto", "Documentation": "\"man:systemd-networkd.service(8)\" \"man:org.freedesktop.network1(5)\"", "DynamicUser": "no", "EffectiveCPUs": "0-7", "EffectiveMemoryNodes": "0", "ExecMainCode": "0", "ExecMainExitTimestampMonotonic": "0", "ExecMainPID": "73383", "ExecMainStartTimestamp": "Tue 2025-04-15 09:27:03 UTC", "ExecMainStartTimestampMonotonic": "73025957064", "ExecMainStatus": "0", "ExecStart": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; ignore_errors=no ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExecStartEx": "{ path=/usr/lib/systemd/systemd-networkd ; argv[]=/usr/lib/systemd/systemd-networkd ; flags=ambient ; start_time=[n/a] ; stop_time=[n/a] ; pid=0 ; code=(null) ; status=0/0 }", "ExitType": "main", "ExtensionImagePolicy": "root=verity+signed+encrypted+unprotected+absent:usr=verity+signed+encrypted+unprotected+absent:home=encrypted+unprotected+absent:srv=encrypted+unprotected+absent:tmp=encrypted+unprotected+absent:var=encrypted+unprotected+absent", "FailureAction": "none", "FileDescriptorStoreMax": "512", "FileDescriptorStorePreserve": "restart", "FinalKillSignal": "9", "FragmentPath": "/usr/lib/systemd/system/systemd-networkd.service", "FreezerState": "running", "GID": "998", "GuessMainPID": "yes", "IOAccounting": "no", "IOReadBytes": "[not set]", "IOReadOperations": "[not set]", "IOSchedulingClass": "2", "IOSchedulingPriority": "4", "IOWeight": "[not set]", "IOWriteBytes": "[not set]", "IOWriteOperations": "[not set]", "IPAccounting": "no", "IPEgressBytes": "[no data]", "IPE ...
#
# PLAY RECAP *********************************************************************
# control                    : ok=122  changed=27   unreachable=0    failed=0    skipped=91   rescued=0    ignored=0
# worker-2                   : ok=108  changed=27   unreachable=0    failed=0    skipped=90   rescued=0    ignored=0
# worker-3                   : ok=105  changed=27   unreachable=0    failed=0    skipped=89   rescued=0    ignored=0
# worker-4                   : ok=105  changed=27   unreachable=0    failed=0    skipped=89   rescued=0    ignored=0
#
# Tuesday 15 April 2025  12:30:12 +0000 (0:00:00.873)       0:02:05.310 *********
# ===============================================================================
# reset : Reset | stop services ------------------------------------------ 17.26s
# reset : Reset | delete some files and directories ---------------------- 15.45s
# kubernetes/preinstall : Update package management cache (APT) ----------- 7.33s
# reset : Reset | unmount kubelet dirs ------------------------------------ 3.19s
# network_plugin/cni : CNI | Copy cni plugins ----------------------------- 3.08s
# Gather information about installed services ----------------------------- 2.64s
# kubernetes/preinstall : Ensure kubelet expected parameters are set ------ 2.25s
# reset : Reset | remove containerd binary files -------------------------- 1.98s
# reset : Reset | remove services ----------------------------------------- 1.92s
# reset : Gather active network services ---------------------------------- 1.87s
# bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora) --- 1.77s
# kubernetes/preinstall : Enable ip forwarding ---------------------------- 1.30s
# network_plugin/cni : CNI | make sure /opt/cni/bin exists ---------------- 1.21s
# reset : Reset | stop all cri containers --------------------------------- 1.06s
# bootstrap-os : Ensure iproute2 is installed ----------------------------- 1.01s
# kubernetes/preinstall : Install packages requirements ------------------- 0.99s
# reset : Reset | stop all cri pods --------------------------------------- 0.98s
# reset : Flush iptables -------------------------------------------------- 0.95s
# kubernetes/preinstall : Preinstall | Restart systemd-resolved ----------- 0.95s
# kubernetes/preinstall : Hosts | create hosts list from inventory -------- 0.93s
